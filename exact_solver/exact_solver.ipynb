# %% [markdown]
# Imports

# %%
from gurobipy import *
import numpy as np

from db_manager import *
from load_data import *
from printing import *

# %%
# clases
from entities import *
from variables import *

# %% [markdown]
# # Cargar datos

# %% [markdown]
# ## (1) Instancia

# %%
instance = "../instances/instance_2025sem2.json"
dias, turnos, horarios, bloques_horario, grupos, materias, profesores, superposicion, superposicion_electivas, num_salones = read_json_instance(instance)

# %%
dias_ids = [d.id for d in dias]
DIAS = dias

horarios_ids = [h.id for h in horarios]
HORARIOS = horarios

bloques_horario_ids = [b for b in bloques_horario]
BLOQUES_HORARIO = bloques_horario

profesores_ids = [p.id for p in profesores]
PROFESORES = profesores

grupos_ids = [g.id for g in grupos]
GRUPOS = grupos

anios = list(set([g.anio for g in grupos if g.anio != None]))  # anios
ANIOS = anios

materias_ids = [m.id for m in materias]
MATERIAS = materias

SUPERPOSICION = superposicion
SUPERPOSICION_ELECTIVAS = superposicion_electivas

# %%
# # print(*[str(g) for g in grupos], sep="\n")
# print(*[m.profesores for m in materias], sep="\n")

# %%
print_prioridades(dias, horarios, profesores)
# Out:
#  Profesor: 1 1  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	1	1
# 2_start-2_end	-	-	-	1	1
# 3_start-3_end	-	-	-	1	1
# 4_start-4_end	-	-	1	1	1
# 5_start-5_end	-	-	1	1	1
# 6_start-6_end	-	-	1	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 2 2  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 3 3  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	3	-
# 1_start-1_end	1	1	1	3	1
# 2_start-2_end	1	1	1	3	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 4 4  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 5 5  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	1	1	1	-	1
# 4_start-4_end	1	1	1	-	1
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 6 6  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	3	-	3	-
#
#  Profesor: 7 7  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	2	-	2	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	1	-	1	-
# 7_start-7_end	-	1	-	1	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	3	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 8 8  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	-	-
# 9_start-9_end	1	1	1	-	-
# 10_start-10_end	1	1	1	1	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	1	1	1	1	-
# 13_start-13_end	1	1	1	-	-
# 14_start-14_end	1	1	1	-	-
# 15_start-15_end	2	2	2	-	-
#
#  Profesor: 9 9  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 10 10  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 11 11  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 12 12  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 13 13  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 14 14  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	1	-	1	2
# 9_start-9_end	-	1	-	1	2
# 10_start-10_end	-	1	-	1	2
# 11_start-11_end	-	1	-	1	2
# 12_start-12_end	-	2	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 15 15  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	2	2
# 1_start-1_end	1	1	1	2	2
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 16 16  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	1	-	1
# 9_start-9_end	-	-	1	-	1
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 17 17  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	2	1	2	3
# 3_start-3_end	1	2	1	2	3
# 4_start-4_end	1	2	3	3	3
# 5_start-5_end	-	-	3	3	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 18 18  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	3	-	-
# 12_start-12_end	2	-	3	1	-
# 13_start-13_end	1	-	-	1	-
# 14_start-14_end	1	-	-	1	-
# 15_start-15_end	1	-	-	2	-
#
#  Profesor: 19 19  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	-	-	-
# 2_start-2_end	1	1	-	-	-
# 3_start-3_end	1	1	1	-	-
# 4_start-4_end	1	1	1	-	-
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	3	3	3	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 20 20  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 21 21  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	1	-	1	-	-
# 11_start-11_end	1	-	1	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 22 22  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 23 23  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	2	2	2	2	2
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 24 24  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	-
# 1_start-1_end	1	1	1	1	-
# 2_start-2_end	2	2	2	2	-
# 3_start-3_end	2	2	2	2	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	1	1	1	1	-
# 13_start-13_end	1	1	1	1	-
# 14_start-14_end	1	1	1	1	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 25 25  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	2	-	2	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	3	-	3	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 26 26  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 27 27  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	3	-	2
# 3_start-3_end	-	-	2	-	2
# 4_start-4_end	-	-	1	-	1
# 5_start-5_end	-	-	1	-	1
# 6_start-6_end	-	-	1	-	1
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	1	-	1
# 12_start-12_end	-	-	1	-	1
# 13_start-13_end	-	-	1	-	1
# 14_start-14_end	-	-	3	-	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 28 28  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	2	1	2	1	2
# 3_start-3_end	2	1	2	1	2
# 4_start-4_end	2	1	2	1	2
# 5_start-5_end	2	1	2	1	2
# 6_start-6_end	1	1	1	1	3
# 7_start-7_end	1	1	1	1	3
# 8_start-8_end	1	1	1	1	3
# 9_start-9_end	1	1	1	1	3
# 10_start-10_end	1	1	1	1	3
# 11_start-11_end	3	1	1	1	-
# 12_start-12_end	3	1	1	1	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 29 29  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	-	1	3
# 1_start-1_end	1	1	-	1	3
# 2_start-2_end	2	2	-	2	3
# 3_start-3_end	3	3	-	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 30 30  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	-	1	2
# 1_start-1_end	1	2	-	1	2
# 2_start-2_end	3	-	-	3	-
# 3_start-3_end	3	-	-	3	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 31 31  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	3	3	3	3
# 1_start-1_end	3	3	3	3	3
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	2	2	2	2	2
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	2	2	2	2	2
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	2	2	2	2	2
# 12_start-12_end	3	3	3	3	3
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 32 32  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	3	-	-	-	3
# 2_start-2_end	1	-	-	-	1
# 3_start-3_end	1	-	-	-	1
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 33 33  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	3	3	3	3
# 1_start-1_end	3	3	3	3	3
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	1	2	1	2	3
# 4_start-4_end	1	2	1	2	3
# 5_start-5_end	1	2	1	2	3
# 6_start-6_end	1	2	1	2	3
# 7_start-7_end	1	3	1	2	3
# 8_start-8_end	1	3	1	2	3
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 34 34  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	2	2	1	-
# 1_start-1_end	2	2	2	1	-
# 2_start-2_end	2	2	2	1	-
# 3_start-3_end	3	3	3	3	-
# 4_start-4_end	3	3	3	3	-
# 5_start-5_end	3	3	3	3	-
# 6_start-6_end	3	3	3	3	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 35 35  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	2	2	2	2	1
#
#  Profesor: 36 36  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 37 37  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	3	1	3	1	3
# 4_start-4_end	3	1	3	1	3
# 5_start-5_end	3	1	3	1	3
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 38 38  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	3	-	3	-
# 1_start-1_end	-	2	-	2	-
# 2_start-2_end	-	2	-	2	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	3	-	3	-
# 7_start-7_end	-	1	-	1	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	3	-	3	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 39 39  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	3	3	3	3
# 1_start-1_end	3	3	3	3	3
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 40 40  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 41 41  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	-
# 3_start-3_end	1	1	1	1	-
# 4_start-4_end	-	3	-	3	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 42 42  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	2
# 13_start-13_end	2	1	1	1	3
# 14_start-14_end	3	2	2	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 43 43  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 44 44  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	-	-	1	3
# 3_start-3_end	3	1	-	1	3
# 4_start-4_end	3	1	-	1	3
# 5_start-5_end	3	1	-	1	3
# 6_start-6_end	3	1	-	1	3
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 45 45  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	1	1	1
# 1_start-1_end	2	1	1	1	1
# 2_start-2_end	-	3	3	2	2
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	1	2	3	1
# 12_start-12_end	3	1	2	3	1
# 13_start-13_end	3	1	2	3	1
# 14_start-14_end	3	1	2	3	1
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 46 46  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 47 47  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	-	-	-	3
# 1_start-1_end	3	-	-	-	3
# 2_start-2_end	3	-	-	-	3
# 3_start-3_end	3	-	-	-	3
# 4_start-4_end	3	-	-	-	3
# 5_start-5_end	3	-	-	-	3
# 6_start-6_end	3	-	-	-	3
# 7_start-7_end	3	-	-	-	3
# 8_start-8_end	3	-	-	-	3
# 9_start-9_end	3	-	-	-	3
# 10_start-10_end	3	-	-	-	3
# 11_start-11_end	3	-	-	-	3
# 12_start-12_end	3	-	-	-	3
# 13_start-13_end	3	-	-	-	3
# 14_start-14_end	3	-	-	-	3
# 15_start-15_end	3	-	-	-	3
#
#  Profesor: 48 48  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 49 49  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	3	1	1
# 1_start-1_end	1	1	3	1	1
# 2_start-2_end	2	2	3	2	2
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 50 50  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	3	2	1
# 1_start-1_end	1	2	3	2	1
# 2_start-2_end	1	3	3	3	1
# 3_start-3_end	1	3	3	3	1
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 51 51  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	-	1	-	1
# 12_start-12_end	2	2	1	3	1
# 13_start-13_end	2	2	1	3	1
# 14_start-14_end	2	2	1	3	1
# 15_start-15_end	2	2	1	3	1
#
#  Profesor: 52 52  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	3	1	-
# 12_start-12_end	-	1	3	1	-
# 13_start-13_end	-	1	3	1	-
# 14_start-14_end	-	2	3	2	-
# 15_start-15_end	-	2	3	2	-
#
#  Profesor: 53 53  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	1	1	1	1
# 1_start-1_end	3	1	1	1	1
# 2_start-2_end	2	1	1	1	1
# 3_start-3_end	2	1	1	1	2
# 4_start-4_end	1	1	1	1	2
# 5_start-5_end	1	1	1	1	3
# 6_start-6_end	1	1	1	1	3
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 54 54  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 55 55  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 56 56  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 57 57  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	3	3	3	3	3
# 8_start-8_end	3	3	3	3	3
# 9_start-9_end	3	3	3	3	3
# 10_start-10_end	3	3	3	3	3
# 11_start-11_end	2	2	2	2	2
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 58 58  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	-	3	-	3
# 1_start-1_end	3	-	3	-	3
# 2_start-2_end	1	-	1	-	1
# 3_start-3_end	1	-	1	-	1
# 4_start-4_end	1	-	1	-	1
# 5_start-5_end	1	-	1	-	1
# 6_start-6_end	2	3	2	3	2
# 7_start-7_end	2	3	2	3	2
# 8_start-8_end	3	3	3	3	3
# 9_start-9_end	3	-	3	-	3
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 59 59  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 60 60  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	-	1
# 1_start-1_end	-	1	1	-	1
# 2_start-2_end	-	1	1	-	1
# 3_start-3_end	-	1	1	-	1
# 4_start-4_end	-	1	1	-	1
# 5_start-5_end	-	1	1	-	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 61 61  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 62 62  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	3	3	-	-
# 1_start-1_end	-	3	-	3	3
# 2_start-2_end	3	2	2	2	2
# 3_start-3_end	3	1	1	1	2
# 4_start-4_end	3	1	1	1	2
# 5_start-5_end	3	1	1	1	2
# 6_start-6_end	3	1	1	1	1
# 7_start-7_end	3	1	1	1	1
# 8_start-8_end	2	1	1	1	1
# 9_start-9_end	2	1	1	1	1
# 10_start-10_end	2	2	2	2	2
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 63 63  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	3	3	3	3	3
# 8_start-8_end	3	3	3	3	3
# 9_start-9_end	3	3	3	3	3
# 10_start-10_end	2	2	2	2	3
# 11_start-11_end	2	1	1	1	3
# 12_start-12_end	2	1	1	1	3
# 13_start-13_end	2	2	2	2	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 64 64  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	2	1	2	1
# 9_start-9_end	1	2	1	2	1
# 10_start-10_end	1	-	1	-	2
# 11_start-11_end	3	-	-	-	2
# 12_start-12_end	-	-	-	-	3
# 13_start-13_end	-	-	-	-	3
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 65 65  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	2	1	2
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	2	2	2	2	2
# 15_start-15_end	2	2	2	2	2
#
#  Profesor: 66 66  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	1	-	2
# 3_start-3_end	1	-	1	-	2
# 4_start-4_end	2	1	2	1	3
# 5_start-5_end	2	1	2	1	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 67 67  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	-	1	-
# 12_start-12_end	2	1	-	1	-
# 13_start-13_end	3	2	-	2	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 68 68  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	1	3	1	-
# 10_start-10_end	3	1	3	1	-
# 11_start-11_end	3	1	3	1	-
# 12_start-12_end	3	1	3	1	-
# 13_start-13_end	3	1	3	1	-
# 14_start-14_end	3	1	3	1	-
# 15_start-15_end	3	1	3	1	-
#
#  Profesor: 69 69  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	2	2	2	2
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 70 70  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 71 71  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	3	1	3	1	3
# 13_start-13_end	3	1	3	1	3
# 14_start-14_end	3	1	3	1	3
# 15_start-15_end	3	1	3	1	3
#
#  Profesor: 72 72  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 73 73  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	-	1
# 1_start-1_end	-	1	-	-	1
# 2_start-2_end	-	1	-	-	1
# 3_start-3_end	-	1	-	-	1
# 4_start-4_end	-	1	-	-	1
# 5_start-5_end	-	2	-	-	2
# 6_start-6_end	-	2	-	-	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 74 74  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	3	1	2
# 3_start-3_end	1	-	3	1	2
# 4_start-4_end	1	-	3	1	2
# 5_start-5_end	1	1	3	1	2
# 6_start-6_end	1	1	3	1	2
# 7_start-7_end	1	1	3	1	2
# 8_start-8_end	1	1	3	1	2
# 9_start-9_end	1	1	3	1	2
# 10_start-10_end	3	-	-	3	3
# 11_start-11_end	3	-	-	3	-
# 12_start-12_end	3	-	-	3	-
# 13_start-13_end	3	-	-	3	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 75 75  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	1	2	1
# 1_start-1_end	1	2	1	2	1
# 2_start-2_end	1	3	1	3	1
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	3	-	-	2
# 11_start-11_end	-	3	-	-	2
# 12_start-12_end	-	3	-	-	2
# 13_start-13_end	-	-	-	-	2
# 14_start-14_end	-	-	-	-	2
# 15_start-15_end	-	-	-	-	2
#
#  Profesor: 76 76  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	2
# 2_start-2_end	2	-	-	-	2
# 3_start-3_end	1	-	-	3	1
# 4_start-4_end	1	-	-	3	1
# 5_start-5_end	1	-	-	-	1
# 6_start-6_end	3	-	-	-	3
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 77 77  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 78 78  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 79 79  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	-	-
# 1_start-1_end	1	1	1	-	-
# 2_start-2_end	1	1	1	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 80 80  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 81 81  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	-	-
# 10_start-10_end	1	1	1	-	2
# 11_start-11_end	-	2	-	2	2
# 12_start-12_end	1	2	2	2	3
# 13_start-13_end	-	-	2	-	-
# 14_start-14_end	-	-	3	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 82 82  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	-	-	1
# 1_start-1_end	1	1	-	-	1
# 2_start-2_end	1	1	-	-	1
# 3_start-3_end	1	1	-	-	1
# 4_start-4_end	1	1	-	-	-
# 5_start-5_end	1	1	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 83 83  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	-	-	-	3
# 1_start-1_end	2	-	-	-	3
# 2_start-2_end	2	-	-	-	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	-	-	1
# 12_start-12_end	1	-	-	-	1
# 13_start-13_end	1	-	-	-	1
# 14_start-14_end	1	-	-	-	1
# 15_start-15_end	1	-	-	-	1
#
#  Profesor: 84 84  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	1	1	1	-	-
# 11_start-11_end	1	1	1	-	-
# 12_start-12_end	1	1	1	-	-
# 13_start-13_end	1	1	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 85 85  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	-	3
# 12_start-12_end	1	1	1	-	3
# 13_start-13_end	1	1	1	-	3
# 14_start-14_end	1	1	1	-	3
# 15_start-15_end	1	1	1	-	3
#
#  Profesor: 86 86  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	3	3	3	3	3
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 87 87  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	3	-	3	3
# 1_start-1_end	-	3	-	3	3
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	1
# 5_start-5_end	-	-	-	-	1
# 6_start-6_end	-	-	-	-	1
# 7_start-7_end	-	2	-	2	1
# 8_start-8_end	-	2	-	2	1
# 9_start-9_end	-	3	-	3	1
# 10_start-10_end	-	3	-	3	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 88 88  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 89 89  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	3	3	-	3	3
# 2_start-2_end	2	2	-	2	2
# 3_start-3_end	1	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	2	2	2	2	2
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 90 90  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	1	-	1	1
# 3_start-3_end	-	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	1	1	-	1	1
# 6_start-6_end	1	1	-	1	1
# 7_start-7_end	-	1	-	-	1
# 8_start-8_end	-	1	-	-	1
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 91 91  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	3	3	1	2
# 1_start-1_end	1	3	3	1	2
# 2_start-2_end	-	3	3	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	1	3	2
# 12_start-12_end	2	1	1	3	2
# 13_start-13_end	2	1	1	3	2
# 14_start-14_end	2	1	1	3	2
# 15_start-15_end	2	1	1	3	2
#
#  Profesor: 92 92  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	2	2	1
# 1_start-1_end	1	2	2	2	1
# 2_start-2_end	1	2	2	2	1
# 3_start-3_end	-	-	-	-	3
# 4_start-4_end	-	-	-	-	3
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 93 93  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	1	-	1	2
# 9_start-9_end	-	1	-	1	2
# 10_start-10_end	-	1	-	1	2
# 11_start-11_end	-	1	-	1	2
# 12_start-12_end	-	2	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 94 94  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	2	-	2	-
#
#  Profesor: 95 95  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	-	1	-	1
# 12_start-12_end	3	-	1	-	1
# 13_start-13_end	-	-	2	-	2
# 14_start-14_end	-	-	2	-	2
# 15_start-15_end	-	-	-	-	-

# %%
print("Grupos:", len(grupos))
# print([str(i) for i in grupos])
print("Materias:", len(materias))
# print([str(i) for i in materias])
print("Profesores:", len(profesores))
# print([str(i) for i in profesores])
# Out:
# Grupos: 27
# Materias: 127
# Profesores: 95

# %% [markdown]
# # Formulacion

# %% [markdown]
# ## (2) Variables
#
#
# $$ u_{mb} \in \{0,1\} $$
#
#     m: materia
#     b: bloque horario = [dh]: dia y hora
#
# $$ v_{md} \in \{0,1\} $$
#
#     m: materia
#     d: dia
#
# $$ w_{mp} \in \{0,1\} $$
#
#     m: materia
#     p: profesor
#
#
# $$ x_{gb} \in \{0,1\} $$
#
#     g: grupo
#     b: bloque horario = [dh]: dia y hora
#
# $$ y_{pb} \in \{0,1\} $$
#
#     p: profesor
#     b: bloque horario = [dh]: dia y hora
#
# $$ z_{pd} \in \{0,1\} $$
#
#     p: profesor
#     d: dia

# %%
print(len(materias))
print(len(bloques_horario))
# Out:
# 127
# 80

# %% [markdown]
# ## (3) Restricciones

# %% [markdown]
# ### (3.1) Materias

# %% [markdown]
# #### (3.1.1) superposicion (redundante con la definicion de la variable x)
# $$ \sum_{b} \sum_{m, m'}{u_{mb} \times S_{m,m'} \times u_{m'b}} = 0 $$

# %%
"""
    This code defines constraints to ensure that no two subjects (materias) overlap
    in the same time block (bloque horario).
    Constraints:
        1. For each time block (b) in bloques_horario_ids, the sum of the product of the decision variables 
        (u_dict[m1, b].variable and u_dict[m2, b].variable) and the overlap value (superposicion[(m1, m2)].value)
        for all pairs of subjects (m1, m2) must be equal to 0.
"""

def constr_superposicion(model, u_dict):

    model.addConstrs(gp.quicksum(u_dict[m1, b].variable * superposicion[(m1, m2)].value * u_dict[m2, b].variable
                            for m1 in materias_ids for m2 in materias_ids)
                == 0 for b in bloques_horario_ids)

# %% [markdown]
# #### (3.1.2) cubrir carga horaria para cada materia
# $$ \sum_b{u_{mb}} = C_m $$
#
#     para todo m (c_m: carga horaria)

# %%
def constr_carga_horaria(model, u_dict):
    for m in materias:
        model.addConstr(gp.quicksum(u_dict[m.id, b].variable for b in bloques_horario_ids) == m.carga_horaria)

# %% [markdown]
# #### (3.1.3) particion de horas por materia

# %% [markdown]
# ##### (3.1.3.1) fijar cantidad de dias por materia
#
# $$ \sum_d {v_{md}} = D_m $$
#
#     para todo m

# %%
def constr_dias_materia(model, v_dict):
    for m in materias:
        model.addConstr(gp.quicksum(v_dict[m.id, d].variable for d in dias_ids) == m.cantidad_dias)

# %% [markdown]
# ##### (3.1.3.2) fijar maximo y minimo de horas por dia
#
# $$ v_{md} \times {H_{MIN}}_m \leq \sum_h {u_{mdh}} \leq v_{md} \times {H_{MAX}}_m $$
#
#     para todo m, d

# %%
def constr_max_min_horas(model, u_dict, v_dict):

    for m in materias:

        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        <= m.horas_max() * v_dict[m.id,d].variable for d in dias_ids)
        
        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        >= m.horas_min() * v_dict[m.id,d].variable for d in dias_ids)

# %% [markdown]
# ##### (3.1.3.3) fijar materia a turno de horarios
#
# $$ u_{mb} = 0 $$
#
#     para todo b fuera de m.turnos
#     para todo m

# %%
def constr_turnos_materia(model, u_dict):

    for m in materias:
        no_bloques_materia_ids = [b for b in bloques_horario if b not in bloques_horario_materia(m, bloques_horario)]
        model.addConstrs(u_dict[m.id, b].variable == 0 for b in no_bloques_materia_ids)

# %% [markdown]
# #### (3.1.4) horas consecutivas dentro de un dia
#
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} = v_{md} $$
#     para todo m, d

# %%
def constr_horas_consecutivas(model, u_dict, v_dict):

    model.addConstrs(gp.quicksum(u_dict[(m,(d,h))].variable for h in horarios_ids)
                 - gp.quicksum(u_dict[(m,(d,h))].variable * u_dict[(m,(d,h+1))].variable for h in horarios_ids[0:-1])
                 == v_dict[m, d].variable for m in materias_ids for d in dias_ids)

# %% [markdown]
# Alternativa:
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} \leq 1 $$
#     para todo m, d

# %% [markdown]
# #### (3.1.5) evitar dias consecutivos para una misma materia
#
# $$ \sum_m \sum_d {v_{m(d)} · v_{m(d+1)}} = 0 $$

# %%
mats_dias_consecutivos = [mat for mat in materias if mat.dias_consecutivos]

def constr_dias_consecutivos(model, v_dict):

    model.addConstrs(gp.quicksum(v_dict[m,d].variable * v_dict[m,d+1].variable for d in dias_ids[0:-1]) == 0
                 for m in [mat.id for mat in materias if not mat in mats_dias_consecutivos])

# %% [markdown]
# ### (3.2) Profesores

# %% [markdown]
# #### (3.2.1) indisponibilidad
#
# $$ \sum_m w_{mp} \times u_{mb} = 0 $$
#
#     para todo p sin disponibilidad en b

# %%
def constr_no_disponible_profesor(model, u_dict, w_dict):
    for m in materias:
        for p in m.profesores:
            for b in p.no_disponible:
                model.addConstr(u_dict[m.id, b.id].variable * w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# #### (3.2.2) unica materia por profesor para un mismo bloque horario
#
# $$ \sum_{m} {w_{mp} \times u_{mb}} \leq 1 $$
#
#     para todo b, p

# %% [markdown]
# REDUNDANTE CON DEFINICION DE y_pb

# %%
p_grupos_simultaneos = [p.nombre for p in profesores if p.cursos_simultaneos]

def constr_unica_materia_profesor(model, u_dict, w_dict):

    for p in [p for p in profesores if p.nombre not in p_grupos_simultaneos]:
        model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids)
                     <= 1 for b in bloques_horario_ids)
        
    # caso particular
    for p in [p for p in profesores if p.nombre in p_grupos_simultaneos]:
        model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids)
                     <= 2 for b in bloques_horario_ids)

# %% [markdown]
# #### (3.2.3) profesores por materia

# %% [markdown]
# ##### (3.2.3.1) limitar profesores a lista
#
# $$ w_{mp} = 0 $$
#
#     para todo p not in m.lista_profesores
#     para todo m

# %%
def constr_limitar_profesores_materia(model, w_dict):
    
    for m in materias:
        for p in profesores:
            if p not in m.profesores:
                model.addConstr(w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# ##### (3.2.3.2) cantidad de profesores para una misma materia
#
# $$ \sum_p {w_{mp}} = P_m $$
#
#     para todo m

# %%
def constr_cantidad_profesores(model, w_dict):
    for m in materias:
        model.addConstr(gp.quicksum(w_dict[m.id, p].variable for p in profesores_ids) == m.cantidad_profesores)

# %% [markdown]
# #### (3.2.4) carga horaria por docente: limitar la cantidad de materias por profesor
#
#
# $$ \sum_m {w_{mp}} \leq K_p $$
#
#     para todo p

# %%
# separar por nombre de materia
def constr_grupos_max_profesor(model, w_dict):
    for p in profesores:
        for l in p.lista_materias:
            mats = search_materias_by_nombre(materias, l["nombre_materia"]) # subject_id
            if len(mats) > 0:
                model.addConstr(gp.quicksum(w_dict[m.id, p.id].variable for m in mats) <= l["grupos_max"])

# %% [markdown]
# #### (3.2.5) definicion de variable "y" (asignacion horario-profesor)
#
# $$ y_{pb} = \sum_m{u_{mb}·w_{mp}} $$
#
# $$ y_{pb} = \text{OR}_m \{u_{mb}·w_{mp}\} $$
#
#     para todo p, b

# %%
def constr_definir_y(model, y_dict, u_dict, w_dict):

    for p in profesores:
        uw_vars = {} # variable auxiliar = u_mb·w_mp
        mats_p = materias_profesor(p, materias)
        for m in mats_p:
            # for b_id in bloques_horario_materia(m, bloques_horario):
            for b_id in bloques_horario_ids:
                uw_vars[m.id,b_id] = model.addVar(vtype=GRB.INTEGER, name=str(m)+str(b_id)+str(p)+"_uw")
                model.addConstr(uw_vars[m.id,b_id] == u_dict[m.id,b_id].variable * w_dict[m.id,p.id].variable)
        
        mats_p_ids = [m.id for m in mats_p]
        model.addConstrs(y_dict[p.id,b_id].variable ==
                     gp.or_(uw_vars[m_id,b_id] for m_id in mats_p_ids)
                     for b_id in bloques_horario_ids)
    
    # model.addConstrs(y_dict[p, b].variable ==
    #              gp.quicksum(u_dict[m,b].variable * w_dict[m,p].variable for m in materias_ids)
    #              for b in bloques_horario_ids for p in profesores_ids)

# %% [markdown]
# #### (3.2.6) definicion de variable "z" (para dias con clase por profesor)
#
# $$ z_{pd} = OR_h{y_{p(dh)}} $$
#
#     para todo p, d

# %%
def constr_definir_z(model, z_dict, y_dict):
    
    model.addConstrs(z_dict[p,d].variable ==
                gp.or_(y_dict[p,(d,h)].variable for h in horarios_ids)
                for p in profesores_ids for d in dias_ids)

# %% [markdown]
# ### (3.3) Restricciones externas

# %% [markdown]
# #### (3.3.1) cantidad de salones
#
# $$ \sum_{m} {u_{mb}} \leq K $$
#
#     para todo b

# %%
def constr_cantidad_salones(model, u_dict, num_salones):
    model.addConstrs(gp.quicksum(u_dict[m, b].variable for m in materias_ids) <= num_salones for b in bloques_horario_ids)

# %% [markdown]
# #### (3.3.2) restricciones ad hoc

# %% [markdown]
# #### (3.3.3) practico despues del teorico
#
# $$ \max_b\{(-b)*u_{mb}\} > \max_b\{(-b)*u_{m'b}\} $$
#
#     para todo par (teorico, practico) =  (m, m')

# %%
def constr_teo_prac(model, u_dict):

    """
    Variables:
        teo (list): Array containing IDs of theoretical subjects.
        prac (list): Array containing IDs of practical subjects.
        vars1erHora (dict): Dictionary mapping subject IDs to Gurobi integer variables representing the first hour.
        scaled_u_dict (dict): Dictionary mapping tuples of subject IDs and block IDs to scaled Gurobi integer variables.

    Functions:
        search_materias_by_nombre(materias, nombre): Searches for subjects by name in the given list of subjects.

    Workflow:
    1. Populate `teo` and `vars1erHora` with IDs and variables for theoretical subjects.
    2. Populate `prac` and `vars1erHora` with IDs and variables for practical subjects.
    3. Create scaled variables `scaled_u_dict` for each subject and block combination.
    4. Add constraints to the model to ensure that `vars1erHora` variables are the maximum of the scaled variables.
    5. Add constraints to ensure that the first hour of theoretical subjects is greater than or equal to the first hour of practical subjects if the lengths of `teo` and `prac` are equal.


    """
    teo = []    # array con IDS de materias de teorico
    prac = []    # array con IDS de materias de practico
    vars1erHora = {}
    scaled_u_dict = {}

    for t in [m for m in materias if m.teo_prac == "teo"]:
        teo.append(t.id)
        vars1erHora[t.id] = model.addVar(vtype=GRB.INTEGER, name=str(t)+"_1er_hora")

    for p in [m for m in materias if m.teo_prac == "prac"]:
        prac.append(p.id)
        vars1erHora[p.id] = model.addVar(vtype=GRB.INTEGER, name=str(p)+"_1er_hora")

    L = len(bloques_horario_ids)

    for m in teo + prac:
        for b in range(0, L):
            scaled_u_dict[m, bloques_horario_ids[b]] = model.addVar(vtype=GRB.INTEGER, name=str(m)+"scaled_u")
            model.addConstr(scaled_u_dict[m, bloques_horario_ids[b]] == (L - b) * u_dict[m, bloques_horario_ids[b]].variable)

    for m_id in vars1erHora:
        model.addConstr(vars1erHora[m_id] ==
                        # gp.max_( (L - b) * u_dict[m_id, bloques_horario_ids[b]].variable
                        gp.max_( scaled_u_dict[m_id, bloques_horario_ids[b]]
                                for b in range(0, L)) )


    if len(teo) == len(prac):
        model.addConstrs(vars1erHora[teo[m]] >= vars1erHora[prac[m]] for m in range(0, len(teo)))
    else:
        print("Error: no coinciden cantidad de teoricos con practicos")

# %% [markdown]
# #### (3.3.4) Limitar horas excepcionales
#
# $$ \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} \leq E$$

# %%
def constr_horarios_excepcionales(model, u_dict, E_teo, E_prac):

    suma_horas_prac = gp.LinExpr()
    suma_horas_teo = gp.LinExpr()
    
    for m in materias:
        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos())) > 0:
                if m.teo_prac == "prac":
                    suma_horas_prac += u_dict[m.id, b.id].variable
                else:
                    suma_horas_teo += u_dict[m.id, b.id].variable
    
    model.addConstr(suma_horas_prac <= E_prac, "horas_excepcionales_prac")
    model.addConstr(suma_horas_teo <= E_teo, "horas_excepcionales_teo")

# %% [markdown]
# ### (3.4) Grupos

# %% [markdown]
# #### (3.4.1) definicion de variable "x"
#
# $$ x_{gb} = \sum_{m \in M_g} {u_{mb}} $$
#
# $$ x_{gb} = OR_{m \in M_g} {u_{mb}} $$

# %%
def constr_definir_x(model, x_dict, u_dict):

    # SUMA
    # for g in grupos:
    #     gr_mats_ids = [m.id for m in materias_grupo(g, materias)]
    #     model.addConstrs(x_dict[g.id, b].variable == gp.quicksum(u_dict[m, b].variable for m in gr_mats_ids) for b in bloques_horario_ids)

    # OR
    for g in grupos:
        # gr_mats_ids = [m.id for m in materias_grupo(g, materias)]
        gr_mats_ids = [m.id for m in materias_grupo(g, [m for m in materias if not m.electiva])] # filtrar materias electivas
        model.addConstrs(x_dict[g.id, b].variable == gp.or_(u_dict[m, b].variable for m in gr_mats_ids) for b in bloques_horario_ids)

# %% [markdown]
# #### (3.4.2) evitar horas puente por grupo
#
# $$ \sum_h {x_{gdh}} - \sum_h {x_{gd(h)} · x_{gd(h+1)}} \leq 1 $$
#     para todo g, d

# %%
def constr_horas_puente_grupos(model, x_dict):

    for g in grupos:
        model.addConstrs(gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
                    - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
                    <= 1 for d in dias_ids)

# %% [markdown]
# ## (4) Funcion Objetivo

# %% [markdown]
# ### (4.1) Prioridad horaria de los docentes
#
# $$ \min: \sum_{m,b,p} {A_{pb}·w_{mp}·u_{mb}} $$

# %%
def obj_prioridades(u_dict, w_dict):

    OBJ1 = gp.QuadExpr()
    """
    This script constructs a quadratic expression for an optimization problem using Gurobi's QuadExpr.
    Variables:
        OBJ1 (gp.QuadExpr): A quadratic expression object to accumulate the terms.
        count (int): A counter to keep track of the number of terms added to the quadratic expression.
    Loops:
        The script iterates over all combinations of 'materias' and 'profesores'. For each professor, it further iterates over their 'prioridades'.
    Inner Loop:
        For each priority 'pr' of a professor:
            - 'b' is assigned the 'bloque_horario' of the priority.
            - 'A' is assigned the 'value' of the priority.
            - The quadratic expression 'OBJ1' is updated by adding the product of 'A', the variable corresponding to the combination of 'materia' and 'profesor' from 'w_dict', and the variable corresponding to the combination of 'materia' and 'bloque_horario' from 'u_dict'.
            - The counter 'count' is incremented.
    Final Step:
        The constructed quadratic expression 'OBJ1' is added to the main objective 'OBJ'.
    Output:
        The total count of terms added to the quadratic expression is printed.
    """

    count = 0
    for m in materias:
        for p in profesores:
            for pr in p.prioridades:
                b = pr.bloque_horario
                A = pr.value
                OBJ1 += A * w_dict[m.id, p.id].variable * u_dict[m.id, b.id].variable
                count += 1


    print("obj_prioridades terms:", count)

    return OBJ1

# %% [markdown]
# ### (4.2) Minimizar/Maximizar dias con clase por profesor
# $$ \min: \sum_{p,d} {\alpha_p} {z_{pd}}$$
# donde $\alpha_p = 1$ si se minimiza, $\alpha_p = -1$ si se maximiza y $\alpha_p = 0$ si es irrelevante

# %%
def obj_min_max_dias(z_dict):

    OBJ2 = gp.LinExpr()
    DP = {}

    count = 0
    for p in profesores:
        
        D_p = gp.quicksum(z_dict[p.id,d].variable for d in dias_ids)
        DP[p.id] = D_p

        # filtrar si el profesor prefiere minimizar o maximizar o ninguno
        match p.min_max_dias:
            case "min":
                OBJ2 += D_p
                count += len(dias_ids)
            case "max":
                OBJ2 -= D_p
                count += len(dias_ids)
            case None:
                pass

    print("obj_min_max_dias terms:", count)

    return OBJ2, DP

# %% [markdown]
# ### (4.3) Minimizar horas puente por grupo (se incluye directamente como restriccion)
#
# $$ \min: -\sum_{g,d,h} {x_{gd(h)}·x_{gd(h+1)}} $$

# %%
def obj_horas_puente_grupos(x_dict):
    OBJ3 = gp.QuadExpr()

    count = 0
    for g in grupos:
        for d in dias_ids:
            OBJ3 += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
            count += 1

    print("obj_horas_puente_grupos terms:", count)

    return OBJ3

# %% [markdown]
# ### (4.4) Minimizar superposicion de electivas
#
# $$ \min:  \sum_{b} \sum_{m, m'}{u_{mb} \times SE_{m,m'} \times u_{m'b}} = 0 $$
#
# para todo par (m, m') de electivas

# %%
def obj_superposicion_electivas(u_dict):
    OBJ4 = gp.QuadExpr()

    count = 0
    for m1 in electivas(materias):
        for m2 in electivas(materias):
            for b in bloques_horario_ids:
                OBJ4 += u_dict[m1.id, b].variable * superposicion_electivas[m1.id, m2.id].value * u_dict[m2.id, b].variable
                count += 1

    print("obj_superposicion_electivas terms:", count)

    return OBJ4

# %% [markdown]
# ### (4.5) Evitar horas excepcionales
#
# $$ \min: \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} $$

# %%
def obj_horarios_excepcionales(u_dict, prac=False):

    objetivo = gp.QuadExpr()

    count = 0
    for m in materias:

        if (not prac and m.teo_prac == "prac") or (prac and m.teo_prac != "prac"):
            continue

        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos()))>0:
                objetivo += u_dict[m.id, b.id].variable
                count += 1
        
    print("obj_horarios_excepcionales terms:", count)

    return objetivo

# %% [markdown]
# Guardar instancia en formato json

# %%
# generate_instance_json("../instances/instance_2025sem2.json", materias, grupos, profesores, dias, horarios, turnos, superposicion, superposicion_electivas, num_salones)

# %% [markdown]
# # Resolver

# %% [markdown]
# ## Compilar modelo

# %%
# Create a new model
model: gp.Model = gp.Model("timetable")
# Out:
# Set parameter ServerTimeout to value 30
# Set parameter TokenServer to value "10.4.0.1"

# %%
# variables
u_dict, v_dict, w_dict, x_dict, y_dict, z_dict = initialize_variables(materias, bloques_horario, dias, profesores, grupos)
create_variables(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)
# Out:
# u:  10160
# v:  635
# w:  12065
# x:  2160
# y:  7600
# z:  475

# %% [markdown]
# ### Seleccionar restricciones

# %%
constr_superposicion(model, u_dict)
constr_carga_horaria(model, u_dict)
constr_dias_materia(model, v_dict)
constr_max_min_horas(model, u_dict, v_dict)

# %%
constr_turnos_materia(model, u_dict)
constr_horas_consecutivas(model, u_dict, v_dict)
constr_dias_consecutivos(model, v_dict)
constr_horarios_excepcionales(model, u_dict, 7, 1)   # (opcional) limitar cantidad de horas excepcionales

# %%
# constr_no_disponible_profesor(model, u_dict, w_dict)
constr_unica_materia_profesor(model, u_dict, w_dict)
constr_limitar_profesores_materia(model, w_dict)
constr_cantidad_profesores(model, w_dict)
constr_grupos_max_profesor(model, w_dict)

# %%
constr_definir_y(model, y_dict, u_dict, w_dict)
constr_definir_z(model, z_dict, y_dict)

# %%
constr_cantidad_salones(model, u_dict, num_salones)
constr_teo_prac(model, u_dict)

# %%
constr_definir_x(model, x_dict, u_dict)
constr_horas_puente_grupos(model, x_dict)

# %% [markdown]
# ### Funcion objetivo

# %%
# funcion objetivo

objectives = { # name : (expr, weight)
    
    "prioridades" : (obj_prioridades(u_dict, w_dict), 0), # weight = 1
    "min_max_dias" : (obj_min_max_dias(z_dict)[0], 0), # weight = 5
    "superposicion_electivas" : (obj_superposicion_electivas(u_dict), 0), # weight = 10
    "horarios_excepcionales (practico)" : (obj_horarios_excepcionales(u_dict, prac=True), 0), # weight = 50
    "horarios_excepcionales" : (obj_horarios_excepcionales(u_dict, prac=False), 1), # weight = 100

}

OBJ = gp.QuadExpr()
for name in objectives:
    expr, weight = objectives[name]
    OBJ += weight * expr

model.setObjective(OBJ, GRB.MINIMIZE)
# Out:
# obj_prioridades terms: 364109
# obj_min_max_dias terms: 140
# obj_superposicion_electivas terms: 32000
# obj_horarios_excepcionales terms: 95
# obj_horarios_excepcionales terms: 750

# %% [markdown]
# ## Optimizar

# %%
model.setParam("TimeLimit", 2*60)
# model.setParam('OutputFlag', 1)
model.Params.MIPGap = 0.01/100
# model.Params.PoolSolutions = 10 # Number of solutions to find
# model.Params.PoolSearchMode = 0 # 0, 1, 2

model.optimize()

# nSolutions = model.SolCount
# print(f"Number of solutions found: {nSolutions}")
# Out:
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 22063 rows, 51927 columns and 78479 nonzeros
# Model fingerprint: 0x0c03b63e
# Model has 24770 quadratic constraints
# Model has 10267 general constraints
# Variable types: 0 continuous, 51927 integer (33095 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [1e+00, 2e+00]
# Presolve added 5648 rows and 0 columns
# Presolve removed 0 rows and 38599 columns
# Presolve time: 0.78s
# Presolved: 58426 rows, 21773 columns, 158124 nonzeros
# Variable types: 0 continuous, 21773 integer (21206 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    15294    7.0000000e+00   7.309734e+00   4.168838e+08      5s
#    18443    1.0000000e+00   0.000000e+00   0.000000e+00      6s
# Concurrent spin time: 0.44s (can be avoided by choosing Method=3)
#
# Solved with primal simplex
#    18443    1.0000000e+00   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 1.000000e+00, 18443 iterations, 4.00 seconds (1.01 work units)
# Total elapsed time = 6.87s (DegenMoves)
# Total elapsed time = 10.21s (DegenMoves)
# Total elapsed time = 16.13s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00000    0 1884          -    1.00000      -     -   19s
#      0     0    1.00000    0 2058          -    1.00000      -     -   21s
#      0     0    1.00000    0 1983          -    1.00000      -     -   21s
#      0     0    1.00000    0 1983          -    1.00000      -     -   21s
#      0     0    1.00000    0 2699          -    1.00000      -     -   28s
#      0     0    1.00000    0 2619          -    1.00000      -     -   29s
#      0     0    1.00000    0 2619          -    1.00000      -     -   29s
#      0     0    1.00000    0 2923          -    1.00000      -     -   37s
#      0     0    1.00000    0 2903          -    1.00000      -     -   37s
#      0     0    1.00000    0  985          -    1.00000      -     -   59s
#      0     0    1.00000    0 1018          -    1.00000      -     -   61s
#      0     0    1.00000    0  333          -    1.00000      -     -   69s
#      0     0    1.00000    0  602          -    1.00000      -     -   70s
#      0     0    1.00000    0  574          -    1.00000      -     -   71s
#      0     0    1.00000    0  272          -    1.00000      -     -   73s
#      0     0    1.00000    0  257          -    1.00000      -     -   74s
#      0     0    1.00000    0  244          -    1.00000      -     -   75s
#      0     0    1.00000    0  364          -    1.00000      -     -   76s
#      0     0    1.00000    0  134          -    1.00000      -     -   77s
#      0     0    1.00000    0  155          -    1.00000      -     -   77s
# H    0     0                       3.0000000    1.00000  66.7%     -   81s
#      0     0    1.00000    0  255    3.00000    1.00000  66.7%     -   81s
#      0     0    1.00000    0  615    3.00000    1.00000  66.7%     -   83s
#      0     0    1.00000    0  333    3.00000    1.00000  66.7%     -   86s
#      0     0    1.00000    0  238    3.00000    1.00000  66.7%     -   90s
#      0     2    1.00000    0  179    3.00000    1.00000  66.7%     -   95s
#     31    34    1.00000    7  159    3.00000    1.00000  66.7%   726  100s
#     86   110    1.00000   14  156    3.00000    1.00000  66.7%   383  105s
#    194   223    1.00000   26  221    3.00000    1.00000  66.7%   224  113s
#    304   284    1.33333   35  104    3.00000    1.00000  66.7%   170  118s
#    414   312    2.00000   42  533    3.00000    1.00000  66.7%   166  120s
#
# Cutting planes:
#   Learned: 14
#   Gomory: 21
#   Lift-and-project: 1
#   Cover: 118
#   Implied bound: 354
#   Clique: 198
#   MIR: 48
#   StrongCG: 3
#   Flow cover: 15
#   Zero half: 146
#   RLT: 778
#   Relax-and-lift: 101
#   BQP: 50
#   PSD: 1
#
# Explored 448 nodes (271428 simplex iterations) in 120.27 seconds (37.47 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 3
#
# Time limit reached
# Best objective 3.000000000000e+00, best bound 1.000000000000e+00, gap 66.6667%

# %% [markdown]
# ### Analizar no-factibilidad

# %%
# if model.Status == GRB.INFEASIBLE:
#     model.computeIIS()
#     model.write('iismodel.ilp')

#     # Print out the IIS constraints and variables
#     print('\nThe following constraints and variables are in the IIS:')
#     for c in model.getConstrs():
#         if c.IISConstr: print(f'\t{c.constrname}: {model.getRow(c)} {c.Sense} {c.RHS}')

#     for v in model.getVars():
#         if v.IISLB: print(f'\t{v.varname} ≥ {v.LB}')
#         if v.IISUB: print(f'\t{v.varname} ≤ {v.UB}')

# %% [markdown]
# ## Imprimir horarios

# %%
model.setParam("SolutionNumber", 0)
model.update()


if not model.Status == GRB.INFEASIBLE:
    print('Obj: %g' % model.ObjVal)
    for name in objectives:
        expr, weight = objectives[name]
        print(f"\t{name}: \t{" "*(35-len(name))}{round(expr.getValue())} \t(peso={weight})")
    print('=============================================================')
    
    print_timetable(dias, horarios, u_dict, w_dict, grupos, anios)

    save_solution_json(u_dict, v_dict, w_dict, "../results/solution.json")
# Out:
# Obj: 3
# 	prioridades: 	                        481 	(peso=0)
# 	min_max_dias: 	                       63 	(peso=0)
# 	superposicion_electivas: 	            190 	(peso=0)
# 	horarios_excepcionales (practico): 	  1 	(peso=0)
# 	horarios_excepcionales: 	             3 	(peso=1)
# =============================================================
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  1
#
#  Grupo:  10
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		20		68		10		13		68
# 1_start-1_end		20		68		10		13		68
# 2_start-2_end		37		13		10		13		62
# 3_start-3_end		37		13		20		37		62
# 4_start-4_end		10		59		20		37		14/59
# 5_start-5_end		10		59		20		37		14/59
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  11
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		13		37		13		14		37
# 1_start-1_end		13		37		13		14		37
# 2_start-2_end		13		37		68		10		68
# 3_start-3_end		20		10		68		10		68
# 4_start-4_end		20		10/59		62		20		59
# 5_start-5_end		20		10/59		62		20		59
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  12
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		68		37		10		20		68
# 1_start-1_end		68		37		10		20		68
# 2_start-2_end		13		20		10		20		62
# 3_start-3_end		13		20		13		37		62
# 4_start-4_end		10		59		13		37		14/59
# 5_start-5_end		10		59		13		37		14/59
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  13
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		---		50		27		46		55
# 8_start-8_end		46		50		27		46		55
# 9_start-9_end		46		---		---		46		48
# 10_start-10_end		---		---		---		---		48
# 11_start-11_end *		---		---		---		---		---
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  14
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		---		50		---		27		55
# 8_start-8_end		46		50		---		27		55
# 9_start-9_end		46		---		46		48		---
# 10_start-10_end		46		---		46		48		---
# 11_start-11_end *		---		---		---		---		---
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  15
# 			1		2		3		4		5
# ··········································································································
# 10_start-10_end *		---		---		67		---		---
# 11_start-11_end		67		68		67		58		68
# 12_start-12_end		67		68		67		58		68
# 13_start-13_end		67		31		22		58		22
# 14_start-14_end		---		31		22		31		22
# 15_start-15_end		---		31		22		31		22
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  2
#
#  Grupo:  26
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		2		6		28		7		4
# 1_start-1_end		2		6		28		7		4
# 2_start-2_end		28		6		2		7		6
# 3_start-3_end		28		43		2		7		6
# 4_start-4_end		4		43		2		7		6
# 5_start-5_end		4		43		11		7		43
# 6_start-6_end *		---		---		11		---		43
#
#  Grupo:  27
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		2		6		28		9		4
# 1_start-1_end		2		6		28		9		4
# 2_start-2_end		28		6		2		54		6
# 3_start-3_end		28		9		2		54		6
# 4_start-4_end		4		9		2		54		6
# 5_start-5_end		4		---		11		---		---
# 6_start-6_end *		---		---		11		---		---
#
#  Grupo:  28
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		29		28		23		73		28
# 1_start-1_end		29		28		23		73		28
# 2_start-2_end		29		73		23		4		11
# 3_start-3_end		23		73		29		4		11
# 4_start-4_end		23		4		29		76		42
# 5_start-5_end		23		4		---		76		42
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  29
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		73		29		---		4		11
# 1_start-1_end		73		29		---		4		11
# 2_start-2_end		76		29		45		29		28
# 3_start-3_end		76		4		45		29		28
# 4_start-4_end		28		4		73		42		45
# 5_start-5_end		28		---		73		42		45
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  210
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		29		28		---		73		28
# 1_start-1_end		29		28		45		73		28
# 2_start-2_end		29		73		45		4		11
# 3_start-3_end		45		73		29		4		11
# 4_start-4_end		45		4		29		76		42
# 5_start-5_end		---		4		---		76		42
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  211
# 			1		2		3		4		5
# ··········································································································
# 10_start-10_end *		---		---		---		---		---
# 11_start-11_end		---		33		63		72		71
# 12_start-12_end		72		33		63		72		71
# 13_start-13_end		72		71		63		72		52
# 14_start-14_end		63		71		52		33		52
# 15_start-15_end		63		71		52		33		---
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  3
#
#  Grupo:  312
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		30		19		64		---		64
# 1_start-1_end		30		19		64		51		64
# 2_start-2_end		51		8		19		51		64
# 3_start-3_end		51		8		19		58		8
# 4_start-4_end		39		39		30		58		8
# 5_start-5_end		39		39		30		58		8
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  313
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		30		56		---		---		16
# 1_start-1_end		30		56		25		51		16
# 2_start-2_end		51		56		25		51		16
# 3_start-3_end		51		25		25		58		56
# 4_start-4_end		16		25		30		58		56
# 5_start-5_end		16		25		30		58		56
# 6_start-6_end *		16		---		---		---		---
#
#  Grupo:  314
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		70		58		70		70
# 1_start-1_end		18		70		58		70		70
# 2_start-2_end		18		51		58		30		51
# 3_start-3_end		57		51		57		30		51
# 4_start-4_end		57		18		57		---		30
# 5_start-5_end		---		18		57		---		30
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  315
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		51		26		---		51		65
# 1_start-1_end		51		26		---		51		65
# 2_start-2_end		26		18		3		18		58
# 3_start-3_end		26		18		3		18		58
# 4_start-4_end		30		30		3		---		58
# 5_start-5_end		30		30		---		---		---
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  316
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		26		58		---		65
# 1_start-1_end		18		26		58		---		65
# 2_start-2_end		18		51		58		30		51
# 3_start-3_end		3		51		26		30		51
# 4_start-4_end		3		18		26		---		30
# 5_start-5_end		3		18		---		---		30
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  317
# 			1		2		3		4		5
# ··········································································································
# 10_start-10_end *		---		---		---		---		---
# 11_start-11_end		---		---		---		41		61/41
# 12_start-12_end		---		---		---		53/53/41		61/41
# 13_start-13_end		0/49/35/61		---		---		53/53		0/49/35
# 14_start-14_end		0/49/35/61		---		---		---		0/49/35
# 15_start-15_end		---		---		---		---		---
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  4
#
#  Grupo:  418
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		1/5/44		69/5/17/78		47		---		---
# 10_start-10_end		69/1/5/44		69/5/44/17/78		47		47		21
# 11_start-11_end		69		44/17/78		---		47/1		21
# 12_start-12_end		---		---		---		21/47/53/53/1		38
# 13_start-13_end		0/49/35		---		78		21/53/53		0/49/35/38
# 14_start-14_end		0/49/35		---		78		---		0/49/35/38
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  419
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		5/44		5/17/78		47		---		---
# 10_start-10_end		5/44		5/44/17/78		47		47		21
# 11_start-11_end		---		44/17/78		---		47		21
# 12_start-12_end		---		---		---		21/47/53/53		75/38
# 13_start-13_end		0/49/35		---		78		21/53/53		0/49/35/75/38
# 14_start-14_end		0/49/35		---		78		---		0/49/35/75/38
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  420
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		44		17/78		47		---		34
# 10_start-10_end		44/34		44/17/78		47		47		21/34
# 11_start-11_end		34		44/17/78		---		47/41		21/61/41
# 12_start-12_end		---		---		---		21/47/53/53/41		38/61/41
# 13_start-13_end		0/49/35/61		---		78		21/53/53		0/49/35/38
# 14_start-14_end		0/49/35/61		---		78		---		0/49/35/38
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  421
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		44		17/78		47		---		34
# 10_start-10_end		44/34		44/17/78		47		47		21/34
# 11_start-11_end		34		44/17/78		---		47/41		21/61/41
# 12_start-12_end		---		---		---		21/47/53/53/41		38/61/41
# 13_start-13_end		0/49/35/61		---		78		21/53/53		0/49/35/38
# 14_start-14_end		0/49/35/61		---		78		---		0/49/35/38
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  422
# 			1		2		3		4		5
# ··········································································································
# 10_start-10_end *		---		---		---		---		---
# 11_start-11_end		---		74		32		40		---
# 12_start-12_end		40		74		32		40		32/32
# 13_start-13_end		40		45		32		45		32/32
# 14_start-14_end		15		45		32		45		15
# 15_start-15_end		15		---		---		77		15
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  5
#
#  Grupo:  523
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		1		60/69		---		---		32
# 10_start-10_end		69/1		60/69		---		---		32
# 11_start-11_end		69		60		24		1		---
# 12_start-12_end		---		36		24		1		---
# 13_start-13_end		24		36		32		36		60
# 14_start-14_end		24		---		32		36		60
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  524
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		---		60/12		---		---		32
# 10_start-10_end		---		60/12		---		---		32
# 11_start-11_end		---		60/12		24		---		---
# 12_start-12_end		---		36		24		---		75
# 13_start-13_end		24		36		32		36		60/75
# 14_start-14_end		24		---		32		36		60/75
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  525
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		---		60		---		---		---
# 10_start-10_end		32		60		---		---		---
# 11_start-11_end		32		60		---		32		36
# 12_start-12_end		36		24		---		32		36
# 13_start-13_end		36		24		---		24		60
# 14_start-14_end		---		---		---		24		60
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  526
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		---		60		---		---		66
# 10_start-10_end		32		60		---		---		66
# 11_start-11_end		32		60		---		32		36
# 12_start-12_end		36		24		---		32		36
# 13_start-13_end		36		24		66		24		60
# 14_start-14_end		---		---		66		24		60
# 15_start-15_end *		---		---		---		---		---

# %%
if not model.Status == GRB.INFEASIBLE:
    print_prof_timetable_excel(dias, horarios, u_dict, w_dict, profesores, materias)
# Out:
#  Profesor:  1 1
# 	1	2	3	4	5
# 0_start-0_end	---	6	---	---	---
# 1_start-1_end	---	6	---	---	---
# 2_start-2_end	---	6	---	---	6
# 3_start-3_end	---	---	---	---	6
# 4_start-4_end	---	---	---	---	6
#
#  Profesor:  3 3
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	65
# 1_start-1_end	---	---	---	---	65
# 2_start-2_end	---	---	3	---	---
# 3_start-3_end	---	---	3	---	---
# 4_start-4_end	---	---	3	---	---
#
#  Profesor:  4 4
# 	1	2	3	4	5
# 4_start-4_end	---	59	---	---	59
# 5_start-5_end	---	59	---	---	59
#
#  Profesor:  6 6
# 	1	2	3	4	5
# 11_start-11_end	---	---	24	---	---
# 12_start-12_end	---	24	24	---	---
# 13_start-13_end	24	24	---	24	---
# 14_start-14_end	24	---	---	24	---
#
#  Profesor:  7 7
# 	1	2	3	4	5
# 2_start-2_end	37	---	---	---	---
# 3_start-3_end	37	---	---	37	---
# 4_start-4_end	---	---	---	37	---
# 5_start-5_end	---	---	---	37	---
# 7_start-7_end	---	---	---	46	---
# 8_start-8_end	46	---	---	46	---
# 9_start-9_end	46	---	---	46	---
#
#  Profesor:  8 8
# 	1	2	3	4	5
# 13_start-13_end	---	---	22	---	22
# 14_start-14_end	---	---	22	---	22
# 15_start-15_end	---	---	22	---	22
#
#  Profesor:  10 10
# 	1	2	3	4	5
# 0_start-0_end	---	68	---	---	68
# 1_start-1_end	---	68	---	---	68
# 2_start-2_end	---	---	68	---	68
# 3_start-3_end	---	---	68	---	68
#
#  Profesor:  11 11
# 	1	2	3	4	5
# 0_start-0_end	68	---	---	---	68
# 1_start-1_end	68	---	---	---	68
#
#  Profesor:  12 12
# 	1	2	3	4	5
# 11_start-11_end	---	68	---	---	68
# 12_start-12_end	---	68	---	---	68
#
#  Profesor:  13 13
# 	1	2	3	4	5
# 11_start-11_end	---	33	---	---	---
# 12_start-12_end	---	33	---	---	---
# 14_start-14_end	---	---	---	33	---
# 15_start-15_end	---	---	---	33	---
#
#  Profesor:  14 14
# 	1	2	3	4	5
# 9_start-9_end	---	17	---	---	---
# 10_start-10_end	---	17	---	---	---
# 11_start-11_end	---	17	---	---	---
#
#  Profesor:  15 15
# 	1	2	3	4	5
# 3_start-3_end	---	43	---	---	---
# 4_start-4_end	---	43	---	---	---
# 5_start-5_end	---	43	---	---	43
# 6_start-6_end	---	---	---	---	43
#
#  Profesor:  16 16
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	---	21
# 11_start-11_end	---	---	---	---	21
# 12_start-12_end	---	---	---	21	---
# 13_start-13_end	---	---	---	21	---
#
#  Profesor:  17 17
# 	1	2	3	4	5
# 0_start-0_end	2	---	---	---	---
# 1_start-1_end	2	---	---	---	---
# 2_start-2_end	---	---	2	---	---
# 3_start-3_end	---	---	2	---	---
# 4_start-4_end	---	---	2	---	---
#
#  Profesor:  18 18
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	72	---
# 12_start-12_end	72	---	---	72	---
# 13_start-13_end	72	---	---	72	---
#
#  Profesor:  19 19
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	4	---
# 1_start-1_end	---	---	---	4	---
# 3_start-3_end	---	4	---	---	---
# 4_start-4_end	---	4	---	---	---
#
#  Profesor:  20 20
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	---	36
# 12_start-12_end	36	36	---	---	36
# 13_start-13_end	36	36	---	36	---
# 14_start-14_end	---	---	---	36	---
#
#  Profesor:  21 21
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	---	61
# 12_start-12_end	---	---	---	---	61
# 13_start-13_end	61	---	---	---	---
# 14_start-14_end	61	---	---	---	---
#
#  Profesor:  22 22
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	58	---
# 4_start-4_end	---	---	---	58	---
# 5_start-5_end	---	---	---	58	---
#
#  Profesor:  23 23
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	---	66
# 10_start-10_end	---	---	---	---	66
# 13_start-13_end	---	---	66	---	---
# 14_start-14_end	---	---	66	---	---
#
#  Profesor:  24 24
# 	1	2	3	4	5
# 2_start-2_end	---	18	45	18	---
# 3_start-3_end	---	18	45	18	---
# 4_start-4_end	---	---	---	---	45
# 5_start-5_end	---	---	---	---	45
# 13_start-13_end	49	---	---	---	49
# 14_start-14_end	49	---	---	---	49
#
#  Profesor:  25 25
# 	1	2	3	4	5
# 0_start-0_end	---	56	---	---	---
# 1_start-1_end	---	56	---	---	---
# 2_start-2_end	---	56	---	---	---
# 3_start-3_end	---	---	---	---	56
# 4_start-4_end	---	---	---	---	56
# 5_start-5_end	---	---	---	---	56
#
#  Profesor:  26 26
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	32
# 13_start-13_end	---	---	32	---	32
# 14_start-14_end	---	---	32	---	---
#
#  Profesor:  27 27
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	11
# 1_start-1_end	---	---	---	---	11
# 2_start-2_end	---	---	---	---	11
# 3_start-3_end	---	---	---	---	11
# 5_start-5_end	---	---	11	---	---
# 6_start-6_end	---	---	11	---	---
# 10_start-10_end	---	---	67	---	---
# 11_start-11_end	67	---	67	---	---
# 12_start-12_end	67	---	67	---	---
# 13_start-13_end	67	---	---	---	---
#
#  Profesor:  28 28
# 	1	2	3	4	5
# 0_start-0_end	30	---	---	13	---
# 1_start-1_end	30	---	---	13	---
# 2_start-2_end	---	13	---	13	---
# 3_start-3_end	---	13	---	---	---
# 4_start-4_end	---	---	30	---	---
# 5_start-5_end	---	---	30	---	---
# 15_start-15_end	---	---	---	77	---
#
#  Profesor:  29 29
# 	1	2	3	4	5
# 0_start-0_end	---	26	---	---	---
# 1_start-1_end	---	26	---	---	---
# 2_start-2_end	26	---	---	---	---
# 3_start-3_end	26	---	---	---	---
#
#  Profesor:  30 30
# 	1	2	3	4	5
# 4_start-4_end	39	39	---	---	---
# 5_start-5_end	39	39	---	---	---
#
#  Profesor:  31 31
# 	1	2	3	4	5
# 2_start-2_end	---	8	---	---	---
# 3_start-3_end	---	8	---	---	8
# 4_start-4_end	---	---	---	---	8
# 5_start-5_end	---	---	---	---	8
# 9_start-9_end	1	---	---	---	---
# 10_start-10_end	1	---	---	---	---
# 11_start-11_end	---	---	---	1	---
# 12_start-12_end	---	---	---	1	---
#
#  Profesor:  32 32
# 	1	2	3	4	5
# 4_start-4_end	30	30	---	---	---
# 5_start-5_end	30	30	---	---	---
#
#  Profesor:  33 33
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	58
# 3_start-3_end	---	---	---	---	58
# 4_start-4_end	---	---	---	---	58
#
#  Profesor:  34 34
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	54	---
# 3_start-3_end	---	---	---	54	---
# 4_start-4_end	---	---	---	54	---
#
#  Profesor:  35 35
# 	1	2	3	4	5
# 9_start-9_end	44	---	---	---	---
# 10_start-10_end	44	44	---	---	---
# 11_start-11_end	---	44	---	---	---
#
#  Profesor:  36 36
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	---	32
# 10_start-10_end	32	---	---	---	32
# 11_start-11_end	32	---	32	32	---
# 12_start-12_end	---	---	32	32	32
# 13_start-13_end	---	---	32	---	32
# 14_start-14_end	---	---	32	---	---
#
#  Profesor:  37 37
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	4	---
# 3_start-3_end	---	---	---	4	---
# 4_start-4_end	---	4	---	---	---
# 5_start-5_end	---	4	---	---	---
#
#  Profesor:  38 38
# 	1	2	3	4	5
# 0_start-0_end	---	37	---	---	37
# 1_start-1_end	---	37	---	---	37
# 2_start-2_end	---	37	---	---	---
# 8_start-8_end	46	---	---	---	---
# 9_start-9_end	46	---	46	---	---
# 10_start-10_end	46	---	46	---	---
#
#  Profesor:  39 39
# 	1	2	3	4	5
# 0_start-0_end	20	70	---	70	70
# 1_start-1_end	20	70	---	70	70
# 3_start-3_end	---	---	20	---	---
# 4_start-4_end	---	---	20	---	---
# 5_start-5_end	---	---	20	---	---
#
#  Profesor:  40 40
# 	1	2	3	4	5
# 0_start-0_end	73	---	---	---	---
# 1_start-1_end	73	---	---	---	---
# 4_start-4_end	---	---	73	---	---
# 5_start-5_end	---	---	73	---	---
#
#  Profesor:  41 41
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	30	---
# 3_start-3_end	---	---	---	30	---
# 4_start-4_end	---	---	---	---	30
# 5_start-5_end	---	---	---	---	30
#
#  Profesor:  42 42
# 	1	2	3	4	5
# 11_start-11_end	---	74	---	---	---
# 12_start-12_end	---	74	---	---	---
# 13_start-13_end	---	45	---	45	---
# 14_start-14_end	---	45	---	45	---
#
#  Profesor:  43 43
# 	1	2	3	4	5
# 0_start-0_end	51	---	---	51	---
# 1_start-1_end	51	---	---	51	---
# 2_start-2_end	51	51	---	51	51
# 3_start-3_end	51	51	---	---	51
#
#  Profesor:  44 44
# 	1	2	3	4	5
# 3_start-3_end	20	---	---	---	---
# 4_start-4_end	20	---	---	20	---
# 5_start-5_end	20	---	---	20	---
#
#  Profesor:  45 45
# 	1	2	3	4	5
# 0_start-0_end	29	29	---	---	---
# 1_start-1_end	29	29	---	---	---
# 2_start-2_end	29	29	---	29	---
# 3_start-3_end	---	---	29	29	---
# 4_start-4_end	---	---	29	---	---
# 11_start-11_end	---	---	---	41	41
# 12_start-12_end	---	---	---	41	41
#
#  Profesor:  46 46
# 	1	2	3	4	5
# 0_start-0_end	13	---	13	---	---
# 1_start-1_end	13	---	13	---	---
# 2_start-2_end	13	---	---	---	---
# 11_start-11_end	---	---	63	---	---
# 12_start-12_end	---	---	63	---	---
# 13_start-13_end	---	---	63	---	---
# 14_start-14_end	63	---	---	---	---
# 15_start-15_end	63	---	---	---	---
#
#  Profesor:  47 47
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	---	71
# 12_start-12_end	---	---	---	---	71
# 13_start-13_end	---	71	---	---	---
# 14_start-14_end	---	71	---	---	---
# 15_start-15_end	---	71	---	---	---
#
#  Profesor:  48 48
# 	1	2	3	4	5
# 0_start-0_end	51	---	---	51	---
# 1_start-1_end	51	---	---	51	---
# 2_start-2_end	51	51	---	51	51
# 3_start-3_end	51	51	---	---	51
#
#  Profesor:  49 49
# 	1	2	3	4	5
# 3_start-3_end	---	---	26	---	---
# 4_start-4_end	---	---	26	---	---
#
#  Profesor:  50 50
# 	1	2	3	4	5
# 0_start-0_end	---	26	---	---	---
# 1_start-1_end	---	26	---	---	---
#
#  Profesor:  51 51
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	75
# 13_start-13_end	---	---	---	---	75
# 14_start-14_end	---	---	---	---	75
#
#  Profesor:  52 52
# 	1	2	3	4	5
# 13_start-13_end	---	31	---	---	---
# 14_start-14_end	---	31	---	31	---
# 15_start-15_end	---	31	---	31	---
#
#  Profesor:  53 53
# 	1	2	3	4	5
# 0_start-0_end	---	37	---	---	---
# 1_start-1_end	---	37	---	---	---
# 2_start-2_end	---	---	---	---	28
# 3_start-3_end	---	---	---	37	28
# 4_start-4_end	28	---	---	37	---
# 5_start-5_end	28	---	---	37	---
#
#  Profesor:  54 54
# 	1	2	3	4	5
# 1_start-1_end	18	---	---	---	---
# 2_start-2_end	18	---	---	---	---
# 4_start-4_end	---	18	---	---	---
# 5_start-5_end	---	18	---	---	---
#
#  Profesor:  55 55
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	58	---
# 12_start-12_end	---	---	---	58	---
# 13_start-13_end	---	---	---	58	---
#
#  Profesor:  56 56
# 	1	2	3	4	5
# 4_start-4_end	---	---	---	76	42
# 5_start-5_end	---	---	---	76	42
#
#  Profesor:  58 58
# 	1	2	3	4	5
# 0_start-0_end	---	28	---	---	28
# 1_start-1_end	---	28	---	---	28
# 2_start-2_end	---	---	---	10	---
# 3_start-3_end	---	10	---	10	---
# 4_start-4_end	---	10	---	---	14
# 5_start-5_end	---	10	---	---	14
#
#  Profesor:  59 59
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	20	---
# 1_start-1_end	---	---	---	20	---
# 2_start-2_end	---	20	---	20	---
# 3_start-3_end	---	20	---	---	---
#
#  Profesor:  60 60
# 	1	2	3	4	5
# 3_start-3_end	57	---	57	---	---
# 4_start-4_end	57	---	57	---	---
# 5_start-5_end	---	---	57	---	---
#
#  Profesor:  61 61
# 	1	2	3	4	5
# 0_start-0_end	---	---	64	---	64
# 1_start-1_end	---	---	64	---	64
# 2_start-2_end	---	---	---	---	64
#
#  Profesor:  62 62
# 	1	2	3	4	5
# 0_start-0_end	---	---	10	---	---
# 1_start-1_end	---	---	10	---	---
# 2_start-2_end	---	---	10	---	---
# 4_start-4_end	10	---	---	---	---
# 5_start-5_end	10	---	---	---	---
#
#  Profesor:  63 63
# 	1	2	3	4	5
# 0_start-0_end	---	---	23	---	---
# 1_start-1_end	---	---	23	---	---
# 2_start-2_end	---	---	23	---	---
# 3_start-3_end	23	---	---	---	---
# 4_start-4_end	23	---	---	---	---
# 5_start-5_end	23	---	---	---	---
# 12_start-12_end	---	---	---	53	---
# 13_start-13_end	---	---	---	53	---
#
#  Profesor:  64 64
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	75
# 13_start-13_end	---	---	---	---	75
# 14_start-14_end	---	---	---	---	75
#
#  Profesor:  65 65
# 	1	2	3	4	5
# 1_start-1_end	---	---	45	---	---
# 2_start-2_end	---	---	45	---	---
# 3_start-3_end	45	---	---	---	---
# 4_start-4_end	45	---	---	---	---
#
#  Profesor:  66 66
# 	1	2	3	4	5
# 0_start-0_end	---	19	---	---	---
# 1_start-1_end	---	19	---	---	---
# 2_start-2_end	---	---	19	---	---
# 3_start-3_end	---	---	19	---	---
#
#  Profesor:  67 67
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	---	52
# 14_start-14_end	---	---	52	---	52
# 15_start-15_end	---	---	52	---	---
#
#  Profesor:  68 68
# 	1	2	3	4	5
# 9_start-9_end	---	78	---	---	---
# 10_start-10_end	---	78	---	---	---
# 11_start-11_end	---	78	---	---	---
# 13_start-13_end	---	---	78	---	---
# 14_start-14_end	---	---	78	---	---
#
#  Profesor:  69 69
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	14	---
# 1_start-1_end	---	---	---	14	---
# 4_start-4_end	---	---	---	---	14
# 5_start-5_end	---	---	---	---	14
#
#  Profesor:  71 71
# 	1	2	3	4	5
# 14_start-14_end	15	---	---	---	15
# 15_start-15_end	15	---	---	---	15
#
#  Profesor:  72 72
# 	1	2	3	4	5
# 0_start-0_end	29	29	---	---	---
# 1_start-1_end	29	29	---	---	---
# 2_start-2_end	29	29	---	29	---
# 3_start-3_end	---	---	29	29	---
# 4_start-4_end	---	---	29	---	---
#
#  Profesor:  73 73
# 	1	2	3	4	5
# 0_start-0_end	---	---	28	---	---
# 1_start-1_end	---	---	28	---	---
# 2_start-2_end	28	---	---	---	62
# 3_start-3_end	28	---	---	---	62
# 4_start-4_end	---	---	62	---	---
# 5_start-5_end	---	---	62	---	---
#
#  Profesor:  74 74
# 	1	2	3	4	5
# 0_start-0_end	---	---	58	---	---
# 1_start-1_end	---	---	58	---	---
# 2_start-2_end	---	---	58	---	---
# 12_start-12_end	---	---	---	---	38
# 13_start-13_end	---	---	---	---	38
# 14_start-14_end	---	---	---	---	38
#
#  Profesor:  75 75
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	65
# 1_start-1_end	---	---	---	---	65
# 3_start-3_end	3	---	---	---	---
# 4_start-4_end	3	---	---	---	---
# 5_start-5_end	3	---	---	---	---
# 12_start-12_end	---	---	---	53	---
# 13_start-13_end	---	---	---	53	---
#
#  Profesor:  76 76
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	4
# 1_start-1_end	---	---	---	---	4
# 4_start-4_end	4	---	---	---	---
# 5_start-5_end	4	---	---	---	---
#
#  Profesor:  77 77
# 	1	2	3	4	5
# 2_start-2_end	76	---	---	---	---
# 3_start-3_end	76	---	---	---	---
# 4_start-4_end	---	---	---	42	---
# 5_start-5_end	---	---	---	42	---
#
#  Profesor:  78 78
# 	1	2	3	4	5
# 0_start-0_end	---	---	64	---	64
# 1_start-1_end	---	---	64	---	64
# 2_start-2_end	---	---	---	---	64
#
#  Profesor:  79 79
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	16
# 1_start-1_end	---	---	---	---	16
# 2_start-2_end	---	---	---	---	16
# 4_start-4_end	16	---	---	---	---
# 5_start-5_end	16	---	---	---	---
# 6_start-6_end	16	---	---	---	---
#
#  Profesor:  81 81
# 	1	2	3	4	5
# 9_start-9_end	5	5	---	---	---
# 10_start-10_end	5	5	---	---	---
#
#  Profesor:  82 82
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	7	---
# 1_start-1_end	---	---	---	7	---
# 2_start-2_end	---	---	---	7	---
# 3_start-3_end	---	---	---	7	---
# 4_start-4_end	---	---	---	7	---
# 5_start-5_end	---	---	---	7	---
#
#  Profesor:  83 83
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	73	---
# 1_start-1_end	---	---	---	73	---
# 2_start-2_end	---	73	---	---	---
# 3_start-3_end	---	73	---	---	---
#
#  Profesor:  84 84
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	---	34
# 10_start-10_end	34	---	---	---	34
# 11_start-11_end	34	---	---	---	---
#
#  Profesor:  85 85
# 	1	2	3	4	5
# 15_start-15_end	---	---	---	77	---
#
#  Profesor:  86 86
# 	1	2	3	4	5
# 9_start-9_end	---	60	47	---	---
# 10_start-10_end	---	60	47	47	---
# 11_start-11_end	---	60	---	47	---
# 12_start-12_end	---	---	---	47	---
# 13_start-13_end	---	---	---	---	60
# 14_start-14_end	---	---	---	---	60
#
#  Profesor:  87 87
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	62
# 3_start-3_end	---	---	---	---	62
# 9_start-9_end	---	---	---	48	48
# 10_start-10_end	---	---	---	48	48
#
#  Profesor:  88 88
# 	1	2	3	4	5
# 0_start-0_end	29	29	---	---	---
# 1_start-1_end	29	29	---	---	---
# 2_start-2_end	29	29	---	29	---
# 3_start-3_end	---	---	29	29	---
# 4_start-4_end	---	---	29	---	---
#
#  Profesor:  89 89
# 	1	2	3	4	5
# 0_start-0_end	---	19	---	---	---
# 1_start-1_end	---	19	---	---	---
# 2_start-2_end	---	---	19	---	---
# 3_start-3_end	---	---	19	---	---
# 9_start-9_end	---	69	---	---	---
# 10_start-10_end	69	69	---	---	---
# 11_start-11_end	69	---	---	---	---
#
#  Profesor:  90 90
# 	1	2	3	4	5
# 0_start-0_end	---	---	10	---	---
# 1_start-1_end	---	---	10	---	---
# 2_start-2_end	---	---	10	---	---
# 4_start-4_end	10	---	---	---	---
# 5_start-5_end	10	---	---	---	---
# 7_start-7_end	---	---	---	---	55
# 8_start-8_end	---	---	---	---	55
#
#  Profesor:  91 91
# 	1	2	3	4	5
# 2_start-2_end	13	---	---	---	---
# 3_start-3_end	13	---	13	---	---
# 4_start-4_end	---	---	13	---	---
# 5_start-5_end	---	---	13	---	---
# 11_start-11_end	---	---	63	---	---
# 12_start-12_end	---	---	63	---	---
# 13_start-13_end	---	---	63	---	---
# 14_start-14_end	63	---	---	---	---
# 15_start-15_end	63	---	---	---	---
#
#  Profesor:  92 92
# 	1	2	3	4	5
# 1_start-1_end	---	---	25	---	---
# 2_start-2_end	---	---	25	---	---
# 3_start-3_end	---	25	25	---	---
# 4_start-4_end	---	25	---	---	---
# 5_start-5_end	---	25	---	---	---
#
#  Profesor:  93 93
# 	1	2	3	4	5
# 9_start-9_end	---	17	---	---	---
# 10_start-10_end	---	17	---	---	---
# 11_start-11_end	---	17	---	---	---
#
#  Profesor:  94 94
# 	1	2	3	4	5
# 11_start-11_end	---	---	24	---	---
# 12_start-12_end	---	24	24	---	---
# 13_start-13_end	24	24	---	24	---
# 14_start-14_end	24	---	---	24	---
#
#  Profesor:  95 95
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	40	---
# 12_start-12_end	40	---	---	40	---
# 13_start-13_end	40	---	---	---	---

# %% [markdown]
# ## Estadísticas de resultados

# %% [markdown]
# ### Promedios de prioridad

# %%
if not model.Status == GRB.INFEASIBLE and "prioridades" in objectives:
    
    CARGA_HORARIA_TOTAL = np.sum([round(y_dict[p, b].variable.X)
                              for p in profesores_ids
                              for b in bloques_horario_ids
                              ])

    obj = objectives["prioridades"][0].getValue()
    print(obj)
    print("Promedio general de prioridad horaria: ", obj/CARGA_HORARIA_TOTAL)
          

# print("Casos de materias con dias consecutivos: ", int(OBJ2.getValue()/10))
# Out:
# 481.0
# Promedio general de prioridad horaria:  0.9144486692015209

# %%
# promedio por profesor:
"""
This script calculates and prints the average workload per professor based on their assigned priorities and time blocks.
Variables:
    profesores (list): List of professor objects, each containing their priorities.
    y_dict (dict): Dictionary mapping professor IDs and time block IDs to Gurobi variables.
    bloques_horario_ids (list): List of time block IDs.
For each professor in the list `profesores`, the script performs the following steps:
1. Initializes a quadratic expression `OBJ_p` to accumulate the weighted priorities.
2. Iterates over the professor's priorities to update `OBJ_p` based on the priority value and corresponding Gurobi variable.
3. Calculates the total workload `CARGA_HORARIA_p` for the professor by summing the relevant Gurobi variables.
4. If the total workload is non-zero, it prints the professor's name, total workload, and the rounded average priority value per workload unit.
5. If the total workload is zero, it prints the professor's name and indicates that they have no workload.

"""
if not model.Status == GRB.INFEASIBLE:
    for p in profesores:

        OBJ_p = gp.QuadExpr()
        # for m in materias:
        #     for pr in p.prioridades:
        #             b = pr.bloque_horario
        #             A = pr.value
        #             OBJ_p += A * w_dict[m.id, p.id].variable * u_dict[m.id, b.id].variable

        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            OBJ_p += A * y_dict[p.id, b.id].variable
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()
        CARGA_HORARIA_p = round(gp.quicksum(y_dict[p.id, b].variable for b in bloques_horario_ids).getValue())

        if CARGA_HORARIA_p != 0:
            print(str(p), "\t", CARGA_HORARIA_p, "\t", round(round(OBJ_p.getValue())/CARGA_HORARIA_p,3))
        else:
            print(str(p), "sin carga horaria")
# Out:
# 1 	 6 	 0.5
# 2 sin carga horaria
# 3 	 5 	 0.4
# 4 	 4 	 0.0
# 5 sin carga horaria
# 6 	 8 	 0.5
# 7 	 10 	 0.6
# 8 	 6 	 0.667
# 9 sin carga horaria
# 10 	 8 	 1.0
# 11 	 4 	 1.0
# 12 	 4 	 1.0
# 13 	 4 	 2.0
# 14 	 3 	 1.0
# 15 	 5 	 0.0
# 16 	 4 	 0.0
# 17 	 5 	 1.0
# 18 	 5 	 1.0
# 19 	 4 	 0.5
# 20 	 8 	 0.0
# 21 	 4 	 0.75
# 22 	 3 	 1.0
# 23 	 4 	 1.0
# 24 	 12 	 1.167
# 25 	 6 	 0.333
# 26 	 4 	 0.75
# 27 	 12 	 0.667
# 28 	 10 	 0.7
# 29 	 4 	 1.75
# 30 	 4 	 0.0
# 31 	 9 	 1.444
# 32 	 4 	 0.0
# 33 	 3 	 3.0
# 34 	 3 	 2.333
# 35 	 4 	 1.0
# 36 	 12 	 0.75
# 37 	 4 	 0.75
# 38 	 10 	 0.7
# 39 	 11 	 2.455
# 40 	 4 	 2.0
# 41 	 4 	 0.5
# 42 	 6 	 1.333
# 43 	 11 	 0.364
# 44 	 5 	 2.2
# 45 	 14 	 1.357
# 46 	 10 	 1.0
# 47 	 5 	 1.2
# 48 	 11 	 0.364
# 49 	 2 	 1.5
# 50 	 2 	 2.0
# 51 	 3 	 1.0
# 52 	 5 	 1.8
# 53 	 9 	 1.111
# 54 	 4 	 0.25
# 55 	 3 	 1.0
# 56 	 4 	 0.0
# 57 sin carga horaria
# 58 	 11 	 0.727
# 59 	 5 	 0.6
# 60 	 5 	 0.6
# 61 	 5 	 1.0
# 62 	 5 	 2.2
# 63 	 8 	 2.0
# 64 	 3 	 2.0
# 65 	 4 	 1.25
# 66 	 4 	 0.5
# 67 	 4 	 0.0
# 68 	 5 	 1.8
# 69 	 4 	 1.25
# 70 sin carga horaria
# 71 	 4 	 3.0
# 72 	 10 	 1.0
# 73 	 8 	 0.25
# 74 	 6 	 0.5
# 75 	 7 	 0.714
# 76 	 4 	 1.0
# 77 	 4 	 0.75
# 78 	 5 	 1.4
# 79 	 6 	 0.0
# 80 sin carga horaria
# 81 	 4 	 1.0
# 82 	 6 	 0.0
# 83 	 4 	 0.0
# 84 	 4 	 0.5
# 85 	 1 	 0.0
# 86 	 10 	 1.1
# 87 	 6 	 1.333
# 88 	 10 	 1.0
# 89 	 8 	 0.875
# 90 	 7 	 0.571
# 91 	 10 	 0.7
# 92 	 6 	 0.667
# 93 	 3 	 1.0
# 94 	 8 	 0.5
# 95 	 4 	 0.75

# %%
# # DIAS CLASE POR PROFESOR

# print("DIAS CON CLASE")
# for p in profesores:
#     if p.min_max_dias is not None:
#         print(str(p), ": ", round(DP[p.id].getValue()), p.min_max_dias)

# %%
# HORAS PUENTE

# HP = gp.QuadExpr()
# for g in grupos_reales:
#     HPg = gp.QuadExpr()
#     for d in dias_ids:
#         HPg += gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
#         HPg += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
#         HPg += - 1
#     # print("horas puente grupo", str(g), ": ", HPg.getValue())
#     HP += HPg

# print("Total de horas puente: ", HP.getValue())

# %% [markdown]
# #### Distribucion de prioridades

# %%
# distribucion de prioridades
"""
This script calculates and prints the distribution of priorities and their averages for a given set of professors and their time block priorities.
Variables:
    promedios_prioridad (dict): A dictionary to store the average priority values for each priority level.
    valores_prioridad (dict): A dictionary to store the count of each priority level.
    profesores (list): A list of professor objects, each containing their priority information.
    y_dict (dict): A dictionary containing the decision variables for the optimization model.
Process:
1. Initialize dictionaries to store priority averages and counts.
2. Iterate over each professor and their priorities:
    - Skip if the priority value is 0.
    - Increment the count for the given priority value.
    - Update the average priority value based on the decision variable.
3. Print the count and percentage distribution of each priority level.
4. Print the average priority values and their percentage distribution.

"""

if not model.Status == GRB.INFEASIBLE:
    promedios_prioridad = {}
    valores_prioridad = {}
    for i in range(1,4):
        promedios_prioridad[i] = 0
        valores_prioridad[i] = 0

    for p in profesores:
        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            if A == 0:
                continue
            valores_prioridad[A] += 1
            # for m in materias:
            #     promedios_prioridad[A] += round(w_dict[m.id, p.id].variable.X * u_dict[m.id, b.id].variable.X)
            promedios_prioridad[A] += round(y_dict[p.id, b.id].variable.X)

    print(valores_prioridad)
    total = np.sum([valores_prioridad[i] for i in valores_prioridad])
    print(*[str(i) + ": " + str(round(valores_prioridad[i]/total*100))+"%" for i in valores_prioridad], sep=", ")

    print(promedios_prioridad)
    total = np.sum([promedios_prioridad[i] for i in promedios_prioridad])
    if total != 0:
        print(*[str(i) + ": " + str(round(promedios_prioridad[i]/total*100))+"%" for i in promedios_prioridad], sep=", ")
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()

        # if CARGA_HORARIA_p != 0:
        #     print(str(p), ": ", OBJ_p.getValue()/CARGA_HORARIA_p)
        # else:
        #     print(str(p), "sin carga horaria")
# Out:
# {1: 1985, 2: 338, 3: 544}
# 1: 69%, 2: 12%, 3: 19%
# {1: 227, 2: 42, 3: 56}
# 1: 70%, 2: 13%, 3: 17%

# %% [markdown]
# ### Ocupacion de salones

# %%
# nivel de ocupacion
if not model.Status == GRB.INFEASIBLE:
    niveles = {}

    for b_id in bloques_horario:
        salones_ocupados = int(gp.quicksum(u_dict[m, b_id].variable for m in materias_ids).getValue())
        nivel = int(salones_ocupados/num_salones*100)
        # print(str(bloques_horario[b_id]), ": ", salones_ocupados,",", str(nivel) + "%")
        niveles[b_id] = nivel

    print_timetable_salones(dias, horarios, niveles)
# Out:
# 		1	2	3	4	5
# ··········································································································
# 0_start-0_end	61%	84%	53%	69%	84%
# 1_start-1_end	69%	84%	69%	76%	84%
# 2_start-2_end	69%	76%	84%	76%	76%
# 3_start-3_end	84%	84%	84%	76%	76%
# 4_start-4_end	92%	76%	76%	61%	76%
# 5_start-5_end	76%	61%	53%	53%	69%
# 6_start-6_end	7%	0%	7%	0%	7%
# 7_start-7_end	0%	7%	7%	15%	7%
# 8_start-8_end	15%	7%	7%	15%	7%
# 9_start-9_end	38%	46%	15%	15%	30%
# 10_start-10_end	53%	53%	23%	15%	38%
# 11_start-11_end	30%	61%	30%	53%	46%
# 12_start-12_end	30%	38%	30%	76%	69%
# 13_start-13_end	69%	38%	46%	61%	76%
# 14_start-14_end	53%	23%	46%	38%	69%
# 15_start-15_end	15%	15%	15%	23%	15%
