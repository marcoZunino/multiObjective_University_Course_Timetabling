# %% [markdown]
# Imports

# %%
from gurobipy import *
import numpy as np

from db_manager import *
from load_data import *
from printing import *

# %%
# clases
from entities import *
from variables import *

# %% [markdown]
# # Cargar datos

# %% [markdown]
# ## (1) Instancia

# %%
instance = "../instances/instance_2026sem1.json"
dias, turnos, horarios, bloques_horario, grupos, materias, profesores, superposicion, superposicion_electivas, num_salones = read_json_instance(instance)

# %%
dias_ids = [d.id for d in dias]
DIAS = dias

horarios_ids = [h.id for h in horarios]
HORARIOS = horarios

bloques_horario_ids = [b for b in bloques_horario]
BLOQUES_HORARIO = bloques_horario

profesores_ids = [p.id for p in profesores]
PROFESORES = profesores

grupos_ids = [g.id for g in grupos]
GRUPOS = grupos

anios = list(set([g.anio for g in grupos if g.anio != None]))  # anios
ANIOS = anios

materias_ids = [m.id for m in materias]
MATERIAS = materias

SUPERPOSICION = superposicion
SUPERPOSICION_ELECTIVAS = superposicion_electivas

# %%
# # print(*[str(g) for g in grupos], sep="\n")
# print(*[m.profesores for m in materias], sep="\n")

# %%
print_prioridades(dias, horarios, profesores)
# Out:
#  Profesor: 3 3  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	3	3	-
# 1_start-1_end	-	-	1	1	-
# 2_start-2_end	-	-	1	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	2	2	-	-	2
# 10_start-10_end	1	1	-	-	1
# 11_start-11_end	1	1	-	-	1
# 12_start-12_end	3	3	-	-	3
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 4 4  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	-	-	1
# 2_start-2_end	1	1	-	-	1
# 3_start-3_end	1	1	-	-	1
# 4_start-4_end	1	1	-	-	1
# 5_start-5_end	1	1	-	-	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	1	-	-	1
# 8_start-8_end	-	1	-	-	1
# 9_start-9_end	-	1	-	-	1
# 10_start-10_end	-	1	-	-	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 5 5  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 6 6  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	3	-	3	-
# 12_start-12_end	1	1	-	1	-
# 13_start-13_end	1	1	-	1	-
# 14_start-14_end	1	1	-	1	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 7 7  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	3
# 11_start-11_end	-	1	-	1	3
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	2	-	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 9 9  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	2	-	2	-
# 14_start-14_end	-	3	-	3	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 11 11  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	3	3	3	3	3
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	2	2	2	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 12 12  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	2	2	2	-	3
# 3_start-3_end	1	1	1	-	1
# 4_start-4_end	1	1	1	-	1
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 13 13  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	3	-	3	-
#
#  Profesor: 14 14  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	-	-
# 1_start-1_end	-	1	-	-	-
# 2_start-2_end	-	1	-	-	-
# 3_start-3_end	-	1	-	-	-
# 4_start-4_end	1	1	1	-	-
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	1	1	1	-	-
# 7_start-7_end	1	1	1	-	-
# 8_start-8_end	1	1	1	-	-
# 9_start-9_end	1	1	1	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 15 15  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	1	-	1	-
# 7_start-7_end	-	1	-	1	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	1	-	2	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 16 16  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 17 17  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	1	-	1
# 1_start-1_end	-	-	1	-	1
# 2_start-2_end	-	-	1	-	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 18 18  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 21 21  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 26 26  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	-	1	-
# 12_start-12_end	1	1	-	1	-
# 13_start-13_end	1	1	-	1	-
# 14_start-14_end	1	1	-	1	-
# 15_start-15_end	1	1	-	1	-
#
#  Profesor: 28 28  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 29 29  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	1	-	1	-	-
# 11_start-11_end	1	-	1	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 30 30  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	2	-	2	2
# 11_start-11_end	-	1	-	1	1
# 12_start-12_end	-	1	-	1	1
# 13_start-13_end	-	1	-	1	1
# 14_start-14_end	-	1	-	1	1
# 15_start-15_end	-	3	-	3	3
#
#  Profesor: 31 31  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	2	2	2	2	2
# 4_start-4_end	2	2	2	2	2
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 32 32  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	2	2	2	-
# 3_start-3_end	-	2	2	2	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	-	-
# 12_start-12_end	1	1	1	-	-
# 13_start-13_end	1	1	1	-	-
# 14_start-14_end	1	1	1	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 33 33  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	3	-	3	-
# 3_start-3_end	-	1	-	1	1
# 4_start-4_end	-	1	-	1	1
# 5_start-5_end	-	2	-	2	2
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 34 34  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 36 36  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	1	-	1
# 3_start-3_end	-	-	1	-	1
# 4_start-4_end	-	-	1	-	1
# 5_start-5_end	-	-	3	-	2
# 6_start-6_end	-	-	3	-	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	2	-	3
# 10_start-10_end	-	-	2	-	3
# 11_start-11_end	-	-	1	-	1
# 12_start-12_end	-	-	1	-	1
# 13_start-13_end	-	-	1	-	1
# 14_start-14_end	-	-	3	-	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 37 37  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	3	1	3	1	3
# 9_start-9_end	3	1	2	1	3
# 10_start-10_end	3	1	2	1	3
# 11_start-11_end	3	1	2	1	3
# 12_start-12_end	3	2	2	2	3
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 38 38  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	2	3	2	3
# 3_start-3_end	3	2	3	2	3
# 4_start-4_end	3	2	3	2	3
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	3
# 8_start-8_end	1	1	1	1	3
# 9_start-9_end	1	1	1	1	3
# 10_start-10_end	1	1	1	1	3
# 11_start-11_end	2	1	1	1	-
# 12_start-12_end	2	1	1	1	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 39 39  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 42 42  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	2	2	2	2	2
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	2	2	2	2	2
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	2	2	2	-	2
# 12_start-12_end	3	3	3	-	3
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 43 43  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	2	2	2	2	2
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 44 44  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 47 47  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	3	-	3
# 9_start-9_end	-	-	3	-	3
# 10_start-10_end	-	-	1	-	1
# 11_start-11_end	-	-	1	-	1
# 12_start-12_end	-	-	3	-	3
# 13_start-13_end	-	-	3	-	3
# 14_start-14_end	-	-	3	-	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 48 48  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	3	3	3	3	3
# 11_start-11_end	2	2	2	2	2
# 12_start-12_end	1	2	2	2	1
# 13_start-13_end	1	2	2	2	1
# 14_start-14_end	1	2	2	2	1
# 15_start-15_end	2	2	2	2	2
#
#  Profesor: 49 49  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 50 50  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	2	2	2	3
# 3_start-3_end	-	3	3	3	3
# 4_start-4_end	-	3	3	3	3
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	2	1	1	1	-
# 7_start-7_end	2	1	1	1	-
# 8_start-8_end	2	1	1	1	-
# 9_start-9_end	2	2	2	2	-
# 10_start-10_end	3	3	3	3	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 53 53  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 54 54  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 55 55  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	3	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 57 57  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 58 58  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	3	3	3	-
# 10_start-10_end	2	2	-	2	-
# 11_start-11_end	1	1	-	1	-
# 12_start-12_end	2	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 59 59  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	3	-	3	-
# 3_start-3_end	-	2	-	2	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	2	-	2	-
# 7_start-7_end	-	1	-	1	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	3	-	3	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 60 60  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	3	3	3	3
# 13_start-13_end	-	1	1	1	1
# 14_start-14_end	-	1	1	1	1
# 15_start-15_end	-	1	1	1	1
#
#  Profesor: 61 61  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	3	3	3	3
# 1_start-1_end	3	3	3	3	3
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 62 62  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	-	2	2	2
# 3_start-3_end	3	-	1	1	1
# 4_start-4_end	3	-	1	1	1
# 5_start-5_end	3	-	2	2	2
# 6_start-6_end	3	-	3	3	3
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 64 64  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	2	2	2	2	2
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 66 66  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	1	1	1	1	-
# 13_start-13_end	2	1	1	1	-
# 14_start-14_end	3	2	2	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 68 68  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 71 71  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	2	1	1
# 1_start-1_end	2	1	2	1	1
# 2_start-2_end	-	3	3	2	2
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	-	3	-	2
# 12_start-12_end	1	1	1	1	2
# 13_start-13_end	1	1	1	1	2
# 14_start-14_end	1	1	1	1	-
# 15_start-15_end	-	2	-	2	-
#
#  Profesor: 72 72  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	-	1	-
# 1_start-1_end	1	2	-	1	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 74 74  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 75 75  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	1	1	1	-
# 4_start-4_end	-	1	1	1	-
# 5_start-5_end	-	1	1	1	-
# 6_start-6_end	-	1	1	1	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 76 76  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 77 77  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	2	2	2	-
# 1_start-1_end	-	2	2	2	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	1	1	1	-
# 4_start-4_end	-	1	1	1	-
# 5_start-5_end	-	1	1	1	-
# 6_start-6_end	-	1	1	1	-
# 7_start-7_end	-	1	1	1	-
# 8_start-8_end	-	1	1	1	-
# 9_start-9_end	-	1	1	1	-
# 10_start-10_end	-	1	1	1	-
# 11_start-11_end	-	1	1	1	-
# 12_start-12_end	-	1	1	1	-
# 13_start-13_end	-	1	1	1	-
# 14_start-14_end	-	1	1	1	-
# 15_start-15_end	-	2	2	2	-
#
#  Profesor: 80 80  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	2	1	2	-
# 9_start-9_end	1	2	1	2	-
# 10_start-10_end	1	2	1	2	-
# 11_start-11_end	1	2	1	2	-
# 12_start-12_end	1	2	1	2	-
# 13_start-13_end	2	2	2	2	-
# 14_start-14_end	3	3	3	3	-
# 15_start-15_end	3	3	3	3	-
#
#  Profesor: 82 82  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	-	2	1
# 1_start-1_end	1	2	-	2	1
# 2_start-2_end	1	2	-	2	1
# 3_start-3_end	2	-	-	-	2
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	2	1
# 12_start-12_end	-	-	-	2	1
# 13_start-13_end	-	-	-	2	1
# 14_start-14_end	-	-	-	2	1
# 15_start-15_end	-	-	-	2	1
#
#  Profesor: 84 84  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	3	3	-
# 2_start-2_end	-	-	3	3	-
# 3_start-3_end	3	-	2	2	-
# 4_start-4_end	3	-	2	2	-
# 5_start-5_end	2	-	1	1	-
# 6_start-6_end	2	-	1	1	-
# 7_start-7_end	1	-	1	1	-
# 8_start-8_end	1	1	1	1	-
# 9_start-9_end	1	1	1	1	-
# 10_start-10_end	1	1	1	1	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	2	-	2	-
# 13_start-13_end	-	2	-	2	-
# 14_start-14_end	-	3	-	3	-
# 15_start-15_end	-	3	-	3	-
#
#  Profesor: 85 85  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	1	1	-
# 2_start-2_end	1	1	1	1	-
# 3_start-3_end	1	1	1	1	-
# 4_start-4_end	1	1	1	1	-
# 5_start-5_end	1	1	1	1	-
# 6_start-6_end	1	1	1	1	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 86 86  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	2	1	3
# 1_start-1_end	2	1	2	1	3
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 87 87  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	-	1	1
# 1_start-1_end	1	1	-	1	1
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	1	-	1	1
# 13_start-13_end	1	1	-	1	1
# 14_start-14_end	1	1	-	1	1
# 15_start-15_end	1	1	-	1	1
#
#  Profesor: 88 88  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	1	-	1	-
#
#  Profesor: 91 91  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	-	1	-	1
# 1_start-1_end	1	-	1	-	1
# 2_start-2_end	1	-	1	-	1
# 3_start-3_end	1	-	1	-	1
# 4_start-4_end	1	-	1	-	1
# 5_start-5_end	1	-	1	-	1
# 6_start-6_end	2	-	2	-	2
# 7_start-7_end	2	-	2	-	2
# 8_start-8_end	3	-	3	-	3
# 9_start-9_end	3	-	3	-	3
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 92 92  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 94 94  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	3	3	3	2
# 10_start-10_end	1	2	1	2	2
# 11_start-11_end	1	2	1	2	2
# 12_start-12_end	1	2	1	2	2
# 13_start-13_end	1	2	1	2	3
# 14_start-14_end	2	2	2	2	3
# 15_start-15_end	2	2	2	2	3
#
#  Profesor: 95 95  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	3	2	2	2	1
# 10_start-10_end	3	3	3	3	1
# 11_start-11_end	-	-	-	-	1
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 97 97  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	3	3	3	3
# 12_start-12_end	2	1	2	2	3
# 13_start-13_end	2	1	1	1	3
# 14_start-14_end	2	1	1	1	3
# 15_start-15_end	3	2	2	2	-
#
#  Profesor: 99 99  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	1	1	1	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	2	2	2	2	-
# 13_start-13_end	-	3	3	3	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 100 100  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 101 101  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	1	-	-	-
# 11_start-11_end	-	1	-	-	-
# 12_start-12_end	-	3	-	-	-
# 13_start-13_end	-	3	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 102 102  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	3	3	-	-
# 1_start-1_end	-	3	-	3	3
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 103 103  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	2
# 1_start-1_end	1	1	1	1	2
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 104 104  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	1	-
# 1_start-1_end	-	1	-	1	-
# 2_start-2_end	-	1	-	1	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 106 106  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	2	-	2	-
# 12_start-12_end	-	3	-	3	-
# 13_start-13_end	-	3	-	3	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 107 107  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	2	2	2	2	2
# 15_start-15_end	2	2	2	2	2
#
#  Profesor: 108 108  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 109 109  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	1	2	1
# 3_start-3_end	1	-	1	2	1
# 4_start-4_end	2	2	2	2	3
# 5_start-5_end	2	2	2	2	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 111 111  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	1	-	1	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 112 112  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	2	2	2	2
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	2	1	1	1	2
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	2	2	2	1
# 11_start-11_end	2	2	2	2	2
# 12_start-12_end	2	2	2	2	2
# 13_start-13_end	2	3	3	3	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 115 115  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 116 116  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	-	1	-	1
# 1_start-1_end	1	-	1	-	1
# 2_start-2_end	1	-	1	-	1
# 3_start-3_end	1	-	1	-	1
# 4_start-4_end	1	-	1	-	1
# 5_start-5_end	1	-	1	-	2
# 6_start-6_end	1	-	1	-	2
# 7_start-7_end	2	-	2	-	-
# 8_start-8_end	2	-	2	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	3	-	3	-	-
# 11_start-11_end	3	-	3	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 119 119  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	2	2	2	2	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	1	1	1	1	-
# 13_start-13_end	2	2	2	2	-
# 14_start-14_end	3	3	3	3	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 120 120  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	-	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	2	-	2	-	-
#
#  Profesor: 121 121  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	1	1	2
# 12_start-12_end	2	1	1	1	2
# 13_start-13_end	2	1	1	1	2
# 14_start-14_end	2	1	1	1	2
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 122 122  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	2	2	2	2	2
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 123 123  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 124 124  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	-	-
# 1_start-1_end	1	1	1	-	-
# 2_start-2_end	1	1	1	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 126 126  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	2	1	2	1	-
# 10_start-10_end	2	1	2	1	-
# 11_start-11_end	2	1	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 128 128  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 129 129  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	3	3	3	3
# 9_start-9_end	-	3	3	3	3
# 10_start-10_end	-	1	1	1	1
# 11_start-11_end	-	1	1	1	1
# 12_start-12_end	-	3	3	3	3
# 13_start-13_end	-	3	3	3	3
# 14_start-14_end	-	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 131 131  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	-
# 5_start-5_end	1	1	1	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 132 132  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	-	-	1
# 12_start-12_end	1	-	-	-	1
# 13_start-13_end	1	-	-	-	1
# 14_start-14_end	1	-	-	-	1
# 15_start-15_end	1	-	-	-	1
#
#  Profesor: 134 134  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 135 135  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	2
# 7_start-7_end	1	-	1	-	2
# 8_start-8_end	1	-	1	-	2
# 9_start-9_end	1	-	1	-	-
# 10_start-10_end	1	-	1	-	-
# 11_start-11_end	1	-	1	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 136 136  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	-	-	-	2
# 13_start-13_end	1	-	-	-	2
# 14_start-14_end	1	-	-	-	2
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 137 137  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	1	1	1	3	1
# 14_start-14_end	1	1	1	3	1
# 15_start-15_end	1	1	1	3	1
#
#  Profesor: 138 138  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 140 140  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	2	2	1	2	1
# 13_start-13_end	2	2	1	2	1
# 14_start-14_end	2	2	1	2	1
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 141 141  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	1	-	1
# 1_start-1_end	-	-	1	-	1
# 2_start-2_end	3	3	2	2	-
# 3_start-3_end	3	3	2	2	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	1	-	2
# 12_start-12_end	1	-	1	-	2
# 13_start-13_end	-	-	3	-	-
# 14_start-14_end	-	-	3	-	-
# 15_start-15_end	-	-	3	-	-
#
#  Profesor: 142 142  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	2
# 1_start-1_end	-	-	-	-	2
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	1	1
# 5_start-5_end	-	-	-	1	1
# 6_start-6_end	-	-	-	1	1
# 7_start-7_end	-	1	-	2	1
# 8_start-8_end	-	1	-	2	1
# 9_start-9_end	-	-	-	3	1
# 10_start-10_end	-	-	-	3	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 145 145  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	1	1	1
# 1_start-1_end	2	1	1	1	1
# 2_start-2_end	2	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 146 146  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 147 147  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 148 148  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 149 149  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	-
# 3_start-3_end	1	1	1	1	-
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	-
# 10_start-10_end	1	1	1	1	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 150 150  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	3	3	-	3	3
# 2_start-2_end	2	2	-	2	2
# 3_start-3_end	1	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	2	2	2	2	2
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 151 151  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	-	-
# 1_start-1_end	-	1	-	-	-
# 2_start-2_end	-	1	-	1	1
# 3_start-3_end	-	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	1	1	-	1	1
# 6_start-6_end	1	1	-	1	1
# 7_start-7_end	1	1	-	1	1
# 8_start-8_end	1	1	-	1	1
# 9_start-9_end	1	-	-	1	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 152 152  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	3	3	1	2
# 1_start-1_end	1	3	3	1	2
# 2_start-2_end	-	3	3	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	1	3	3
# 12_start-12_end	2	1	1	3	3
# 13_start-13_end	2	1	1	3	3
# 14_start-14_end	2	1	1	3	3
# 15_start-15_end	2	1	1	3	3
#
#  Profesor: 156 156  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	2	2	2	2	2
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 157 157  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 158 158  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 159 159  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 160 160  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 161 161  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 162 162  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 163 163  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 164 164  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	2	-	2	-
#
#  Profesor: 165 165  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	1	1	1	-
# 4_start-4_end	-	1	1	1	-
# 5_start-5_end	-	1	1	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 167 167  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	3	3	2
# 3_start-3_end	1	-	1	1	1
# 4_start-4_end	1	-	1	1	1
# 5_start-5_end	1	-	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	1	-	1	1	1
# 8_start-8_end	-	-	1	1	1
# 9_start-9_end	-	-	1	1	2
# 10_start-10_end	-	-	1	1	2
# 11_start-11_end	-	-	1	1	-
# 12_start-12_end	-	-	2	2	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 168 168  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	1	3	1	3
# 12_start-12_end	3	1	3	1	3
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-

# %%
print("Grupos:", len(grupos))
# print([str(i) for i in grupos])
print("Materias:", len(materias))
# print([str(i) for i in materias])
print("Profesores:", len(profesores))
# print([str(i) for i in profesores])
# Out:
# Grupos: 29
# Materias: 165
# Profesores: 117

# %% [markdown]
# # Formulacion

# %% [markdown]
# ## (2) Variables
#
#
# $$ u_{mb} \in \{0,1\} $$
#
#     m: materia
#     b: bloque horario = [dh]: dia y hora
#
# $$ v_{md} \in \{0,1\} $$
#
#     m: materia
#     d: dia
#
# $$ w_{mp} \in \{0,1\} $$
#
#     m: materia
#     p: profesor
#
#
# $$ x_{gb} \in \{0,1\} $$
#
#     g: grupo
#     b: bloque horario = [dh]: dia y hora
#
# $$ y_{pb} \in \{0,1\} $$
#
#     p: profesor
#     b: bloque horario = [dh]: dia y hora
#
# $$ z_{pd} \in \{0,1\} $$
#
#     p: profesor
#     d: dia

# %%
print(len(materias))
print(len(bloques_horario))
# Out:
# 165
# 80

# %% [markdown]
# ## (3) Restricciones

# %% [markdown]
# ### (3.1) Materias

# %% [markdown]
# #### (3.1.1) superposicion (redundante con la definicion de la variable x)
# $$ \sum_{b} \sum_{m, m'}{u_{mb} \times S_{m,m'} \times u_{m'b}} = 0 $$

# %%
"""
    This code defines constraints to ensure that no two subjects (materias) overlap
    in the same time block (bloque horario).
    Constraints:
        1. For each time block (b) in bloques_horario_ids, the sum of the product of the decision variables 
        (u_dict[m1, b].variable and u_dict[m2, b].variable) and the overlap value (superposicion[(m1, m2)].value)
        for all pairs of subjects (m1, m2) must be equal to 0.
"""

def constr_superposicion(model, u_dict):

    # model.addConstrs(gp.quicksum(u_dict[m1, b].variable * superposicion[(m1, m2)].value * u_dict[m2, b].variable
    #                         for m1 in materias_ids for m2 in materias_ids)
    #             == 0 for b in bloques_horario_ids)
    
    for b in bloques_horario_ids:
        for m1 in materias_ids:
            for m2 in materias_ids:
                if m1 != m2 and superposicion[(m1, m2)].value == 1:
                    model.addConstr(u_dict[m1, b].variable + u_dict[m2, b].variable <= 1)

# %% [markdown]
# #### (3.1.2) cubrir carga horaria para cada materia
# $$ \sum_b{u_{mb}} = C_m $$
#
#     para todo m (c_m: carga horaria)

# %%
def constr_carga_horaria(model, u_dict):
    for m in materias:
        model.addConstr(gp.quicksum(u_dict[m.id, b].variable for b in bloques_horario_ids) == m.carga_horaria)

# %% [markdown]
# #### (3.1.3) particion de horas por materia

# %% [markdown]
# ##### (3.1.3.1) fijar cantidad de dias por materia
#
# $$ \sum_d {v_{md}} = D_m $$
#
#     para todo m

# %%
def constr_dias_materia(model, v_dict):
    for m in materias:
        model.addConstr(gp.quicksum(v_dict[m.id, d].variable for d in dias_ids) == m.cantidad_dias)

# %% [markdown]
# ##### (3.1.3.2) fijar maximo y minimo de horas por dia
#
# $$ v_{md} \times {H_{MIN}}_m \leq \sum_h {u_{mdh}} \leq v_{md} \times {H_{MAX}}_m $$
#
#     para todo m, d

# %%
def constr_max_min_horas(model, u_dict, v_dict):

    for m in materias:

        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        <= m.horas_max() * v_dict[m.id,d].variable for d in dias_ids)
        
        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        >= m.horas_min() * v_dict[m.id,d].variable for d in dias_ids)

# %% [markdown]
# ##### (3.1.3.3) fijar materia a turno de horarios
#
# $$ u_{mb} = 0 $$
#
#     para todo b fuera de m.turnos
#     para todo m

# %%
def constr_turnos_materia(model, u_dict):

    for m in materias:
        no_bloques_materia_ids = [b for b in bloques_horario if b not in bloques_horario_materia(m, bloques_horario)]
        model.addConstrs(u_dict[m.id, b].variable == 0 for b in no_bloques_materia_ids)

# %% [markdown]
# #### (3.1.4) horas consecutivas dentro de un dia
#
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} = v_{md} $$
#     para todo m, d

# %%
def constr_horas_consecutivas(model, u_dict, v_dict):

    model.addConstrs(gp.quicksum(u_dict[(m,(d,h))].variable for h in horarios_ids)
                 - gp.quicksum(u_dict[(m,(d,h))].variable * u_dict[(m,(d,h+1))].variable for h in horarios_ids[0:-1])
                 == v_dict[m, d].variable for m in materias_ids for d in dias_ids)

# %% [markdown]
# Alternativa:
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} \leq 1 $$
#     para todo m, d

# %% [markdown]
# #### (3.1.5) evitar dias consecutivos para una misma materia
#
# $$ \sum_m \sum_d {v_{m(d)} · v_{m(d+1)}} = 0 $$

# %%
mats_dias_consecutivos = [mat for mat in materias if mat.dias_consecutivos]

def constr_dias_consecutivos(model, v_dict):

    model.addConstrs(gp.quicksum(v_dict[m,d].variable * v_dict[m,d+1].variable for d in dias_ids[0:-1]) == 0
                 for m in [mat.id for mat in materias if not mat in mats_dias_consecutivos])

# %% [markdown]
# ### (3.2) Profesores

# %% [markdown]
# #### (3.2.1) indisponibilidad
#
# $$ \sum_m w_{mp} \times u_{mb} = 0 $$
#
#     para todo p sin disponibilidad en b

# %%
def constr_no_disponible_profesor(model, u_dict, w_dict):
    for m in materias:
        for p in m.profesores:
            for b in p.no_disponible:
                model.addConstr(u_dict[m.id, b.id].variable * w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# #### (3.2.2) unica materia por profesor para un mismo bloque horario
#
# $$ \sum_{m} {w_{mp} \times u_{mb}} \leq 1 $$
#
#     para todo b, p

# %% [markdown]
# REDUNDANTE CON DEFINICION DE y_pb

# %%
p_grupos_simultaneos = [p.nombre for p in profesores if p.cursos_simultaneos]

def constr_unica_materia_profesor(model, u_dict, w_dict):

    for p in profesores:
        mats_p = [m.id for m in materias_profesor(p, materias)]
        if p.nombre not in p_grupos_simultaneos:
            model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in mats_p)
                        <= 1 for b in bloques_horario_ids)
        else: # caso particular
            model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in mats_p)
                     <= 2 for b in bloques_horario_ids)

# %% [markdown]
# #### (3.2.3) profesores por materia

# %% [markdown]
# ##### (3.2.3.1) limitar profesores a lista
#
# $$ w_{mp} = 0 $$
#
#     para todo p not in m.lista_profesores
#     para todo m

# %%
def constr_limitar_profesores_materia(model, w_dict):
    
    for m in materias:
        for p in profesores:
            if p not in m.profesores:
                model.addConstr(w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# ##### (3.2.3.2) cantidad de profesores para una misma materia
#
# $$ \sum_p {w_{mp}} = P_m $$
#
#     para todo m

# %%
def constr_cantidad_profesores(model, w_dict):
    for m in materias:
        model.addConstr(gp.quicksum(w_dict[m.id, p].variable for p in profesores_ids) == m.cantidad_profesores)

# %% [markdown]
# #### (3.2.4) carga horaria por docente: limitar la cantidad de materias por profesor
#
#
# $$ \sum_m {w_{mp}} \leq K_p $$
#
#     para todo p

# %%
# separar por nombre de materia
def constr_grupos_max_profesor(model, w_dict):
    for p in profesores:
        for l in p.lista_materias:
            mats = search_materias_by_nombre(materias, l["nombre_materia"]) # subject_id
            if len(mats) > 0:
                model.addConstr(gp.quicksum(w_dict[m.id, p.id].variable for m in mats) <= l["grupos_max"])

# %% [markdown]
# #### (3.2.5) definicion de variable "y" (asignacion horario-profesor)
#
# $$ y_{pb} = \sum_m{u_{mb}·w_{mp}} $$
#
# $$ y_{pb} = \text{OR}_m \{u_{mb}·w_{mp}\} $$
#
#     para todo p, b

# %%
def constr_definir_y(model, y_dict, u_dict, w_dict):

    for p in profesores:
        uw_vars = {} # variable auxiliar = u_mb·w_mp
        mats_p = materias_profesor(p, materias)
        for m in mats_p:
            # for b_id in bloques_horario_materia(m, bloques_horario):
            for b_id in bloques_horario_ids:
                uw_vars[m.id,b_id] = model.addVar(vtype=GRB.INTEGER, name=str(m)+str(b_id)+str(p)+"_uw")
                model.addConstr(uw_vars[m.id,b_id] == u_dict[m.id,b_id].variable * w_dict[m.id,p.id].variable)
        
        mats_p_ids = [m.id for m in mats_p]
        model.addConstrs(y_dict[p.id,b_id].variable ==
                     gp.or_(uw_vars[m_id,b_id] for m_id in mats_p_ids)
                     for b_id in bloques_horario_ids)
    
    # model.addConstrs(y_dict[p, b].variable ==
    #              gp.quicksum(u_dict[m,b].variable * w_dict[m,p].variable for m in materias_ids)
    #              for b in bloques_horario_ids for p in profesores_ids)

# %% [markdown]
# #### (3.2.6) definicion de variable "z" (para dias con clase por profesor)
#
# $$ z_{pd} = OR_h{y_{p(dh)}} $$
#
#     para todo p, d

# %%
def constr_definir_z(model, z_dict, y_dict):
    
    model.addConstrs(z_dict[p,d].variable ==
                gp.or_(y_dict[p,(d,h)].variable for h in horarios_ids)
                for p in profesores_ids for d in dias_ids)

# %% [markdown]
# ### (3.3) Restricciones externas

# %% [markdown]
# #### (3.3.1) cantidad de salones
#
# $$ \sum_{m} {u_{mb}} \leq K $$
#
#     para todo b

# %%
def constr_cantidad_salones(model, u_dict, num_salones):
    model.addConstrs(gp.quicksum(u_dict[m, b].variable for m in materias_ids) <= num_salones for b in bloques_horario_ids)

# %% [markdown]
# #### (3.3.2) restricciones ad hoc

# %% [markdown]
# #### (3.3.3) practico despues del teorico
#
# $$ \max_b\{(-b)*u_{mb}\} > \max_b\{(-b)*u_{m'b}\} $$
#
#     para todo par (teorico, practico) =  (m, m')

# %%
def constr_teo_prac(model, u_dict):

    """
    Variables:
        teo (list): Array containing IDs of theoretical subjects.
        prac (list): Array containing IDs of practical subjects.
        vars1erHora (dict): Dictionary mapping subject IDs to Gurobi integer variables representing the first hour.
        scaled_u_dict (dict): Dictionary mapping tuples of subject IDs and block IDs to scaled Gurobi integer variables.

    Functions:
        search_materias_by_nombre(materias, nombre): Searches for subjects by name in the given list of subjects.

    Workflow:
    1. Populate `teo` and `vars1erHora` with IDs and variables for theoretical subjects.
    2. Populate `prac` and `vars1erHora` with IDs and variables for practical subjects.
    3. Create scaled variables `scaled_u_dict` for each subject and block combination.
    4. Add constraints to the model to ensure that `vars1erHora` variables are the maximum of the scaled variables.
    5. Add constraints to ensure that the first hour of theoretical subjects is greater than or equal to the first hour of practical subjects if the lengths of `teo` and `prac` are equal.


    """
    teo = []    # array con IDS de materias de teorico
    prac = []    # array con IDS de materias de practico
    vars1erHora = {}
    scaled_u_dict = {}

    for t in [m for m in materias if m.teo_prac == "teo"]:
        teo.append(t.id)
        vars1erHora[t.id] = model.addVar(vtype=GRB.INTEGER, name=str(t)+"_1er_hora")

    for p in [m for m in materias if m.teo_prac == "prac"]:
        prac.append(p.id)
        vars1erHora[p.id] = model.addVar(vtype=GRB.INTEGER, name=str(p)+"_1er_hora")

    L = len(bloques_horario_ids)

    for m in teo + prac:
        for b in range(0, L):
            scaled_u_dict[m, bloques_horario_ids[b]] = model.addVar(vtype=GRB.INTEGER, name=str(m)+"scaled_u")
            model.addConstr(scaled_u_dict[m, bloques_horario_ids[b]] == (L - b) * u_dict[m, bloques_horario_ids[b]].variable)

    for m_id in vars1erHora:
        model.addConstr(vars1erHora[m_id] ==
                        # gp.max_( (L - b) * u_dict[m_id, bloques_horario_ids[b]].variable
                        gp.max_( scaled_u_dict[m_id, bloques_horario_ids[b]]
                                for b in range(0, L)) )


    if len(teo) == len(prac):
        model.addConstrs(vars1erHora[teo[m]] >= vars1erHora[prac[m]] for m in range(0, len(teo)))
    else:
        print("Error: no coinciden cantidad de teoricos con practicos")

# %% [markdown]
# #### (3.3.4) Limitar horas excepcionales
#
# $$ \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} \leq E$$

# %%
def constr_horarios_excepcionales(model, u_dict, E_teo, E_prac):

    suma_horas_prac = gp.LinExpr()
    suma_horas_teo = gp.LinExpr()
    
    for m in materias:
        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos())) > 0:
                if m.teo_prac == "prac":
                    suma_horas_prac += u_dict[m.id, b.id].variable
                else:
                    suma_horas_teo += u_dict[m.id, b.id].variable
    
    model.addConstr(suma_horas_prac <= E_prac, "horas_excepcionales_prac")
    model.addConstr(suma_horas_teo <= E_teo, "horas_excepcionales_teo")

# %% [markdown]
# ### (3.4) Grupos

# %% [markdown]
# #### (3.4.1) definicion de variable "x"
#
# $$ x_{gb} = OR_{m \in M_g} {u_{mb}} $$

# %%
def constr_definir_x(model, x_dict, u_dict):

    for g in grupos:
        # gr_mats_ids = [m.id for m in materias_grupo(g, materias)]
        gr_mats_ids = [m.id for m in materias_grupo(g, [m for m in materias if not m.electiva])] # filtrar materias electivas
        model.addConstrs(x_dict[g.id, b].variable == gp.or_(u_dict[m, b].variable for m in gr_mats_ids) for b in bloques_horario_ids)

# %% [markdown]
# #### (3.4.2) evitar horas puente por grupo
#
# $$ \sum_h {x_{gdh}} - \sum_h {x_{gd(h)} · x_{gd(h+1)}} \leq 1 $$
#     para todo g, d

# %%
def constr_horas_puente_grupos(model, x_dict):

    for g in grupos:
        model.addConstrs(gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
                    - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
                    <= 1 for d in dias_ids)

# %% [markdown]
# ## (4) Funcion Objetivo

# %% [markdown]
# ### (4.1) Prioridad horaria de los docentes
#
# $$ \min: \sum_{m,b,p} {A_{pb}·w_{mp}·u_{mb}} $$

# %%
def obj_prioridades(y_dict):

    OBJ1 = gp.LinExpr()

    count = 0
    for p in profesores:
        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            OBJ1 += A * y_dict[p.id, b.id].variable
            count += 1

    print("obj_prioridades terms:", count)

    return OBJ1

# %% [markdown]
# ### (4.2) Minimizar/Maximizar dias con clase por profesor
# $$ \min: \sum_{p,d} {\alpha_p} {z_{pd}}$$
# donde $\alpha_p = 1$ si se minimiza, $\alpha_p = -1$ si se maximiza y $\alpha_p = 0$ si es irrelevante

# %%
def obj_min_max_dias(z_dict):

    OBJ2 = gp.LinExpr()
    DP = {}

    count = 0
    for p in profesores:
        
        D_p = gp.quicksum(z_dict[p.id,d].variable for d in dias_ids)
        DP[p.id] = D_p

        # filtrar si el profesor prefiere minimizar o maximizar o ninguno
        match p.min_max_dias:
            case "min":
                OBJ2 += D_p
                count += len(dias_ids)
            case "max":
                OBJ2 -= D_p
                count += len(dias_ids)
            case None:
                pass

    print("obj_min_max_dias terms:", count)

    return OBJ2, DP

# %% [markdown]
# ### (4.3) Minimizar horas puente por grupo (se incluye directamente como restriccion)
#
# $$ \min: -\sum_{g,d,h} {x_{gd(h)}·x_{gd(h+1)}} $$

# %%
def obj_horas_puente_grupos(x_dict):
    OBJ3 = gp.QuadExpr()

    count = 0
    for g in grupos:
        for d in dias_ids:
            OBJ3 += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
            count += 1

    print("obj_horas_puente_grupos terms:", count)

    return OBJ3

# %% [markdown]
# ### (4.4) Minimizar superposicion de electivas
#
# $$ \min:  \sum_{b} \sum_{m, m'}{u_{mb} \times SE_{m,m'} \times u_{m'b}} = 0 $$
#
# para todo par (m, m') de electivas

# %%
def obj_superposicion_electivas(u_dict):
    OBJ4 = gp.QuadExpr()

    count = 0
    for m1 in electivas(materias):
        for m2 in electivas(materias):
            for b in bloques_horario_ids:
                OBJ4 += u_dict[m1.id, b].variable * superposicion_electivas[m1.id, m2.id].value * u_dict[m2.id, b].variable
                count += 1

    print("obj_superposicion_electivas terms:", count)

    return OBJ4

# %% [markdown]
# ### (4.5) Evitar horas excepcionales
#
# $$ \min: \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} $$

# %%
def obj_horarios_excepcionales(u_dict, prac=False):

    objetivo = gp.LinExpr()

    count = 0
    for m in materias:

        if (not prac and m.teo_prac == "prac") or (prac and m.teo_prac != "prac"):
            continue

        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos()))>0:
                objetivo += u_dict[m.id, b.id].variable
                count += 1
        
    print("obj_horarios_excepcionales terms:", count)

    return objetivo

# %% [markdown]
# Guardar instancia en formato json

# %%
# # recargar input original

# import copy

# anios = copy.deepcopy(ANIOS)
# dias = copy.deepcopy(DIAS)
# horarios = copy.deepcopy(HORARIOS)
# bloques_horario = copy.deepcopy(BLOQUES_HORARIO)
# profesores = copy.deepcopy(PROFESORES)
# grupos = copy.deepcopy(GRUPOS)
# materias = copy.deepcopy(MATERIAS)
# superposicion = copy.deepcopy(SUPERPOSICION)
# superposicion_electivas = copy.deepcopy(SUPERPOSICION_ELECTIVAS)

# %%
# #filtrar por grupos

# grupos = [g for g in grupos 
#                        if g.anio in [
#                         #    1,
#                         #    2,
#                         #    3,
#                            4,
#                            5,
#                        ]
#                     #    and g.carrera in [
#                     #     #    "CIV",
#                     #     #    "IND",
#                     #     #    "TEL",
#                     #     #    "INF",
#                     #     #    "DIA",
#                     #        "LINF",
#                     #     #    None
#                     #    ]
#                     #    and g.particion != 1
#                         # and not g.recurse
#                     ]

# # grupos: list[Grupo] = [g for g in grupos if not (g.anio == 3 and g.carrera == "INF") and not (g.anio == 4 and g.carrera == "LINF")]

# # materias = [m for m in materias if m.nombre not in ["Cam"]]

# ms = []
# for m in materias:
#     gs_m = []
#     for g in grupos:
#         if g in m.grupos:
#             gs_m.append(g)

#     if len(gs_m) > 0:
#         m.grupos = gs_m
#         ms.append(m)

# materias: list[Materia] = ms


# # ajustar conjunto de profesores y grupos segun las materias filtradas

# ps = []
# gs = []

# for m in materias:
#     # print(str(m), ":", [str(g) for g in m.grupos], [str(p) for p in m.profesores], m.carga_horaria, m.cantidad_dias)
#     for p in m.profesores:
#         if p not in ps:
#             ps.append(p)
#     for g in m.grupos:
#         if g not in gs:
#             gs.append(g)

# for p in ps: # ajustar materias que puede dictar un profesor
#     p.lista_materias = [m for m in p.lista_materias if m['nombre_materia'] in [str(m) for m in materias]]
#     # print(f"{p}: {set([str(m) for m in materias if p in m.profesores])} =? {[f'{m['nombre_materia'], m['grupos_max']}' for m in p.lista_materias]}")

# grupos: list[Grupo] = gs
# grupos.sort(key=lambda x: x.id)

# profesores: list[Profesor] = ps

# anios = [a for a in anios if a in [g.anio for g in grupos]]

# print([str(g) for g in grupos])

# %%
# generate_instance_json("../instances/instance_4th&5th_2026sem1.json", materias, grupos, profesores, dias, horarios, turnos, superposicion, superposicion_electivas, num_salones)

# %% [markdown]
# # Resolver

# %% [markdown]
# ## Compilar modelo

# %%
# Create a new model
model: gp.Model = gp.Model("timetable")

# %%
# variables
u_dict, v_dict, w_dict, x_dict, y_dict, z_dict = initialize_variables(materias, bloques_horario, dias, profesores, grupos)
create_variables(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)
# Out:
# u:  13200
# v:  825
# w:  19305
# x:  2320
# y:  9360
# z:  585

# %% [markdown]
# ### Seleccionar restricciones

# %%
constr_superposicion(model, u_dict)

# %%
constr_carga_horaria(model, u_dict)

# %%
constr_dias_materia(model, v_dict)

# %%
constr_max_min_horas(model, u_dict, v_dict)

# %%
constr_turnos_materia(model, u_dict)

# %%
constr_horas_consecutivas(model, u_dict, v_dict)

# %%
constr_dias_consecutivos(model, v_dict)
# constr_horarios_excepcionales(model, u_dict, 7, 1)   # (opcional) limitar cantidad de horas excepcionales

# %%
constr_no_disponible_profesor(model, u_dict, w_dict)

# %%
constr_unica_materia_profesor(model, u_dict, w_dict)

# %%
constr_limitar_profesores_materia(model, w_dict)

# %%
constr_cantidad_profesores(model, w_dict)

# %%
constr_grupos_max_profesor(model, w_dict)

# %%
constr_definir_y(model, y_dict, u_dict, w_dict)

# %%
constr_definir_z(model, z_dict, y_dict)

# %%
constr_cantidad_salones(model, u_dict, num_salones)

# %%
constr_teo_prac(model, u_dict)

# %%
constr_definir_x(model, x_dict, u_dict)

# %%
constr_horas_puente_grupos(model, x_dict)

# %% [markdown]
# ### Funcion objetivo

# %%
# funcion objetivo

objectives = { # name : (expr, weight)
    
    "prioridades" : (obj_prioridades(y_dict), 0), # weight = 1
    "min_max_dias" : (obj_min_max_dias(z_dict)[0], 0), # weight = 5
    "superposicion_electivas" : (obj_superposicion_electivas(u_dict), 0), # weight = 10
    "horarios_excepcionales (practico)" : (obj_horarios_excepcionales(u_dict, prac=True), 1), # weight = 50
    "horarios_excepcionales" : (obj_horarios_excepcionales(u_dict, prac=False), 2), # weight = 100

}
# Out:
# obj_prioridades terms: 4045
# obj_min_max_dias terms: 175
# obj_superposicion_electivas terms: 8000
# obj_horarios_excepcionales terms: 110
# obj_horarios_excepcionales terms: 865

# %%
OBJ = gp.QuadExpr()
for name in objectives:
    expr, weight = objectives[name]
    OBJ += weight * expr

model.setObjective(OBJ, GRB.MINIMIZE)

# %%
def set_starting_solution(solution_path):

    print("Setting starting solution...")

    data = read_json_solution(solution_path)

    for mb_pair, var in u_dict.items():
        var.variable.Start = 1 if mb_pair in data["u_dict"] else 0
            
    for md_pair, var in v_dict.items():
        var.variable.Start = 1 if md_pair in data["v_dict"] else 0

    for mp_pair, var in w_dict.items():
        var.variable.Start = 1 if mp_pair in data["w_dict"] else 0

# %% [markdown]
# ## Optimizar

# %%
model.setParam("TimeLimit", 2*60*60)
# model.setParam('OutputFlag', 1)
model.Params.MIPGap = 0.01/100
# model.Params.PoolSolutions = 10 # Number of solutions to find
# model.Params.PoolSearchMode = 0 # 0, 1, 2

model.optimize()

# nSolutions = model.SolCount
# print(f"Number of solutions found: {nSolutions}")
# Out:
# Set parameter TimeLimit to value 7200
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 131502 rows, 68919 columns and 306591 nonzeros
# Model fingerprint: 0x11cd310f
# Model has 41176 quadratic constraints
# Model has 12309 general constraints
# Variable types: 0 continuous, 68919 integer (45595 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [1e+00, 2e+00]
# Presolve removed 115619 rows and 55857 columns
# Presolve time: 0.34s
# Presolved: 42741 rows, 20413 columns, 124105 nonzeros
# Presolved model has 29 SOS constraint(s)
# Variable types: 0 continuous, 20413 integer (19670 binary)
#
# Root relaxation: objective 1.200000e+01, 16604 iterations, 3.22 seconds (2.02 work units)
# Total elapsed time = 6.97s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.00000    0 1439          -   12.00000      -     -   10s
#      0     0   12.00000    0 1567          -   12.00000      -     -   11s
#      0     0   12.00000    0 1598          -   12.00000      -     -   11s
#      0     0   14.00000    0 2037          -   14.00000      -     -   15s
#      0     0   14.00000    0 2028          -   14.00000      -     -   15s
#      0     0   14.00000    0 1697          -   14.00000      -     -   17s
#      0     0   14.00000    0 1697          -   14.00000      -     -   17s
#      0     0   14.00000    0 1919          -   14.00000      -     -   20s
#      0     0   14.00000    0 1711          -   14.00000      -     -   21s
#      0     0   14.00000    0  942          -   14.00000      -     -   31s
#      0     0   14.00000    0 1067          -   14.00000      -     -   31s
#      0     0   14.00000    0  766          -   14.00000      -     -   42s
#      0     0   14.00000    0  942          -   14.00000      -     -   44s
#      0     0   14.00000    0  668          -   14.00000      -     -   54s
# H    0     0                      22.0000000   14.00000  36.4%     -   56s
#      0     0   14.00000    0  768   22.00000   14.00000  36.4%     -   56s
# H    0     0                      18.0000000   14.00000  22.2%     -   60s
#      0     0   14.00000    0  738   18.00000   14.00000  22.2%     -   63s
#      0     0   14.00000    0  738   18.00000   14.00000  22.2%     -   65s
# H    0     0                      17.0000000   14.00000  17.6%     -   66s
#      0     2   14.00000    0  709   17.00000   14.00000  17.6%     -   70s
#      7    14   14.00000    3  825   17.00000   14.00000  17.6%  3070   75s
#     19    26   14.09375    4 1068   17.00000   14.00000  17.6%  4673   81s
#     31    38   14.00000    6  840   17.00000   14.00000  17.6%  4400   85s
#     44    50   14.14864    7 1294   17.00000   14.00000  17.6%  4013   90s
#     64    69   14.27229    9  832   17.00000   14.00000  17.6%  3964   95s
#     88    87   14.09583   10 1357   17.00000   14.00000  17.6%  3737  101s
#    114   100   15.00000   13 1308   17.00000   14.00000  17.6%  3463  105s
#    151   120   14.22222   15 1136   17.00000   14.00000  17.6%  3326  112s
#    166   125   14.77778   16  999   17.00000   14.00000  17.6%  3265  116s
#    187   123   14.99745   18 1190   17.00000   14.00000  17.6%  3227  120s
#    234   131   14.90909    9 1159   17.00000   14.00000  17.6%  3052  127s
#    242   141   14.95792   10 1166   17.00000   14.00000  17.6%  3071  130s
#    254   144   15.43151   11 1045   17.00000   14.00000  17.6%  3088  135s
#    275   150     cutoff   10        17.00000   14.00000  17.6%  3020  147s
#    290   157     cutoff   12        17.00000   14.00000  17.6%  2991  150s
#    332   179   14.69731   13 1083   17.00000   14.00000  17.6%  3009  159s
#    376   180   14.64000    8 1217   17.00000   14.00000  17.6%  2894  169s
#    391   189     cutoff   10        17.00000   14.00000  17.6%  2865  172s
#    414   196   15.33720   13 1179   17.00000   14.00000  17.6%  2854  186s
#    443   205   15.99929   18 1021   17.00000   14.00000  17.6%  2805  190s
#    474   215   14.17287    7 1216   17.00000   14.00000  17.6%  2746  200s
#    492   231   14.80000   12 1125   17.00000   14.00000  17.6%  2732  209s
#    536   242   15.45378   20 1172   17.00000   14.00000  17.6%  2637  214s
#    587   250   14.15718    7  823   17.00000   14.00000  17.6%  2573  274s
#    597   256   14.58821    9  799   17.00000   14.00000  17.6%  2601  287s
#    615   288   14.74952   10  783   17.00000   14.00000  17.6%  2572  294s
#    655   295   15.00000    8 1386   17.00000   14.00000  17.6%  2572  300s
#    703   312   16.00000   10 1086   17.00000   14.00000  17.6%  2528  305s
#    742   328 infeasible   13        17.00000   14.00000  17.6%  2512  310s
#    787   342   14.28370    8 1322   17.00000   14.00000  17.6%  2503  316s
#    841   370   14.15638    8 1199   17.00000   14.00000  17.6%  2499  322s
#    885   381   15.05142   13  883   17.00000   14.00000  17.6%  2503  343s
#    918   398   14.17651    6  951   17.00000   14.00000  17.6%  2483  350s
#    965   407   14.95129   11 1199   17.00000   14.00000  17.6%  2509  358s
#   1039   435   15.03863    9  882   17.00000   14.00000  17.6%  2483  366s
#   1099   450     cutoff   15        17.00000   14.00665  17.6%  2473  374s
#   1166   465   15.79490   14 1179   17.00000   14.00953  17.6%  2453  382s
#   1257   491   14.33333    6 1215   17.00000   14.07255  17.2%  2409  389s
#   1317   506     cutoff   12        17.00000   14.09375  17.1%  2417  399s
#   1388   529     cutoff   14        17.00000   14.12000  16.9%  2419  412s
#   1471   546   15.66667    8  778   17.00000   14.12055  16.9%  2403  422s
#   1545   566   14.69457    8 1014   17.00000   14.14865  16.8%  2413  434s
#   1625   582   15.90642   12  961   17.00000   14.16667  16.7%  2414  443s
#   1693   590   14.83443   10 1174   17.00000   14.16667  16.7%  2426  452s
#   1788   593   15.75812   16 1622   17.00000   14.17787  16.6%  2420  465s
#   1918   623 infeasible    8        17.00000   14.21005  16.4%  2383  473s
#   2037   665   15.52266   13 1684   17.00000   14.22222  16.3%  2356  484s
#   2171   689   15.43548   14 1572   17.00000   14.25335  16.2%  2320  494s
#   2261   705   16.00000   16  733   17.00000   14.25335  16.2%  2333  508s
#   2383   721   15.37486   18  970   17.00000   14.28916  15.9%  2318  520s
#   2541   732     cutoff   16        17.00000   14.34238  15.6%  2276  532s
#   2676   752     cutoff   13        17.00000   14.37840  15.4%  2269  545s
#   2790   756   15.64518   17 1208   17.00000   14.39886  15.3%  2276  558s
#   2919   763   15.33333   17 1235   17.00000   14.42407  15.2%  2284  575s
#   3024   776     cutoff   16        17.00000   14.46444  14.9%  2305  589s
#   3173   772   15.50000    9  609   17.00000   14.50736  14.7%  2300  603s
#   3354   767   15.39803   17 1305   17.00000   14.58086  14.2%  2284  625s
#   3494   761 infeasible   15        17.00000   14.63712  13.9%  2291  645s
#   3677   756     cutoff   12        17.00000   14.69602  13.6%  2280  662s
#   3895   727   15.75000   11 1022   17.00000   14.73957  13.3%  2258  681s
# H 4056   281                      16.0000000   14.76408  7.72%  2233  681s
#   4123   136     cutoff   23        16.00000   14.85845  7.13%  2235  700s
#   4272   192   15.00000    9  358   16.00000   15.00000  6.25%  2246  727s
# * 4345   192              27      15.0000000   15.00000  0.00%  2224  727s
#
# Cutting planes:
#   Learned: 6
#   Gomory: 5
#   Cover: 219
#   Implied bound: 1191
#   Clique: 292
#   MIR: 67
#   StrongCG: 9
#   Flow cover: 21
#   Inf proof: 4
#   Zero half: 172
#   RLT: 903
#   Relax-and-lift: 36
#   BQP: 147
#
# Explored 4554 nodes (10402883 simplex iterations) in 727.79 seconds (677.51 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 15 16 17 ... 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%

# %%
set_starting_solution("../results/solution_test.json")
# Out:
# Setting starting solution...

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 131502 rows, 68919 columns and 306591 nonzeros
# Model fingerprint: 0x98c9592d
# Model has 41176 quadratic constraints
# Model has 12309 general constraints
# Variable types: 0 continuous, 68919 integer (45595 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [1e+00, 2e+00]
#
# User MIP start produced solution with objective 15 (0.15s)
# Loaded user MIP start with objective 15
#
# Presolve removed 115619 rows and 55857 columns
# Presolve time: 0.29s
# Presolved: 42741 rows, 20413 columns, 124105 nonzeros
# Presolved model has 29 SOS constraint(s)
# Variable types: 0 continuous, 20413 integer (19670 binary)
#
# Root relaxation: objective 1.200000e+01, 16981 iterations, 3.33 seconds (2.22 work units)
# Total elapsed time = 6.91s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.00000    0 1807   15.00000   12.00000  20.0%     -   10s
#      0     0   12.00000    0 1644   15.00000   12.00000  20.0%     -   11s
#      0     0   12.00000    0 1738   15.00000   12.00000  20.0%     -   11s
#      0     0   13.33333    0 1655   15.00000   13.33333  11.1%     -   11s
#      0     0   14.00000    0 1652   15.00000   14.00000  6.67%     -   11s
#      0     0   14.00000    0 1551   15.00000   14.00000  6.67%     -   11s
#      0     0   14.00000    0 2254   15.00000   14.00000  6.67%     -   15s
#      0     0   14.00000    0 2255   15.00000   14.00000  6.67%     -   16s
#      0     0   14.00000    0 2257   15.00000   14.00000  6.67%     -   19s
#      0     0   14.00000    0 2257   15.00000   14.00000  6.67%     -   19s
#      0     0   14.00000    0  777   15.00000   14.00000  6.67%     -   32s
#      0     0   14.00000    0  798   15.00000   14.00000  6.67%     -   32s
#      0     0   14.00000    0 1185   15.00000   14.00000  6.67%     -   34s
#      0     0   14.00000    0 1176   15.00000   14.00000  6.67%     -   34s
#      0     0   14.00000    0  975   15.00000   14.00000  6.67%     -   42s
#      0     0   14.00000    0 1138   15.00000   14.00000  6.67%     -   43s
#      0     0   14.00000    0 1113   15.00000   14.00000  6.67%     -   43s
#      0     0   14.00000    0 1241   15.00000   14.00000  6.67%     -   45s
#      0     0   14.00000    0 1173   15.00000   14.00000  6.67%     -   55s
#      0     0   14.00000    0 1130   15.00000   14.00000  6.67%     -   55s
#      0     0   14.00000    0  367   15.00000   14.00000  6.67%     -   57s
#      0     0   14.00000    0 1242   15.00000   14.00000  6.67%     -   66s
#      0     0   14.00000    0 1110   15.00000   14.00000  6.67%     -   66s
#      0     0   14.00000    0 1511   15.00000   14.00000  6.67%     -   68s
#      0     0   14.00000    0 1753   15.00000   14.00000  6.67%     -   69s
#      0     0   14.00000    0 1731   15.00000   14.00000  6.67%     -   69s
#      0     0   14.00000    0 1014   15.00000   14.00000  6.67%     -   80s
#      0     0   14.00000    0 1399   15.00000   14.00000  6.67%     -   82s
#      0     0   14.00000    0 1247   15.00000   14.00000  6.67%     -   82s
#      0     0   14.00000    0 1192   15.00000   14.00000  6.67%     -   88s
#      0     0   14.00000    0 1024   15.00000   14.00000  6.67%     -   90s
#      0     2   14.00000    0 1024   15.00000   14.00000  6.67%     -   93s
#      1     5   14.00000    1  857   15.00000   14.00000  6.67%  8006   95s
#     13    20   14.00000    4 1415   15.00000   14.00000  6.67%  6121  101s
#     46    53   14.00000    7 1162   15.00000   14.00000  6.67%  2969  105s
#     75    64   14.00000   10 1210   15.00000   14.00000  6.67%  2328  111s
#    105    54   14.00000   10  946   15.00000   14.00000  6.67%  2266  115s
#    185    65   14.00000    9 1421   15.00000   14.00000  6.67%  2187  124s
#    218    75   14.00000   11 1283   15.00000   14.00000  6.67%  2240  129s
#    258   102   14.00000   15 1281   15.00000   14.00000  6.67%  2218  136s
#    319   103   14.00000   20 1322   15.00000   14.00000  6.67%  2215  147s
#    400    99 infeasible   22        15.00000   14.00000  6.67%  2094  158s
#    498    87   14.00000   15 1154   15.00000   14.00000  6.67%  2151  168s
#    578    88 infeasible   15        15.00000   14.00000  6.67%  2269  180s
#    671    76 infeasible   16        15.00000   14.00000  6.67%  2278  193s
#    775    84 infeasible   17        15.00000   14.00000  6.67%  2225  202s
#    849    66 infeasible   16        15.00000   14.00000  6.67%  2270  213s
#    923    52 infeasible    7        15.00000   14.00000  6.67%  2318  224s
#    987    46 infeasible    6        15.00000   14.00000  6.67%  2334  233s
#   1049    37 infeasible   15        15.00000   14.00000  6.67%  2369  242s
#   1127    32   14.00000    9 1257   15.00000   14.00000  6.67%  2338  251s
#   1194    18 infeasible   15        15.00000   14.00000  6.67%  2329  258s
#   1238     7   14.00000   17 1157   15.00000   14.00000  6.67%  2329  264s
#   1277     0 infeasible    9        15.00000   14.00000  6.67%  2330  269s
#
# Cutting planes:
#   Learned: 101
#   Gomory: 10
#   Cover: 331
#   Implied bound: 1141
#   Clique: 258
#   MIR: 74
#   StrongCG: 8
#   Flow cover: 21
#   GUB cover: 2
#   Inf proof: 2
#   Zero half: 129
#   RLT: 840
#   Relax-and-lift: 50
#   BQP: 113
#   PSD: 1
#
# Explored 1294 nodes (3349579 simplex iterations) in 269.52 seconds (254.06 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%

# %% [markdown]
# ### Analizar no-factibilidad

# %%
# if model.Status == GRB.INFEASIBLE:
#     model.computeIIS()
#     model.write('iismodel.ilp')

#     # Print out the IIS constraints and variables
#     print('\nThe following constraints and variables are in the IIS:')
#     for c in model.getConstrs():
#         if c.IISConstr: print(f'\t{c.constrname}: {model.getRow(c)} {c.Sense} {c.RHS}')

#     for v in model.getVars():
#         if v.IISLB: print(f'\t{v.varname} ≥ {v.LB}')
#         if v.IISUB: print(f'\t{v.varname} ≤ {v.UB}')

# %% [markdown]
# ## Imprimir horarios

# %%
# save_solution_json(u_dict, v_dict, w_dict, "../results/solution_test.json")

# %%
if not model.Status == GRB.INFEASIBLE:

    print('Obj: %g' % model.ObjVal)
    for name in objectives:
        expr, weight = objectives[name]
        print(f"\t{name}: \t{" "*(35-len(name))}{round(expr.getValue())} \t(peso={weight})")
        # print('=============================================================')
            
    print_timetable(dias, horarios, u_dict, w_dict, grupos, anios)
# Out:
# Obj: 15
# 	prioridades: 	                        954 	(peso=0)
# 	min_max_dias: 	                       78 	(peso=0)
# 	superposicion_electivas: 	            50 	(peso=0)
# 	horarios_excepcionales (practico): 	  1 	(peso=1)
# 	horarios_excepcionales: 	             7 	(peso=2)
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  1
#
#  Grupo:  10
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		81		---		---		16
# 1_start-1_end		---		81		57		85		16
# 2_start-2_end		---		81		57		85		89
# 3_start-3_end		---		88		57		88		89
# 4_start-4_end		0		88		56		88		81
# 5_start-5_end		0		---		56		88		81
# 6_start-6_end *		---		---		56		---		---
#
#  Grupo:  11
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		81		56		---		---		89
# 1_start-1_end		81		56		---		57		89
# 2_start-2_end		0		56		---		57		85
# 3_start-3_end		0		88		81		57		85
# 4_start-4_end		---		88		81		88		16
# 5_start-5_end		---		88		81		88		16
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  12
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		---		---		---		85
# 1_start-1_end		88		0		---		88		85
# 2_start-2_end		88		0		81		88		89
# 3_start-3_end		57		56		81		88		89
# 4_start-4_end		57		56		81		16		81
# 5_start-5_end		57		56		---		16		81
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  13
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		57		88		56		88		0
# 8_start-8_end		57		88		56		88		0
# 9_start-9_end		57		88		56		16		89
# 10_start-10_end		81		85		81		16		89
# 11_start-11_end		81		85		81		---		---
# 12_start-12_end *		---		---		81		---		---
#
#  Grupo:  14
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		51		15		63		15		63
# 8_start-8_end		51		15		63		15		63
# 9_start-9_end		51		15		13		83		63
# 10_start-10_end		---		---		13		83		51
# 11_start-11_end		---		---		---		---		51
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  15
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		51		15		63		---		63
# 8_start-8_end		51		15		63		15		63
# 9_start-9_end		51		83		13		15		63
# 10_start-10_end		---		83		13		15		51
# 11_start-11_end		---		---		---		---		51
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  16
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		54		---		90		---		54
# 12_start-12_end		54		38		90		74		54
# 13_start-13_end		74		38		90		74		90
# 14_start-14_end		74		65		90		65		90
# 15_start-15_end		74		65		---		65		---
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  2
#
#  Grupo:  27
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		87		8		75		24		8
# 1_start-1_end		87		8		75		24		8
# 2_start-2_end		87		46		87		24		8
# 3_start-3_end		40		46		87		67		46
# 4_start-4_end		40		67		40		67		46
# 5_start-5_end		40		67		40		---		46
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  28
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		87		8		75		30		8
# 1_start-1_end		87		8		75		30		8
# 2_start-2_end		87		46		87		30		8
# 3_start-3_end		40		46		87		67		46
# 4_start-4_end		40		67		40		67		46
# 5_start-5_end		40		67		40		---		46
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  29
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		39		76/76		75		76/76		94
# 1_start-1_end		39		76/76		75		76/76		94
# 2_start-2_end		39		67		67		76/76		94
# 3_start-3_end		40		67		67		39		22/22
# 4_start-4_end		40		22/22		40		39		22/22
# 5_start-5_end		40		22/22		40		39		22/22
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  210
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		39		76/76		62		76/76		39
# 1_start-1_end		39		76/76		62		76/76		39
# 2_start-2_end		39		32		14		76/76		39
# 3_start-3_end		62		32		14		32		22/22
# 4_start-4_end		62		22/22		67		32		22/22
# 5_start-5_end		62		22/22		67		67		22/22
# 6_start-6_end *		---		---		---		67		---
#
#  Grupo:  211
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		39		22		62		22		76
# 1_start-1_end		39		22		62		22		76
# 2_start-2_end		39		67		67		22		76
# 3_start-3_end		62		67		67		39		32
# 4_start-4_end		62		76		32		39		32
# 5_start-5_end		62		76		32		39		14
# 6_start-6_end *		---		---		---		---		14
#
#  Grupo:  212
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		---		40		---		40		---
# 8_start-8_end		---		40		---		40		---
# 9_start-9_end		---		---		---		40		---
# 10_start-10_end		---		---		---		---		75
# 11_start-11_end		---		---		---		---		75
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  213
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		47		36		55		2		---
# 12_start-12_end		76		36		55		2		55
# 13_start-13_end		76		36		55		2		55
# 14_start-14_end		76		2		47		36		76
# 15_start-15_end		---		2		47		36		76
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  3
#
#  Grupo:  314
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		21		45		41		45		28
# 1_start-1_end		21		45		41		45		28
# 2_start-2_end		21		49		41		49		25
# 3_start-3_end		21		49		25		79		25
# 4_start-4_end		21		79		25		79		---
# 5_start-5_end		21		79		---		79		---
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  315
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		98		45		98		45		37
# 1_start-1_end		98		45		98		45		37
# 2_start-2_end		98		49		98		49		25
# 3_start-3_end		73		49		25		73		25
# 4_start-4_end		73		37		25		73		---
# 5_start-5_end		73		37		---		73		---
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  316
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		78		---		78		7		6
# 1_start-1_end		78		6		78		7		6
# 2_start-2_end		49		6		78		7		25
# 3_start-3_end		73		7		25		73		25
# 4_start-4_end		73		7		25		73		49
# 5_start-5_end		73		---		---		73		49
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  317
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		10		---		---		---		3
# 1_start-1_end		10		96		3		96		3
# 2_start-2_end		49		96		3		96		43
# 3_start-3_end		43		52		10		52		43
# 4_start-4_end		43		52		10		52		49
# 5_start-5_end		43		52		10		---		49
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  318
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		96		---		---		96
# 1_start-1_end		6		96		10		6		96
# 2_start-2_end		6		25		10		6		10
# 3_start-3_end		7		25		10		7		10
# 4_start-4_end		7		49		---		7		25
# 5_start-5_end		7		49		---		49		25
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  319
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		61		19		61		---		---
# 12_start-12_end		61		19		61		91		19
# 13_start-13_end		97		92		12		91		19
# 14_start-14_end		97		92		12		92		12
# 15_start-15_end		91		---		---		92		12
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  4
#
#  Grupo:  420
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		34/82/60		34/82/60		---		84		91
# 10_start-10_end		34/82/60		34/82/60		91		84		58/4
# 11_start-11_end		84		---		91		69		58/4
# 12_start-12_end		84		69		58/4		69		---
# 13_start-13_end		69		69		58/4		53		77
# 14_start-14_end		69		69		77		53		77
# 15_start-15_end *		---		---		77		---		---
#
#  Grupo:  421
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		11		91		4		91		58/4
# 10_start-10_end		11		91		4		11		58/4
# 11_start-11_end		11		17		80		11		86
# 12_start-12_end		80		17		80		17		86
# 13_start-13_end		80		17		58		17		86
# 14_start-14_end		80		---		58		---		86
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  422
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		33		---		---		---		91
# 10_start-10_end		33		---		91		95		58/4
# 11_start-11_end		33		26		91		95		58/4
# 12_start-12_end		33		26		58/4		9		26
# 13_start-13_end		9		95		58/4		9		26
# 14_start-14_end		9		95		---		9		26
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  423
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		33		58		91		97		---
# 10_start-10_end		33		58		91		97		91
# 11_start-11_end		33		95		23		95		---
# 12_start-12_end		33		95		23		95		---
# 13_start-13_end		71		4		71		58/4		---
# 14_start-14_end		71		4		71		58/4		---
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  424
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		29		---		---		96		---
# 12_start-12_end		29		96		---		96		29
# 13_start-13_end		10		96		10		64		29
# 14_start-14_end		10		49		10		64		49
# 15_start-15_end		10		---		---		64		49
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  5
#
#  Grupo:  525
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		48
# 9_start-9_end		34/82/60		34/82/60		---		---		48
# 10_start-10_end		34/82/60		34/82/60		---		1		31
# 11_start-11_end		---		---		48		1		31
# 12_start-12_end		---		1		48/48		31		---
# 13_start-13_end		48		1		48		31		77
# 14_start-14_end		48		50		77		50		77
# 15_start-15_end *		---		50		77		50		---
#
#  Grupo:  526
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		48
# 9_start-9_end		72		---		72		18		48
# 10_start-10_end		72		18		72		93/18		59
# 11_start-11_end		93		18		48		93		59
# 12_start-12_end		93		44		48/48		44		59
# 13_start-13_end		48		44		48		44		---
# 14_start-14_end		48		50		---		50		---
# 15_start-15_end *		---		50		---		50		---
#
#  Grupo:  527
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		48
# 9_start-9_end		35/66/5		---		---		66		48
# 10_start-10_end		35/66/5		20		---		66		20
# 11_start-11_end		35/29/5		20		48		---		20
# 12_start-12_end		29/5		68		48/48		68		42/27/29
# 13_start-13_end		48		68		48		68		42/27/29
# 14_start-14_end		48		50		---		50		42/27
# 15_start-15_end *		---		50		---		50		---
#
#  Grupo:  528
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		35/66/5		---		---		66		48
# 10_start-10_end		35/66/5		70		---		66		48
# 11_start-11_end		35/29/5		70		48		50		---
# 12_start-12_end		29/5		50		48/48		50		42/27/29
# 13_start-13_end		48		50		48		70		42/27/29
# 14_start-14_end		48		---		---		70		42/27
# 15_start-15_end *		---		---		---		---		---

# %%
if not model.Status == GRB.INFEASIBLE:
    print_prof_timetable_excel(dias, horarios, u_dict, w_dict, profesores, materias)
# Out:
#  Profesor:  3 3
# 	1	2	3	4	5
# 0_start-0_end	---	---	41	---	---
# 1_start-1_end	---	---	41	---	---
# 2_start-2_end	---	---	41	---	---
# 9_start-9_end	60	60	---	---	---
# 10_start-10_end	60	60	---	---	---
#
#  Profesor:  4 4
# 	1	2	3	4	5
# 1_start-1_end	---	0	---	---	---
# 2_start-2_end	0	0	---	---	---
# 3_start-3_end	0	---	---	---	---
# 4_start-4_end	0	---	---	---	---
# 5_start-5_end	0	---	---	---	---
# 7_start-7_end	---	---	---	---	0
# 8_start-8_end	---	---	---	---	0
#
#  Profesor:  5 5
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	---	91
# 10_start-10_end	---	---	91	---	---
# 11_start-11_end	---	---	91	---	---
# 12_start-12_end	---	---	---	91	---
# 13_start-13_end	---	---	---	91	---
# 15_start-15_end	91	---	---	---	---
#
#  Profesor:  6 6
# 	1	2	3	4	5
# 12_start-12_end	---	69	---	---	---
# 13_start-13_end	---	69	---	---	---
# 14_start-14_end	---	69	---	---	---
#
#  Profesor:  7 7
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	---	31
# 11_start-11_end	---	---	---	---	31
# 12_start-12_end	---	---	---	31	---
# 13_start-13_end	---	---	---	31	---
#
#  Profesor:  9 9
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	96	---
# 12_start-12_end	---	96	---	96	---
# 13_start-13_end	---	96	---	---	---
#
#  Profesor:  11 11
# 	1	2	3	4	5
# 10_start-10_end	81	---	81	---	---
# 11_start-11_end	81	---	81	---	---
# 12_start-12_end	---	---	81	---	---
#
#  Profesor:  12 12
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	85
# 3_start-3_end	57	---	---	---	85
# 4_start-4_end	57	---	---	---	---
# 5_start-5_end	57	---	---	---	---
#
#  Profesor:  13 13
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	50	---
# 12_start-12_end	---	50	---	50	---
# 13_start-13_end	---	50	---	---	---
# 14_start-14_end	---	50	---	50	---
# 15_start-15_end	---	50	---	50	---
#
#  Profesor:  14 14
# 	1	2	3	4	5
# 0_start-0_end	---	56	---	---	---
# 1_start-1_end	---	56	---	---	---
# 2_start-2_end	---	56	---	---	---
# 3_start-3_end	---	56	---	---	---
# 4_start-4_end	---	56	56	---	---
# 5_start-5_end	---	56	56	---	---
# 6_start-6_end	---	---	56	---	---
# 7_start-7_end	---	---	56	---	---
# 8_start-8_end	---	---	56	---	---
# 9_start-9_end	---	---	56	---	---
#
#  Profesor:  15 15
# 	1	2	3	4	5
# 3_start-3_end	---	88	---	88	---
# 4_start-4_end	---	88	---	88	---
# 5_start-5_end	---	---	---	88	---
# 7_start-7_end	---	15	---	15	---
# 8_start-8_end	---	15	---	15	---
# 9_start-9_end	---	15	---	83	---
# 10_start-10_end	---	---	---	83	---
#
#  Profesor:  16 16
# 	1	2	3	4	5
# 9_start-9_end	35	---	---	---	---
# 10_start-10_end	35	---	---	---	---
# 11_start-11_end	35	---	---	---	---
#
#  Profesor:  17 17
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	94
# 1_start-1_end	---	---	---	---	94
# 2_start-2_end	---	---	---	---	94
#
#  Profesor:  18 18
# 	1	2	3	4	5
# 0_start-0_end	39	---	---	---	39
# 1_start-1_end	39	---	---	---	39
# 2_start-2_end	39	---	---	---	39
#
#  Profesor:  21 21
# 	1	2	3	4	5
# 13_start-13_end	---	---	12	---	---
# 14_start-14_end	---	---	12	---	12
# 15_start-15_end	---	---	---	---	12
#
#  Profesor:  26 26
# 	1	2	3	4	5
# 11_start-11_end	---	36	---	---	---
# 12_start-12_end	---	36	---	74	---
# 13_start-13_end	74	36	---	74	---
# 14_start-14_end	74	---	---	36	---
# 15_start-15_end	74	---	---	36	---
#
#  Profesor:  28 28
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	25
# 3_start-3_end	---	---	25	---	25
# 4_start-4_end	---	---	25	---	---
#
#  Profesor:  29 29
# 	1	2	3	4	5
# 9_start-9_end	5	---	---	---	---
# 10_start-10_end	5	---	---	---	---
# 11_start-11_end	5	---	---	---	---
# 12_start-12_end	5	---	---	---	---
#
#  Profesor:  30 30
# 	1	2	3	4	5
# 10_start-10_end	---	70	---	95	---
# 11_start-11_end	---	70	---	95	---
# 13_start-13_end	---	95	---	70	---
# 14_start-14_end	---	95	---	70	---
#
#  Profesor:  31 31
# 	1	2	3	4	5
# 2_start-2_end	---	46	---	---	---
# 3_start-3_end	---	46	---	---	46
# 4_start-4_end	---	---	---	---	46
# 5_start-5_end	---	---	---	---	46
#
#  Profesor:  32 32
# 	1	2	3	4	5
# 11_start-11_end	---	19	---	---	---
# 12_start-12_end	---	19	---	---	---
# 13_start-13_end	71	---	71	---	---
# 14_start-14_end	71	---	71	---	---
#
#  Profesor:  33 33
# 	1	2	3	4	5
# 2_start-2_end	---	25	---	---	---
# 3_start-3_end	---	25	---	---	---
# 4_start-4_end	---	---	---	---	25
# 5_start-5_end	---	---	---	---	25
#
#  Profesor:  34 34
# 	1	2	3	4	5
# 12_start-12_end	---	---	48	---	---
# 13_start-13_end	48	---	48	---	---
# 14_start-14_end	48	---	---	---	---
#
#  Profesor:  36 36
# 	1	2	3	4	5
# 2_start-2_end	---	---	81	---	89
# 3_start-3_end	---	---	81	---	89
# 4_start-4_end	---	---	81	---	81
# 5_start-5_end	---	---	---	---	81
# 9_start-9_end	---	---	---	---	89
# 10_start-10_end	---	---	---	---	89
# 11_start-11_end	---	---	90	---	---
# 12_start-12_end	---	---	90	---	---
# 13_start-13_end	---	---	90	---	90
# 14_start-14_end	---	---	90	---	90
#
#  Profesor:  37 37
# 	1	2	3	4	5
# 9_start-9_end	33	---	---	---	---
# 10_start-10_end	33	---	---	---	---
# 11_start-11_end	33	---	---	---	---
# 12_start-12_end	33	---	---	---	---
#
#  Profesor:  38 38
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	43
# 3_start-3_end	43	---	---	---	43
# 4_start-4_end	43	---	---	---	---
# 5_start-5_end	43	---	---	---	---
#
#  Profesor:  39 39
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	93	---
# 11_start-11_end	93	---	---	93	86
# 12_start-12_end	93	---	---	---	86
# 13_start-13_end	---	---	---	---	86
# 14_start-14_end	---	---	---	---	86
#
#  Profesor:  42 42
# 	1	2	3	4	5
# 9_start-9_end	82	82	---	---	---
# 10_start-10_end	82	82	---	---	---
#
#  Profesor:  43 43
# 	1	2	3	4	5
# 0_start-0_end	21	---	---	---	---
# 1_start-1_end	21	---	---	---	---
# 2_start-2_end	21	---	---	---	---
# 3_start-3_end	21	---	---	---	---
# 4_start-4_end	21	---	---	---	---
# 5_start-5_end	21	---	---	---	---
#
#  Profesor:  44 44
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	24	---
# 1_start-1_end	---	---	---	24	---
# 2_start-2_end	---	---	---	24	---
#
#  Profesor:  47 47
# 	1	2	3	4	5
# 9_start-9_end	---	---	4	---	4
# 10_start-10_end	---	---	4	---	4
# 11_start-11_end	---	---	---	---	4
# 12_start-12_end	---	---	4	---	---
# 13_start-13_end	---	---	4	---	---
#
#  Profesor:  48 48
# 	1	2	3	4	5
# 11_start-11_end	---	---	80	---	---
# 12_start-12_end	80	---	80	---	---
# 13_start-13_end	80	---	---	---	---
# 14_start-14_end	80	---	---	---	---
#
#  Profesor:  49 49
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	1	---
# 11_start-11_end	---	---	---	1	---
# 12_start-12_end	---	1	---	---	---
# 13_start-13_end	---	1	---	---	---
#
#  Profesor:  50 50
# 	1	2	3	4	5
# 0_start-0_end	---	76	---	76	---
# 1_start-1_end	---	76	---	76	---
# 2_start-2_end	---	---	---	76	---
# 9_start-9_end	---	---	13	---	---
# 10_start-10_end	---	---	13	---	---
#
#  Profesor:  53 53
# 	1	2	3	4	5
# 9_start-9_end	11	---	---	---	---
# 10_start-10_end	11	---	---	11	---
# 11_start-11_end	11	---	---	11	---
#
#  Profesor:  54 54
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	25
# 3_start-3_end	---	---	25	---	25
# 4_start-4_end	---	---	25	---	---
#
#  Profesor:  55 55
# 	1	2	3	4	5
# 8_start-8_end	---	---	---	---	48
# 9_start-9_end	---	---	---	---	48
# 10_start-10_end	---	---	---	---	48
# 11_start-11_end	---	---	48	---	---
# 12_start-12_end	---	---	48	---	---
#
#  Profesor:  57 57
# 	1	2	3	4	5
# 9_start-9_end	5	---	---	---	---
# 10_start-10_end	5	---	---	---	---
# 11_start-11_end	5	---	---	---	---
# 12_start-12_end	5	---	---	---	---
#
#  Profesor:  58 58
# 	1	2	3	4	5
# 9_start-9_end	34	34	---	---	---
# 10_start-10_end	34	34	---	---	---
#
#  Profesor:  59 59
# 	1	2	3	4	5
# 3_start-3_end	---	88	---	---	---
# 4_start-4_end	---	88	---	88	---
# 5_start-5_end	---	88	---	88	---
# 7_start-7_end	---	15	---	---	---
# 8_start-8_end	---	15	---	15	---
# 9_start-9_end	---	83	---	15	---
# 10_start-10_end	---	83	---	15	---
#
#  Profesor:  60 60
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	---	77
# 14_start-14_end	---	---	77	---	77
# 15_start-15_end	---	---	77	---	---
#
#  Profesor:  61 61
# 	1	2	3	4	5
# 0_start-0_end	---	8	---	---	8
# 1_start-1_end	---	8	---	---	8
# 2_start-2_end	---	---	---	---	8
# 3_start-3_end	73	---	---	73	---
# 4_start-4_end	73	---	---	73	---
# 5_start-5_end	73	---	---	73	---
#
#  Profesor:  62 62
# 	1	2	3	4	5
# 3_start-3_end	7	---	---	7	---
# 4_start-4_end	7	---	---	7	---
# 5_start-5_end	7	---	---	---	---
#
#  Profesor:  64 64
# 	1	2	3	4	5
# 0_start-0_end	---	76	---	76	---
# 1_start-1_end	---	76	---	76	---
# 2_start-2_end	---	---	---	76	---
#
#  Profesor:  66 66
# 	1	2	3	4	5
# 1_start-1_end	6	---	---	6	---
# 2_start-2_end	6	---	---	6	---
# 11_start-11_end	---	---	23	---	---
# 12_start-12_end	---	---	23	---	---
#
#  Profesor:  68 68
# 	1	2	3	4	5
# 11_start-11_end	---	95	---	95	---
# 12_start-12_end	---	95	---	95	---
#
#  Profesor:  71 71
# 	1	2	3	4	5
# 0_start-0_end	78	---	78	---	---
# 1_start-1_end	78	---	78	---	---
# 2_start-2_end	---	---	78	---	---
# 11_start-11_end	---	---	55	---	---
# 12_start-12_end	---	---	55	---	55
# 13_start-13_end	---	---	55	---	55
#
#  Profesor:  72 72
# 	1	2	3	4	5
# 0_start-0_end	---	45	---	45	---
# 1_start-1_end	---	45	---	45	---
#
#  Profesor:  74 74
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	---	22
# 4_start-4_end	---	22	---	---	22
# 5_start-5_end	---	22	---	---	22
# 11_start-11_end	---	---	---	2	---
# 12_start-12_end	---	---	---	2	---
# 13_start-13_end	---	---	---	2	---
# 14_start-14_end	---	2	---	---	---
# 15_start-15_end	---	2	---	---	---
#
#  Profesor:  75 75
# 	1	2	3	4	5
# 2_start-2_end	---	67	67	---	---
# 3_start-3_end	---	67	67	67	---
# 4_start-4_end	---	67	67	67	---
# 5_start-5_end	---	67	67	67	---
# 6_start-6_end	---	---	---	67	---
#
#  Profesor:  76 76
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	18	---
# 10_start-10_end	---	18	---	93	---
# 11_start-11_end	93	18	---	93	---
# 12_start-12_end	93	---	---	---	---
#
#  Profesor:  77 77
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	7	---
# 1_start-1_end	---	---	---	7	---
# 2_start-2_end	---	---	---	7	---
# 3_start-3_end	---	7	---	---	---
# 4_start-4_end	---	7	---	---	---
#
#  Profesor:  80 80
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	97	---
# 10_start-10_end	---	---	---	97	---
# 13_start-13_end	97	---	---	---	---
# 14_start-14_end	97	---	---	---	---
#
#  Profesor:  82 82
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	6
# 1_start-1_end	---	6	---	---	6
# 2_start-2_end	---	6	---	---	---
# 12_start-12_end	---	---	---	---	42
# 13_start-13_end	---	---	---	---	42
# 14_start-14_end	---	---	---	---	42
#
#  Profesor:  84 84
# 	1	2	3	4	5
# 1_start-1_end	---	---	---	85	---
# 2_start-2_end	---	---	---	85	---
# 10_start-10_end	---	85	---	---	---
# 11_start-11_end	---	85	---	---	---
#
#  Profesor:  85 85
# 	1	2	3	4	5
# 1_start-1_end	88	---	---	88	---
# 2_start-2_end	88	---	---	88	---
# 3_start-3_end	40	---	---	88	---
# 4_start-4_end	40	---	40	---	---
# 5_start-5_end	40	---	40	---	---
#
#  Profesor:  86 86
# 	1	2	3	4	5
# 0_start-0_end	---	96	---	---	96
# 1_start-1_end	---	96	---	---	96
#
#  Profesor:  87 87
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	19
# 13_start-13_end	---	---	---	---	19
#
#  Profesor:  88 88
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	64	---
# 14_start-14_end	---	---	---	64	---
# 15_start-15_end	---	---	---	64	---
#
#  Profesor:  91 91
# 	1	2	3	4	5
# 0_start-0_end	---	---	62	---	---
# 1_start-1_end	---	---	62	---	---
# 2_start-2_end	---	---	14	---	---
# 3_start-3_end	62	---	14	---	---
# 4_start-4_end	62	---	---	---	---
# 5_start-5_end	62	---	---	---	14
# 6_start-6_end	---	---	---	---	14
# 7_start-7_end	---	---	63	---	63
# 8_start-8_end	---	---	63	---	63
# 9_start-9_end	---	---	---	---	63
#
#  Profesor:  92 92
# 	1	2	3	4	5
# 9_start-9_end	11	---	---	---	---
# 10_start-10_end	11	---	---	11	---
# 11_start-11_end	11	---	---	11	---
#
#  Profesor:  94 94
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	---	59
# 11_start-11_end	---	---	---	---	59
# 12_start-12_end	---	---	---	---	59
#
#  Profesor:  95 95
# 	1	2	3	4	5
# 7_start-7_end	51	---	---	---	---
# 8_start-8_end	51	---	---	---	---
# 9_start-9_end	51	---	---	---	---
# 10_start-10_end	---	---	---	---	51
# 11_start-11_end	---	---	---	---	51
#
#  Profesor:  97 97
# 	1	2	3	4	5
# 13_start-13_end	---	92	---	---	---
# 14_start-14_end	---	92	---	92	---
# 15_start-15_end	---	---	---	92	---
#
#  Profesor:  99 99
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	69	---
# 12_start-12_end	---	---	---	69	---
#
#  Profesor:  100 100
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	84	---
# 10_start-10_end	---	---	---	84	---
# 11_start-11_end	84	---	---	---	---
# 12_start-12_end	84	---	---	---	---
# 13_start-13_end	---	---	---	53	---
# 14_start-14_end	---	---	---	53	---
#
#  Profesor:  101 101
# 	1	2	3	4	5
# 12_start-12_end	---	38	---	---	---
# 13_start-13_end	---	38	---	---	---
#
#  Profesor:  102 102
# 	1	2	3	4	5
# 7_start-7_end	---	88	---	88	---
# 8_start-8_end	---	88	---	88	---
# 9_start-9_end	66	88	---	66	---
# 10_start-10_end	66	---	---	66	---
#
#  Profesor:  103 103
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	28
# 1_start-1_end	---	---	---	---	28
#
#  Profesor:  104 104
# 	1	2	3	4	5
# 2_start-2_end	---	49	---	49	---
# 3_start-3_end	---	49	---	---	---
# 4_start-4_end	---	49	---	---	---
# 5_start-5_end	---	49	---	49	---
#
#  Profesor:  106 106
# 	1	2	3	4	5
# 11_start-11_end	---	17	---	---	---
# 12_start-12_end	---	17	---	17	---
# 13_start-13_end	---	17	---	17	---
#
#  Profesor:  107 107
# 	1	2	3	4	5
# 1_start-1_end	---	---	10	---	---
# 2_start-2_end	---	---	10	---	10
# 3_start-3_end	---	---	10	---	10
#
#  Profesor:  108 108
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	3
# 1_start-1_end	---	---	3	---	3
# 2_start-2_end	---	---	3	---	---
#
#  Profesor:  109 109
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	79	---
# 4_start-4_end	---	79	---	79	---
# 5_start-5_end	---	79	---	79	---
#
#  Profesor:  111 111
# 	1	2	3	4	5
# 3_start-3_end	---	52	---	52	---
# 4_start-4_end	---	52	---	52	---
# 5_start-5_end	---	52	---	---	---
#
#  Profesor:  112 112
# 	1	2	3	4	5
# 0_start-0_end	---	---	75	---	85
# 1_start-1_end	---	---	75	---	85
# 7_start-7_end	57	---	---	---	---
# 8_start-8_end	57	---	---	---	---
# 9_start-9_end	57	---	---	---	---
# 10_start-10_end	---	---	---	---	75
# 11_start-11_end	---	---	---	---	75
#
#  Profesor:  115 115
# 	1	2	3	4	5
# 0_start-0_end	78	---	78	---	---
# 1_start-1_end	78	---	78	---	---
# 2_start-2_end	---	---	78	---	---
# 11_start-11_end	---	---	55	---	---
# 12_start-12_end	---	---	55	---	55
# 13_start-13_end	---	---	55	---	55
#
#  Profesor:  116 116
# 	1	2	3	4	5
# 0_start-0_end	81	---	62	---	89
# 1_start-1_end	81	---	62	---	89
# 2_start-2_end	---	---	---	---	89
# 3_start-3_end	62	---	81	---	89
# 4_start-4_end	62	---	81	---	---
# 5_start-5_end	62	---	81	---	---
#
#  Profesor:  119 119
# 	1	2	3	4	5
# 13_start-13_end	69	---	---	---	---
# 14_start-14_end	69	---	---	---	---
#
#  Profesor:  120 120
# 	1	2	3	4	5
# 11_start-11_end	47	---	---	---	---
# 14_start-14_end	---	---	47	---	---
# 15_start-15_end	---	---	47	---	---
#
#  Profesor:  121 121
# 	1	2	3	4	5
# 11_start-11_end	61	---	61	---	---
# 12_start-12_end	61	---	61	---	---
#
#  Profesor:  122 122
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	53	---
# 14_start-14_end	---	---	---	53	---
#
#  Profesor:  123 123
# 	1	2	3	4	5
# 14_start-14_end	---	49	---	---	49
# 15_start-15_end	---	---	---	---	49
#
#  Profesor:  124 124
# 	1	2	3	4	5
# 0_start-0_end	98	---	98	---	---
# 1_start-1_end	98	---	98	---	---
# 2_start-2_end	98	---	98	---	---
#
#  Profesor:  126 126
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	18	---
# 10_start-10_end	---	18	---	18	---
# 11_start-11_end	---	18	---	---	---
#
#  Profesor:  128 128
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	37
# 1_start-1_end	---	---	---	---	37
# 4_start-4_end	---	37	---	---	---
# 5_start-5_end	---	37	---	---	---
#
#  Profesor:  129 129
# 	1	2	3	4	5
# 9_start-9_end	---	---	4	---	4
# 10_start-10_end	---	---	4	---	4
# 11_start-11_end	---	---	---	---	4
# 12_start-12_end	---	---	4	---	---
# 13_start-13_end	---	4	4	4	---
# 14_start-14_end	---	4	---	4	---
#
#  Profesor:  131 131
# 	1	2	3	4	5
# 0_start-0_end	21	---	---	---	---
# 1_start-1_end	21	---	---	---	---
# 2_start-2_end	21	---	---	---	---
# 3_start-3_end	21	---	---	---	---
# 4_start-4_end	21	---	---	---	---
# 5_start-5_end	21	---	---	---	---
#
#  Profesor:  132 132
# 	1	2	3	4	5
# 12_start-12_end	76	---	---	---	---
# 13_start-13_end	76	---	---	---	---
# 14_start-14_end	76	---	---	---	76
# 15_start-15_end	---	---	---	---	76
#
#  Profesor:  134 134
# 	1	2	3	4	5
# 9_start-9_end	33	---	---	---	---
# 10_start-10_end	33	---	---	---	---
# 11_start-11_end	33	---	---	---	---
# 12_start-12_end	33	---	---	---	---
#
#  Profesor:  135 135
# 	1	2	3	4	5
# 9_start-9_end	72	---	72	---	---
# 10_start-10_end	72	---	72	---	---
#
#  Profesor:  136 136
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	27
# 13_start-13_end	---	---	---	---	27
# 14_start-14_end	---	---	---	---	27
#
#  Profesor:  137 137
# 	1	2	3	4	5
# 13_start-13_end	10	---	10	---	---
# 14_start-14_end	10	65	10	65	---
# 15_start-15_end	10	65	---	65	---
#
#  Profesor:  138 138
# 	1	2	3	4	5
# 2_start-2_end	---	32	---	---	---
# 3_start-3_end	---	32	---	32	32
# 4_start-4_end	---	---	32	32	32
# 5_start-5_end	---	---	32	---	---
# 11_start-11_end	29	---	---	---	---
# 12_start-12_end	29	---	---	---	29
# 13_start-13_end	---	---	---	---	29
#
#  Profesor:  140 140
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	9	---
# 13_start-13_end	9	---	---	9	---
# 14_start-14_end	9	---	---	9	---
#
#  Profesor:  141 141
# 	1	2	3	4	5
# 11_start-11_end	54	---	---	---	54
# 12_start-12_end	54	---	---	---	54
#
#  Profesor:  142 142
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	16
# 1_start-1_end	---	---	---	---	16
# 4_start-4_end	---	---	---	16	16
# 5_start-5_end	---	---	---	16	16
# 9_start-9_end	---	---	---	16	---
# 10_start-10_end	---	---	---	16	---
#
#  Profesor:  145 145
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	30	---
# 1_start-1_end	---	---	---	30	---
# 2_start-2_end	---	---	---	30	---
#
#  Profesor:  146 146
# 	1	2	3	4	5
# 9_start-9_end	5	---	---	---	---
# 10_start-10_end	5	---	---	---	---
# 11_start-11_end	5	---	---	---	---
# 12_start-12_end	5	---	---	---	---
#
#  Profesor:  147 147
# 	1	2	3	4	5
# 9_start-9_end	11	---	---	---	---
# 10_start-10_end	11	---	---	11	---
# 11_start-11_end	11	---	---	11	---
#
#  Profesor:  148 148
# 	1	2	3	4	5
# 0_start-0_end	78	---	78	---	---
# 1_start-1_end	78	---	78	---	---
# 2_start-2_end	---	---	78	---	---
# 11_start-11_end	---	---	55	---	---
# 12_start-12_end	---	---	55	---	55
# 13_start-13_end	---	---	55	---	55
#
#  Profesor:  149 149
# 	1	2	3	4	5
# 2_start-2_end	49	---	---	---	---
# 4_start-4_end	---	---	---	---	49
# 5_start-5_end	---	---	---	---	49
# 9_start-9_end	---	91	---	91	---
# 10_start-10_end	---	91	---	---	---
#
#  Profesor:  150 150
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	79	---
# 4_start-4_end	---	79	---	79	---
# 5_start-5_end	---	79	---	79	---
#
#  Profesor:  151 151
# 	1	2	3	4	5
# 0_start-0_end	---	81	---	---	---
# 1_start-1_end	---	81	---	---	---
# 2_start-2_end	---	81	---	---	---
# 4_start-4_end	---	---	---	---	81
# 5_start-5_end	---	---	---	---	81
# 7_start-7_end	---	40	---	40	---
# 8_start-8_end	---	40	---	40	---
# 9_start-9_end	---	---	---	40	---
#
#  Profesor:  152 152
# 	1	2	3	4	5
# 0_start-0_end	---	22	---	22	---
# 1_start-1_end	---	22	---	22	---
# 2_start-2_end	---	---	---	22	---
# 11_start-11_end	---	26	---	---	---
# 12_start-12_end	---	26	---	---	26
# 13_start-13_end	---	---	---	---	26
# 14_start-14_end	---	---	---	---	26
#
#  Profesor:  156 156
# 	1	2	3	4	5
# 12_start-12_end	---	68	---	68	---
# 13_start-13_end	---	68	---	68	---
#
#  Profesor:  157 157
# 	1	2	3	4	5
# 0_start-0_end	10	---	---	---	---
# 1_start-1_end	10	---	---	---	---
# 3_start-3_end	---	---	10	---	---
# 4_start-4_end	---	---	10	---	---
# 5_start-5_end	---	---	10	---	---
#
#  Profesor:  158 158
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	---	22
# 4_start-4_end	---	22	---	---	22
# 5_start-5_end	---	22	---	---	22
#
#  Profesor:  159 159
# 	1	2	3	4	5
# 1_start-1_end	---	96	---	96	---
# 2_start-2_end	---	96	---	96	---
#
#  Profesor:  160 160
# 	1	2	3	4	5
# 10_start-10_end	---	20	---	---	20
# 11_start-11_end	---	20	---	---	20
#
#  Profesor:  161 161
# 	1	2	3	4	5
# 0_start-0_end	87	---	---	---	---
# 1_start-1_end	87	---	---	---	---
# 2_start-2_end	87	---	87	---	---
# 3_start-3_end	---	---	87	---	---
#
#  Profesor:  162 162
# 	1	2	3	4	5
# 9_start-9_end	---	58	---	---	58
# 10_start-10_end	---	58	---	---	58
# 11_start-11_end	---	---	---	---	58
# 12_start-12_end	---	---	58	---	---
# 13_start-13_end	---	---	58	58	---
# 14_start-14_end	---	---	58	58	---
#
#  Profesor:  163 163
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	76
# 1_start-1_end	---	---	---	---	76
# 2_start-2_end	---	---	---	---	76
# 4_start-4_end	---	76	---	---	---
# 5_start-5_end	---	76	---	---	---
#
#  Profesor:  164 164
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	50	---
# 12_start-12_end	---	50	---	50	---
# 13_start-13_end	---	50	---	---	---
# 14_start-14_end	---	50	---	50	---
# 15_start-15_end	---	50	---	50	---
#
#  Profesor:  165 165
# 	1	2	3	4	5
# 1_start-1_end	---	---	57	57	---
# 2_start-2_end	---	---	57	57	---
# 3_start-3_end	---	---	57	57	---
#
#  Profesor:  167 167
# 	1	2	3	4	5
# 9_start-9_end	---	---	91	---	---
# 10_start-10_end	---	---	91	---	91
#
#  Profesor:  168 168
# 	1	2	3	4	5
# 12_start-12_end	---	44	---	44	---
# 13_start-13_end	---	44	---	44	---

# %% [markdown]
# ## Estadísticas de resultados

# %% [markdown]
# ### Promedios de prioridad

# %%
if not model.Status == GRB.INFEASIBLE and "prioridades" in objectives:
    
    CARGA_HORARIA_TOTAL = np.sum([round(y_dict[p, b].variable.X)
                              for p in profesores_ids
                              for b in bloques_horario_ids
                              ])

    obj = objectives["prioridades"][0].getValue()
    print(obj)
    print("Promedio general de prioridad horaria: ", obj/CARGA_HORARIA_TOTAL)
          

# print("Casos de materias con dias consecutivos: ", int(OBJ2.getValue()/10))
# Out:
# 954.0
# Promedio general de prioridad horaria:  1.394736842105263

# %%
# promedio por profesor:
"""
This script calculates and prints the average workload per professor based on their assigned priorities and time blocks.
Variables:
    profesores (list): List of professor objects, each containing their priorities.
    y_dict (dict): Dictionary mapping professor IDs and time block IDs to Gurobi variables.
    bloques_horario_ids (list): List of time block IDs.
For each professor in the list `profesores`, the script performs the following steps:
1. Initializes a quadratic expression `OBJ_p` to accumulate the weighted priorities.
2. Iterates over the professor's priorities to update `OBJ_p` based on the priority value and corresponding Gurobi variable.
3. Calculates the total workload `CARGA_HORARIA_p` for the professor by summing the relevant Gurobi variables.
4. If the total workload is non-zero, it prints the professor's name, total workload, and the rounded average priority value per workload unit.
5. If the total workload is zero, it prints the professor's name and indicates that they have no workload.

"""
if not model.Status == GRB.INFEASIBLE:
    for p in profesores:

        OBJ_p = gp.QuadExpr()
        # for m in materias:
        #     for pr in p.prioridades:
        #             b = pr.bloque_horario
        #             A = pr.value
        #             OBJ_p += A * w_dict[m.id, p.id].variable * u_dict[m.id, b.id].variable

        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            OBJ_p += A * y_dict[p.id, b.id].variable
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()
        CARGA_HORARIA_p = round(gp.quicksum(y_dict[p.id, b].variable for b in bloques_horario_ids).getValue())

        if CARGA_HORARIA_p != 0:
            print(str(p), "\t", CARGA_HORARIA_p, "\t", round(round(OBJ_p.getValue())/CARGA_HORARIA_p,3))
        else:
            print(str(p), "sin carga horaria")
# Out:
# 3 	 7 	 1.571
# 4 	 8 	 1.0
# 5 	 6 	 1.333
# 6 	 3 	 1.0
# 7 	 4 	 2.0
# 9 	 4 	 1.25
# 11 	 5 	 1.8
# 12 	 5 	 1.4
# 13 	 8 	 1.5
# 14 	 12 	 1.0
# 15 	 12 	 1.083
# 16 	 3 	 1.0
# 17 	 3 	 1.0
# 18 	 6 	 1.333
# 21 	 4 	 3.0
# 26 	 10 	 1.0
# 28 	 4 	 1.0
# 29 	 4 	 1.5
# 30 	 8 	 1.25
# 31 	 5 	 2.0
# 32 	 6 	 1.0
# 33 	 4 	 1.75
# 34 	 4 	 1.25
# 36 	 15 	 1.6
# 37 	 4 	 3.0
# 38 	 5 	 2.6
# 39 	 8 	 1.0
# 42 	 4 	 1.0
# 43 	 6 	 1.833
# 44 	 3 	 1.0
# 47 	 7 	 2.143
# 48 	 5 	 1.4
# 49 	 4 	 1.25
# 50 	 7 	 1.571
# 53 	 5 	 1.0
# 54 	 4 	 2.5
# 55 	 5 	 1.0
# 57 	 4 	 1.0
# 58 	 4 	 2.5
# 59 	 12 	 1.583
# 60 	 4 	 1.0
# 61 	 11 	 1.818
# 62 	 5 	 2.2
# 64 	 5 	 1.2
# 66 	 6 	 1.0
# 68 	 4 	 1.0
# 71 	 10 	 2.0
# 72 	 4 	 1.5
# 74 	 10 	 1.0
# 75 	 12 	 1.0
# 76 	 7 	 1.0
# 77 	 5 	 1.4
# 80 	 4 	 2.25
# 82 	 7 	 1.286
# 84 	 4 	 2.0
# 85 	 10 	 1.0
# 86 	 4 	 2.0
# 87 	 2 	 1.0
# 88 	 3 	 1.0
# 91 	 14 	 1.643
# 92 	 5 	 1.0
# 94 	 3 	 2.0
# 95 	 5 	 1.4
# 97 	 4 	 1.25
# 99 	 2 	 1.5
# 100 	 6 	 1.5
# 101 	 2 	 3.0
# 102 	 9 	 1.0
# 103 	 2 	 2.0
# 104 	 6 	 1.0
# 106 	 5 	 2.8
# 107 	 5 	 2.2
# 108 	 4 	 1.0
# 109 	 5 	 2.0
# 111 	 5 	 1.0
# 112 	 9 	 1.444
# 115 	 10 	 1.0
# 116 	 14 	 1.0
# 119 	 2 	 2.5
# 120 	 3 	 1.667
# 121 	 4 	 1.5
# 122 	 2 	 3.0
# 123 	 3 	 1.0
# 124 	 6 	 1.0
# 126 	 4 	 1.0
# 128 	 4 	 1.0
# 129 	 11 	 2.455
# 131 	 6 	 1.0
# 132 	 5 	 1.0
# 134 	 4 	 1.0
# 135 	 4 	 1.0
# 136 	 3 	 2.0
# 137 	 9 	 1.444
# 138 	 12 	 1.083
# 140 	 5 	 2.0
# 141 	 4 	 1.5
# 142 	 8 	 1.75
# 145 	 3 	 1.0
# 146 	 4 	 1.0
# 147 	 5 	 1.0
# 148 	 10 	 1.0
# 149 	 6 	 1.0
# 150 	 5 	 1.4
# 151 	 10 	 1.0
# 152 	 10 	 2.0
# 156 	 4 	 1.0
# 157 	 5 	 1.0
# 158 	 5 	 1.0
# 159 	 4 	 1.0
# 160 	 4 	 1.0
# 161 	 5 	 1.0
# 162 	 10 	 1.0
# 163 	 5 	 1.0
# 164 	 8 	 1.25
# 165 	 6 	 1.0
# 167 	 3 	 1.333
# 168 	 4 	 2.0

# %%
# # DIAS CLASE POR PROFESOR

# print("DIAS CON CLASE")
# for p in profesores:
#     if p.min_max_dias is not None:
#         print(str(p), ": ", round(DP[p.id].getValue()), p.min_max_dias)

# %%
# HORAS PUENTE

# HP = gp.QuadExpr()
# for g in grupos_reales:
#     HPg = gp.QuadExpr()
#     for d in dias_ids:
#         HPg += gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
#         HPg += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
#         HPg += - 1
#     # print("horas puente grupo", str(g), ": ", HPg.getValue())
#     HP += HPg

# print("Total de horas puente: ", HP.getValue())

# %% [markdown]
# #### Distribucion de prioridades

# %%
# distribucion de prioridades
"""
This script calculates and prints the distribution of priorities and their averages for a given set of professors and their time block priorities.
Variables:
    promedios_prioridad (dict): A dictionary to store the average priority values for each priority level.
    valores_prioridad (dict): A dictionary to store the count of each priority level.
    profesores (list): A list of professor objects, each containing their priority information.
    y_dict (dict): A dictionary containing the decision variables for the optimization model.
Process:
1. Initialize dictionaries to store priority averages and counts.
2. Iterate over each professor and their priorities:
    - Skip if the priority value is 0.
    - Increment the count for the given priority value.
    - Update the average priority value based on the decision variable.
3. Print the count and percentage distribution of each priority level.
4. Print the average priority values and their percentage distribution.

"""

if not model.Status == GRB.INFEASIBLE:
    promedios_prioridad = {}
    valores_prioridad = {}
    for i in range(1,4):
        promedios_prioridad[i] = 0
        valores_prioridad[i] = 0

    for p in profesores:
        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            if A == 0:
                continue
            valores_prioridad[A] += 1
            # for m in materias:
            #     promedios_prioridad[A] += round(w_dict[m.id, p.id].variable.X * u_dict[m.id, b.id].variable.X)
            promedios_prioridad[A] += round(y_dict[p.id, b.id].variable.X)

    print(valores_prioridad)
    total = np.sum([valores_prioridad[i] for i in valores_prioridad])
    print(*[str(i) + ": " + str(round(valores_prioridad[i]/total*100))+"%" for i in valores_prioridad], sep=", ")

    print(promedios_prioridad)
    total = np.sum([promedios_prioridad[i] for i in promedios_prioridad])
    if total != 0:
        print(*[str(i) + ": " + str(round(promedios_prioridad[i]/total*100))+"%" for i in promedios_prioridad], sep=", ")
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()

        # if CARGA_HORARIA_p != 0:
        #     print(str(p), ": ", OBJ_p.getValue()/CARGA_HORARIA_p)
        # else:
        #     print(str(p), "sin carga horaria")
# Out:
# {1: 3179, 2: 442, 3: 424}
# 1: 79%, 2: 11%, 3: 10%
# {1: 505, 2: 88, 3: 91}
# 1: 74%, 2: 13%, 3: 13%

# %% [markdown]
# ### Ocupacion de salones

# %%
# nivel de ocupacion
if not model.Status == GRB.INFEASIBLE:
    niveles = {}

    for b_id in bloques_horario:
        salones_ocupados = int(gp.quicksum(u_dict[m, b_id].variable for m in materias_ids).getValue())
        nivel = int(salones_ocupados/num_salones*100)
        # print(str(bloques_horario[b_id]), ": ", salones_ocupados,",", str(nivel) + "%")
        niveles[b_id] = nivel

    print_timetable_salones(dias, horarios, niveles)
# Out:
# 		1	2	3	4	5
# ··········································································································
# 0_start-0_end	61%	61%	46%	53%	92%
# 1_start-1_end	76%	84%	69%	92%	92%
# 2_start-2_end	69%	76%	76%	92%	76%
# 3_start-3_end	69%	76%	69%	76%	76%
# 4_start-4_end	69%	92%	61%	76%	69%
# 5_start-5_end	69%	76%	46%	61%	69%
# 6_start-6_end	0%	0%	7%	7%	7%
# 7_start-7_end	15%	30%	15%	23%	15%
# 8_start-8_end	15%	30%	15%	30%	23%
# 9_start-9_end	84%	61%	38%	69%	53%
# 10_start-10_end	76%	76%	46%	84%	92%
# 11_start-11_end	84%	69%	69%	69%	69%
# 12_start-12_end	69%	92%	92%	92%	69%
# 13_start-13_end	76%	92%	76%	100%	69%
# 14_start-14_end	76%	61%	53%	76%	69%
# 15_start-15_end	23%	23%	15%	38%	23%
