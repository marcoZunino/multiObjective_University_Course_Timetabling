# %% [markdown]
# Imports

# %%
from gurobipy import *
import numpy as np
import pandas as pd

from db_manager import *
from load_data import *
from printing import *

# %%
# clases
from entities import *
from variables import *

# %%
# print(*[m.no_super for m in materias], sep="\n")

# %% [markdown]
# # Cargar datos

# %% [markdown]
# ## (1) Datos / Constantes

# %%
import json

def read_json_instance(instance_path):
    
    with open(instance_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    dias = [Dia(id, str(id)) for id in data["days"]]
    dias.sort(key=lambda v: v.id)

    turnos = [str(t) for t in data["shifts"]]
    turnos.sort()

    horarios = []
    for h in data["times"]:
        inicio = str(h["id"]) + "_start"
        fin = str(h["id"]) + "_end"
        ts = [str(tur) for tur in h["shifts"]]
        ts_excepcional = [str(tur) for tur in h["exceptional_shifts"]]
        horarios.append(Horario(h["id"], inicio, fin, ts, ts_excepcional))
    horarios.sort(key=lambda v: v.id)

    bloques_horario: dict[tuple, BloqueHorario] = {}
    for dia in dias:
        for horario in horarios:
            bloques_horario[(dia.id, horario.id)] = BloqueHorario(dia, horario)

    grupos = []
    for g in data["groups"]:
        grupos.append(Grupo(g["id"], g["year"], str(g["shift"]), particion=g["id"]))
    grupos.sort(key=lambda v: v.id)

    profesores = []
    for p in data["professors"]:
        nombre = str(p["id"])
        min_max_dias = "min" if p["min_max_days"] == True else "max" if p["min_max_days"] == False else None
        prof = Profesor(p["id"], nombre, min_max_dias, nombre, cursos_simultaneos = p["simult_courses"])
        for mat in p["num_groups_per_subject"]:
            prof.lista_materias.append({"nombre_materia" : str(mat["subject_id"]), "grupos_max" : mat["num_groups"]})
        prof.set_prioridades(bloques_horario, [(
                             (dtp["day"], dtp["time"]),  dtp["preference"]
                             )  for dtp in p["availability"] ])
        profesores.append(prof)
    profesores.sort(key=lambda v: v.id)

    materias = []
    for m in data["courses"]:
        nombre = str(m["subject_id"])
        gs = [g for g in grupos if g.id in m["groups"]]
        profs = [p for p in profesores if p.id in m["available_professors"]]
        t_p = "teo" if m["theo_prac"] == True else "prac" if m["theo_prac"] == False else None
        materias.append(Materia(m["id"], nombre, nombre, m["num_hours"], m["num_days"], gs, profs, m["num_profs"], m["elective"], t_p, m["consecutive_days"], m["no_overlap"], m["elective_no_overlap"]))
    materias.sort(key=lambda v: v.id)

    superposicion: dict[tuple, Superposicion] = {}
    for m1 in materias:
        for m2 in materias:
            s = (m1.id in m2.no_super) or (m2.id in m1.no_super)
            superposicion[(m1.id, m2.id)] = Superposicion(1 if s else 0, m1, m2)

    superposicion_electivas: dict[tuple, Superposicion] = {}
    for m1 in materias:
        for m2 in materias:
            s = (m1.id in m2.elec_no_super) or (m2.id in m1.elec_no_super)
            superposicion_electivas[(m1.id, m2.id)] = Superposicion(1 if s else 0, m1, m2)


    return dias, turnos, horarios, bloques_horario, grupos, materias, profesores, superposicion, superposicion_electivas



instance = "../instances/instance_2026sem1.json"
dias, turnos, horarios, bloques_horario, grupos, materias, profesores, superposicion, superposicion_electivas = read_json_instance(instance)

# %%
dias_ids = [d.id for d in dias]
DIAS = dias

horarios_ids = [h.id for h in horarios]
HORARIOS = horarios

bloques_horario_ids = [b for b in bloques_horario]
BLOQUES_HORARIO = bloques_horario

profesores_ids = [p.id for p in profesores]
PROFESORES = profesores

grupos_ids = [g.id for g in grupos]
GRUPOS = grupos

anios = list(set([g.anio for g in grupos if g.anio != None]))  # anios
ANIOS = anios

materias_ids = [m.id for m in materias]
MATERIAS = materias

SUPERPOSICION = superposicion
SUPERPOSICION_ELECTIVAS = superposicion_electivas

# %%
# # print(*[str(g) for g in grupos], sep="\n")
# print(*[m.profesores for m in materias], sep="\n")

# %%
print_prioridades(dias, horarios, profesores)
# Out:
#  Profesor: 3 3  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	3	3	-
# 1_start-1_end	-	-	1	1	-
# 2_start-2_end	-	-	1	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	2	2	-	-	2
# 10_start-10_end	1	1	-	-	1
# 11_start-11_end	1	1	-	-	1
# 12_start-12_end	3	3	-	-	3
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 4 4  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	-	-	1
# 2_start-2_end	1	1	-	-	1
# 3_start-3_end	1	1	-	-	1
# 4_start-4_end	1	1	-	-	1
# 5_start-5_end	1	1	-	-	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	1	-	-	1
# 8_start-8_end	-	1	-	-	1
# 9_start-9_end	-	1	-	-	1
# 10_start-10_end	-	1	-	-	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 5 5  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 6 6  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	3	-	3	-
# 12_start-12_end	1	1	-	1	-
# 13_start-13_end	1	1	-	1	-
# 14_start-14_end	1	1	-	1	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 7 7  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	3
# 11_start-11_end	-	1	-	1	3
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	2	-	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 9 9  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	2	-	2	-
# 14_start-14_end	-	3	-	3	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 11 11  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	3	3	3	3	3
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	2	2	2	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 12 12  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	2	2	2	-	3
# 3_start-3_end	1	1	1	-	1
# 4_start-4_end	1	1	1	-	1
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 13 13  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	3	-	3	-
#
#  Profesor: 14 14  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	-	-
# 1_start-1_end	-	1	-	-	-
# 2_start-2_end	-	1	-	-	-
# 3_start-3_end	-	1	-	-	-
# 4_start-4_end	1	1	1	-	-
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	1	1	1	-	-
# 7_start-7_end	1	1	1	-	-
# 8_start-8_end	1	1	1	-	-
# 9_start-9_end	1	1	1	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 15 15  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	1	-	1	-
# 7_start-7_end	-	1	-	1	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	1	-	2	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 16 16  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 17 17  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	1	-	1
# 1_start-1_end	-	-	1	-	1
# 2_start-2_end	-	-	1	-	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 18 18  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 21 21  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 26 26  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	-	1	-
# 12_start-12_end	1	1	-	1	-
# 13_start-13_end	1	1	-	1	-
# 14_start-14_end	1	1	-	1	-
# 15_start-15_end	1	1	-	1	-
#
#  Profesor: 28 28  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 29 29  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	1	-	1	-	-
# 11_start-11_end	1	-	1	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 30 30  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	2	-	2	2
# 11_start-11_end	-	1	-	1	1
# 12_start-12_end	-	1	-	1	1
# 13_start-13_end	-	1	-	1	1
# 14_start-14_end	-	1	-	1	1
# 15_start-15_end	-	3	-	3	3
#
#  Profesor: 31 31  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	2	2	2	2	2
# 4_start-4_end	2	2	2	2	2
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 32 32  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	2	2	2	-
# 3_start-3_end	-	2	2	2	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	-	-
# 12_start-12_end	1	1	1	-	-
# 13_start-13_end	1	1	1	-	-
# 14_start-14_end	1	1	1	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 33 33  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	3	-	3	-
# 3_start-3_end	-	1	-	1	1
# 4_start-4_end	-	1	-	1	1
# 5_start-5_end	-	2	-	2	2
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 34 34  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 36 36  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	1	-	1
# 3_start-3_end	-	-	1	-	1
# 4_start-4_end	-	-	1	-	1
# 5_start-5_end	-	-	3	-	2
# 6_start-6_end	-	-	3	-	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	2	-	3
# 10_start-10_end	-	-	2	-	3
# 11_start-11_end	-	-	1	-	1
# 12_start-12_end	-	-	1	-	1
# 13_start-13_end	-	-	1	-	1
# 14_start-14_end	-	-	3	-	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 37 37  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	3	1	3	1	3
# 9_start-9_end	3	1	2	1	3
# 10_start-10_end	3	1	2	1	3
# 11_start-11_end	3	1	2	1	3
# 12_start-12_end	3	2	2	2	3
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 38 38  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	2	3	2	3
# 3_start-3_end	3	2	3	2	3
# 4_start-4_end	3	2	3	2	3
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	3
# 8_start-8_end	1	1	1	1	3
# 9_start-9_end	1	1	1	1	3
# 10_start-10_end	1	1	1	1	3
# 11_start-11_end	2	1	1	1	-
# 12_start-12_end	2	1	1	1	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 39 39  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 42 42  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	2	2	2	2	2
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	2	2	2	2	2
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	2	2	2	-	2
# 12_start-12_end	3	3	3	-	3
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 43 43  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	2	2	2	2	2
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 44 44  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 47 47  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	3	-	3
# 9_start-9_end	-	-	3	-	3
# 10_start-10_end	-	-	1	-	1
# 11_start-11_end	-	-	1	-	1
# 12_start-12_end	-	-	3	-	3
# 13_start-13_end	-	-	3	-	3
# 14_start-14_end	-	-	3	-	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 48 48  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	3	3	3	3	3
# 11_start-11_end	2	2	2	2	2
# 12_start-12_end	1	2	2	2	1
# 13_start-13_end	1	2	2	2	1
# 14_start-14_end	1	2	2	2	1
# 15_start-15_end	2	2	2	2	2
#
#  Profesor: 49 49  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 50 50  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	2	2	2	3
# 3_start-3_end	-	3	3	3	3
# 4_start-4_end	-	3	3	3	3
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	2	1	1	1	-
# 7_start-7_end	2	1	1	1	-
# 8_start-8_end	2	1	1	1	-
# 9_start-9_end	2	2	2	2	-
# 10_start-10_end	3	3	3	3	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 53 53  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 54 54  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 55 55  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	3	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 57 57  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 58 58  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	3	3	3	-
# 10_start-10_end	2	2	-	2	-
# 11_start-11_end	1	1	-	1	-
# 12_start-12_end	2	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 59 59  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	3	-	3	-
# 3_start-3_end	-	2	-	2	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	2	-	2	-
# 7_start-7_end	-	1	-	1	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	3	-	3	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 60 60  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	3	3	3	3
# 13_start-13_end	-	1	1	1	1
# 14_start-14_end	-	1	1	1	1
# 15_start-15_end	-	1	1	1	1
#
#  Profesor: 61 61  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	3	3	3	3	3
# 1_start-1_end	3	3	3	3	3
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 62 62  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	-	2	2	2
# 3_start-3_end	3	-	1	1	1
# 4_start-4_end	3	-	1	1	1
# 5_start-5_end	3	-	2	2	2
# 6_start-6_end	3	-	3	3	3
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 64 64  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	2	2	2	2	2
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 66 66  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	1	1	1	1	-
# 13_start-13_end	2	1	1	1	-
# 14_start-14_end	3	2	2	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 68 68  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 71 71  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	2	1	1
# 1_start-1_end	2	1	2	1	1
# 2_start-2_end	-	3	3	2	2
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	-	3	-	2
# 12_start-12_end	1	1	1	1	2
# 13_start-13_end	1	1	1	1	2
# 14_start-14_end	1	1	1	1	-
# 15_start-15_end	-	2	-	2	-
#
#  Profesor: 72 72  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	-	1	-
# 1_start-1_end	1	2	-	1	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 74 74  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 75 75  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	1	1	1	-
# 4_start-4_end	-	1	1	1	-
# 5_start-5_end	-	1	1	1	-
# 6_start-6_end	-	1	1	1	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 76 76  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 77 77  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	2	2	2	-
# 1_start-1_end	-	2	2	2	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	1	1	1	-
# 4_start-4_end	-	1	1	1	-
# 5_start-5_end	-	1	1	1	-
# 6_start-6_end	-	1	1	1	-
# 7_start-7_end	-	1	1	1	-
# 8_start-8_end	-	1	1	1	-
# 9_start-9_end	-	1	1	1	-
# 10_start-10_end	-	1	1	1	-
# 11_start-11_end	-	1	1	1	-
# 12_start-12_end	-	1	1	1	-
# 13_start-13_end	-	1	1	1	-
# 14_start-14_end	-	1	1	1	-
# 15_start-15_end	-	2	2	2	-
#
#  Profesor: 80 80  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	2	1	2	-
# 9_start-9_end	1	2	1	2	-
# 10_start-10_end	1	2	1	2	-
# 11_start-11_end	1	2	1	2	-
# 12_start-12_end	1	2	1	2	-
# 13_start-13_end	2	2	2	2	-
# 14_start-14_end	3	3	3	3	-
# 15_start-15_end	3	3	3	3	-
#
#  Profesor: 82 82  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	2	-	2	1
# 1_start-1_end	1	2	-	2	1
# 2_start-2_end	1	2	-	2	1
# 3_start-3_end	2	-	-	-	2
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	2	1
# 12_start-12_end	-	-	-	2	1
# 13_start-13_end	-	-	-	2	1
# 14_start-14_end	-	-	-	2	1
# 15_start-15_end	-	-	-	2	1
#
#  Profesor: 84 84  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	3	3	-
# 2_start-2_end	-	-	3	3	-
# 3_start-3_end	3	-	2	2	-
# 4_start-4_end	3	-	2	2	-
# 5_start-5_end	2	-	1	1	-
# 6_start-6_end	2	-	1	1	-
# 7_start-7_end	1	-	1	1	-
# 8_start-8_end	1	1	1	1	-
# 9_start-9_end	1	1	1	1	-
# 10_start-10_end	1	1	1	1	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	2	-	2	-
# 13_start-13_end	-	2	-	2	-
# 14_start-14_end	-	3	-	3	-
# 15_start-15_end	-	3	-	3	-
#
#  Profesor: 85 85  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	1	1	-
# 2_start-2_end	1	1	1	1	-
# 3_start-3_end	1	1	1	1	-
# 4_start-4_end	1	1	1	1	-
# 5_start-5_end	1	1	1	1	-
# 6_start-6_end	1	1	1	1	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 86 86  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	2	1	3
# 1_start-1_end	2	1	2	1	3
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 87 87  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	-	1	1
# 1_start-1_end	1	1	-	1	1
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	1	-	1	1
# 13_start-13_end	1	1	-	1	1
# 14_start-14_end	1	1	-	1	1
# 15_start-15_end	1	1	-	1	1
#
#  Profesor: 88 88  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	1	-	1	-
#
#  Profesor: 91 91  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	-	1	-	1
# 1_start-1_end	1	-	1	-	1
# 2_start-2_end	1	-	1	-	1
# 3_start-3_end	1	-	1	-	1
# 4_start-4_end	1	-	1	-	1
# 5_start-5_end	1	-	1	-	1
# 6_start-6_end	2	-	2	-	2
# 7_start-7_end	2	-	2	-	2
# 8_start-8_end	3	-	3	-	3
# 9_start-9_end	3	-	3	-	3
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 92 92  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 94 94  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	3	3	3	2
# 10_start-10_end	1	2	1	2	2
# 11_start-11_end	1	2	1	2	2
# 12_start-12_end	1	2	1	2	2
# 13_start-13_end	1	2	1	2	3
# 14_start-14_end	2	2	2	2	3
# 15_start-15_end	2	2	2	2	3
#
#  Profesor: 95 95  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	3	2	2	2	1
# 10_start-10_end	3	3	3	3	1
# 11_start-11_end	-	-	-	-	1
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 97 97  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	3	3	3	3
# 12_start-12_end	2	1	2	2	3
# 13_start-13_end	2	1	1	1	3
# 14_start-14_end	2	1	1	1	3
# 15_start-15_end	3	2	2	2	-
#
#  Profesor: 99 99  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	1	1	1	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	2	2	2	2	-
# 13_start-13_end	-	3	3	3	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 100 100  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 101 101  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	1	-	-	-
# 11_start-11_end	-	1	-	-	-
# 12_start-12_end	-	3	-	-	-
# 13_start-13_end	-	3	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 102 102  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	3	3	-	-
# 1_start-1_end	-	3	-	3	3
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 103 103  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	2
# 1_start-1_end	1	1	1	1	2
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 104 104  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	1	-
# 1_start-1_end	-	1	-	1	-
# 2_start-2_end	-	1	-	1	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 106 106  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	2	-	2	-
# 12_start-12_end	-	3	-	3	-
# 13_start-13_end	-	3	-	3	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 107 107  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	2	2	2	2	2
# 15_start-15_end	2	2	2	2	2
#
#  Profesor: 108 108  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 109 109  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	1	2	1
# 3_start-3_end	1	-	1	2	1
# 4_start-4_end	2	2	2	2	3
# 5_start-5_end	2	2	2	2	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 111 111  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	1	-	1	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 112 112  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	2	2	2	2
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	2	1	1	1	2
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	2	2	2	1
# 11_start-11_end	2	2	2	2	2
# 12_start-12_end	2	2	2	2	2
# 13_start-13_end	2	3	3	3	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 115 115  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 116 116  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	-	1	-	1
# 1_start-1_end	1	-	1	-	1
# 2_start-2_end	1	-	1	-	1
# 3_start-3_end	1	-	1	-	1
# 4_start-4_end	1	-	1	-	1
# 5_start-5_end	1	-	1	-	2
# 6_start-6_end	1	-	1	-	2
# 7_start-7_end	2	-	2	-	-
# 8_start-8_end	2	-	2	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	3	-	3	-	-
# 11_start-11_end	3	-	3	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 119 119  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	2	2	2	2	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	1	1	1	1	-
# 13_start-13_end	2	2	2	2	-
# 14_start-14_end	3	3	3	3	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 120 120  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	-	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	2	-	2	-	-
#
#  Profesor: 121 121  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	1	1	2
# 12_start-12_end	2	1	1	1	2
# 13_start-13_end	2	1	1	1	2
# 14_start-14_end	2	1	1	1	2
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 122 122  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	2	2	2	2	2
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 123 123  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 124 124  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	-	-
# 1_start-1_end	1	1	1	-	-
# 2_start-2_end	1	1	1	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 126 126  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	2	1	2	1	-
# 10_start-10_end	2	1	2	1	-
# 11_start-11_end	2	1	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 128 128  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 129 129  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	3	3	3	3
# 9_start-9_end	-	3	3	3	3
# 10_start-10_end	-	1	1	1	1
# 11_start-11_end	-	1	1	1	1
# 12_start-12_end	-	3	3	3	3
# 13_start-13_end	-	3	3	3	3
# 14_start-14_end	-	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 131 131  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	-
# 5_start-5_end	1	1	1	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 132 132  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	-	-	1
# 12_start-12_end	1	-	-	-	1
# 13_start-13_end	1	-	-	-	1
# 14_start-14_end	1	-	-	-	1
# 15_start-15_end	1	-	-	-	1
#
#  Profesor: 134 134  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 135 135  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	2
# 7_start-7_end	1	-	1	-	2
# 8_start-8_end	1	-	1	-	2
# 9_start-9_end	1	-	1	-	-
# 10_start-10_end	1	-	1	-	-
# 11_start-11_end	1	-	1	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 136 136  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	-	-	-	2
# 13_start-13_end	1	-	-	-	2
# 14_start-14_end	1	-	-	-	2
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 137 137  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	1	1	1	3	1
# 14_start-14_end	1	1	1	3	1
# 15_start-15_end	1	1	1	3	1
#
#  Profesor: 138 138  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 140 140  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	2	2	1	2	1
# 13_start-13_end	2	2	1	2	1
# 14_start-14_end	2	2	1	2	1
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 141 141  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	1	-	1
# 1_start-1_end	-	-	1	-	1
# 2_start-2_end	3	3	2	2	-
# 3_start-3_end	3	3	2	2	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	1	-	2
# 12_start-12_end	1	-	1	-	2
# 13_start-13_end	-	-	3	-	-
# 14_start-14_end	-	-	3	-	-
# 15_start-15_end	-	-	3	-	-
#
#  Profesor: 142 142  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	2
# 1_start-1_end	-	-	-	-	2
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	1	1
# 5_start-5_end	-	-	-	1	1
# 6_start-6_end	-	-	-	1	1
# 7_start-7_end	-	1	-	2	1
# 8_start-8_end	-	1	-	2	1
# 9_start-9_end	-	-	-	3	1
# 10_start-10_end	-	-	-	3	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 145 145  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	1	1	1
# 1_start-1_end	2	1	1	1	1
# 2_start-2_end	2	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 146 146  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 147 147  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 148 148  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 149 149  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	-
# 3_start-3_end	1	1	1	1	-
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	-
# 10_start-10_end	1	1	1	1	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 150 150  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	3	3	-	3	3
# 2_start-2_end	2	2	-	2	2
# 3_start-3_end	1	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	2	2	2	2	2
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 151 151  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	-	-
# 1_start-1_end	-	1	-	-	-
# 2_start-2_end	-	1	-	1	1
# 3_start-3_end	-	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	1	1	-	1	1
# 6_start-6_end	1	1	-	1	1
# 7_start-7_end	1	1	-	1	1
# 8_start-8_end	1	1	-	1	1
# 9_start-9_end	1	-	-	1	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 152 152  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	3	3	1	2
# 1_start-1_end	1	3	3	1	2
# 2_start-2_end	-	3	3	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	1	3	3
# 12_start-12_end	2	1	1	3	3
# 13_start-13_end	2	1	1	3	3
# 14_start-14_end	2	1	1	3	3
# 15_start-15_end	2	1	1	3	3
#
#  Profesor: 156 156  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	2	2	2	2	2
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 157 157  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 158 158  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 159 159  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 160 160  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 161 161  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 162 162  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 163 163  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 164 164  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	2	-	2	-
#
#  Profesor: 165 165  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	1	1	1	-
# 4_start-4_end	-	1	1	1	-
# 5_start-5_end	-	1	1	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 167 167  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	3	3	2
# 3_start-3_end	1	-	1	1	1
# 4_start-4_end	1	-	1	1	1
# 5_start-5_end	1	-	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	1	-	1	1	1
# 8_start-8_end	-	-	1	1	1
# 9_start-9_end	-	-	1	1	2
# 10_start-10_end	-	-	1	1	2
# 11_start-11_end	-	-	1	1	-
# 12_start-12_end	-	-	2	2	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 168 168  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	1	3	1	3
# 12_start-12_end	3	1	3	1	3
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-

# %%
print("Grupos:", len(grupos))
# print([str(i) for i in grupos])
print("Materias:", len(materias))
# print([str(i) for i in materias])
print("Profesores:", len(profesores))
# print([str(i) for i in profesores])
# Out:
# Grupos: 29
# Materias: 165
# Profesores: 117

# %% [markdown]
# # Formulacion

# %% [markdown]
# ## (2) Variables
#
#
# $$ u_{mb} \in \{0,1\} $$
#
#     m: materia
#     b: bloque horario = [dh]: dia y hora
#
# $$ v_{md} \in \{0,1\} $$
#
#     m: materia
#     d: dia
#
# $$ w_{mp} \in \{0,1\} $$
#
#     m: materia
#     p: profesor
#
#
# $$ x_{gb} \in \{0,1\} $$
#
#     g: grupo
#     b: bloque horario = [dh]: dia y hora
#
# $$ y_{pb} \in \{0,1\} $$
#
#     p: profesor
#     b: bloque horario = [dh]: dia y hora
#
# $$ z_{pd} \in \{0,1\} $$
#
#     p: profesor
#     d: dia

# %%
print(len(materias))
print(len(bloques_horario))
# Out:
# 165
# 80

# %% [markdown]
# ## (3) Restricciones

# %% [markdown]
# ### (3.1) Materias

# %% [markdown]
# #### (3.1.1) superposicion (redundante con la definicion de la variable x)
# $$ \sum_{b} \sum_{m, m'}{u_{mb} \times S_{m,m'} \times u_{m'b}} = 0 $$

# %%
"""
    This code defines constraints to ensure that no two subjects (materias) overlap
    in the same time block (bloque horario).
    Constraints:
        1. For each time block (b) in bloques_horario_ids, the sum of the product of the decision variables 
        (u_dict[m1, b].variable and u_dict[m2, b].variable) and the overlap value (superposicion[(m1, m2)].value)
        for all pairs of subjects (m1, m2) must be equal to 0.
"""

def constr_superposicion(model, u_dict):

    model.addConstrs(gp.quicksum(u_dict[m1, b].variable * superposicion[(m1, m2)].value * u_dict[m2, b].variable
                            for m1 in materias_ids for m2 in materias_ids)
                == 0 for b in bloques_horario_ids)

# %% [markdown]
# #### (3.1.2) cubrir carga horaria para cada materia
# $$ \sum_b{u_{mb}} = C_m $$
#
#     para todo m (c_m: carga horaria)

# %%
def constr_carga_horaria(model, u_dict):
    for m in materias:
        model.addConstr(gp.quicksum(u_dict[m.id, b].variable for b in bloques_horario_ids) == m.carga_horaria)

# %% [markdown]
# #### (3.1.3) particion de horas por materia

# %% [markdown]
# ##### (3.1.3.1) fijar cantidad de dias por materia
#
# $$ \sum_d {v_{md}} = D_m $$
#
#     para todo m

# %%
def constr_dias_materia(model, v_dict):
    for m in materias:
        model.addConstr(gp.quicksum(v_dict[m.id, d].variable for d in dias_ids) == m.cantidad_dias)

# %% [markdown]
# ##### (3.1.3.2) fijar maximo y minimo de horas por dia
#
# $$ v_{md} \times {H_{MIN}}_m \leq \sum_h {u_{mdh}} \leq v_{md} \times {H_{MAX}}_m $$
#
#     para todo m, d

# %%
def constr_max_min_horas(model, u_dict, v_dict):

    for m in materias:

        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        <= m.horas_max() * v_dict[m.id,d].variable for d in dias_ids)
        
        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        >= m.horas_min() * v_dict[m.id,d].variable for d in dias_ids)

# %% [markdown]
# ##### (3.1.3.3) fijar materia a turno de horarios
#
# $$ u_{mb} = 0 $$
#
#     para todo b fuera de m.turnos
#     para todo m

# %%
def constr_turnos_materia(model, u_dict):

    for m in materias:
        no_bloques_materia_ids = [b for b in bloques_horario if b not in bloques_horario_materia(m, bloques_horario)]
        model.addConstrs(u_dict[m.id, b].variable == 0 for b in no_bloques_materia_ids)

# %% [markdown]
# #### (3.1.4) horas consecutivas dentro de un dia
#
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} = v_{md} $$
#     para todo m, d

# %%
def constr_horas_consecutivas(model, u_dict, v_dict):

    model.addConstrs(gp.quicksum(u_dict[(m,(d,h))].variable for h in horarios_ids)
                 - gp.quicksum(u_dict[(m,(d,h))].variable * u_dict[(m,(d,h+1))].variable for h in horarios_ids[0:-1])
                 == v_dict[m, d].variable for m in materias_ids for d in dias_ids)

# %% [markdown]
# Alternativa:
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} \leq 1 $$
#     para todo m, d

# %% [markdown]
# #### (3.1.5) evitar dias consecutivos para una misma materia
#
# $$ \sum_m \sum_d {v_{m(d)} · v_{m(d+1)}} = 0 $$

# %%
mats_dias_consecutivos = [mat for mat in materias if mat.dias_consecutivos]

def constr_dias_consecutivos(model, v_dict):

    model.addConstrs(gp.quicksum(v_dict[m,d].variable * v_dict[m,d+1].variable for d in dias_ids[0:-1]) == 0
                 for m in [mat.id for mat in materias if not mat in mats_dias_consecutivos])

# %% [markdown]
# ### (3.2) Profesores

# %% [markdown]
# #### (3.2.1) indisponibilidad
#
# $$ \sum_m w_{mp} \times u_{mb} = 0 $$
#
#     para todo p sin disponibilidad en b

# %%
def constr_no_disponible_profesor(model, u_dict, w_dict):
    for m in materias:
        for p in m.profesores:
            for b in p.no_disponible:
                model.addConstr(u_dict[m.id, b.id].variable * w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# #### (3.2.2) unica materia por profesor para un mismo bloque horario
#
# $$ \sum_{m} {w_{mp} \times u_{mb}} \leq 1 $$
#
#     para todo b, p

# %% [markdown]
# REDUNDANTE CON DEFINICION DE y_pb

# %%
p_grupos_simultaneos = [p.nombre for p in profesores if p.cursos_simultaneos]

def constr_unica_materia_profesor(model, u_dict, w_dict):

    for p in [p for p in profesores if p.nombre not in p_grupos_simultaneos]:
        model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids)
                     <= 1 for b in bloques_horario_ids)
        
    # caso particular
    for p in [p for p in profesores if p.nombre in p_grupos_simultaneos]:
        model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids)
                     <= 2 for b in bloques_horario_ids)

# %% [markdown]
# #### (3.2.3) profesores por materia

# %% [markdown]
# ##### (3.2.3.1) limitar profesores a lista
#
# $$ w_{mp} = 0 $$
#
#     para todo p not in m.lista_profesores
#     para todo m

# %%
def constr_limitar_profesores_materia(model, w_dict):
    
    for m in materias:
        for p in profesores:
            if p not in m.profesores:
                model.addConstr(w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# ##### (3.2.3.2) cantidad de profesores para una misma materia
#
# $$ \sum_p {w_{mp}} = P_m $$
#
#     para todo m

# %%
def constr_cantidad_profesores(model, w_dict):
    for m in materias:
        model.addConstr(gp.quicksum(w_dict[m.id, p].variable for p in profesores_ids) == m.cantidad_profesores)

# %% [markdown]
# #### (3.2.4) carga horaria por docente: limitar la cantidad de materias por profesor
#
#
# $$ \sum_m {w_{mp}} \leq K_p $$
#
#     para todo p

# %%
# separar por nombre de materia
def constr_grupos_max_profesor(model, w_dict):
    for p in profesores:
        for l in p.lista_materias:
            mats = search_materias_by_nombre(materias, l["nombre_materia"]) # subject_id
            if len(mats) > 0:
                model.addConstr(gp.quicksum(w_dict[m.id, p.id].variable for m in mats) <= l["grupos_max"])

# %% [markdown]
# #### (3.2.5) definicion de variable "y" (asignacion horario-profesor)
#
# $$ y_{pb} = \sum_m{u_{mb}·w_{mp}} $$
#
# $$ y_{pb} = \text{OR}_m \{u_{mb}·w_{mp}\} $$
#
#     para todo p, b

# %%
def constr_definir_y(model, y_dict, u_dict, w_dict):

    for p in profesores:
        uw_vars = {} # variable auxiliar = u_mb·w_mp
        mats_p = materias_profesor(p, materias)
        for m in mats_p:
            # for b_id in bloques_horario_materia(m, bloques_horario):
            for b_id in bloques_horario_ids:
                uw_vars[m.id,b_id] = model.addVar(vtype=GRB.INTEGER, name=str(m)+str(b_id)+str(p)+"_uw")
                model.addConstr(uw_vars[m.id,b_id] == u_dict[m.id,b_id].variable * w_dict[m.id,p.id].variable)
        
        mats_p_ids = [m.id for m in mats_p]
        model.addConstrs(y_dict[p.id,b_id].variable ==
                     gp.or_(uw_vars[m_id,b_id] for m_id in mats_p_ids)
                     for b_id in bloques_horario_ids)
    
    # model.addConstrs(y_dict[p, b].variable ==
    #              gp.quicksum(u_dict[m,b].variable * w_dict[m,p].variable for m in materias_ids)
    #              for b in bloques_horario_ids for p in profesores_ids)

# %% [markdown]
# #### (3.2.6) definicion de variable "z" (para dias con clase por profesor)
#
# $$ z_{pd} = OR_h{y_{p(dh)}} $$
#
#     para todo p, d

# %%
def constr_definir_z(model, z_dict, y_dict):
    
    model.addConstrs(z_dict[p,d].variable ==
                gp.or_(y_dict[p,(d,h)].variable for h in horarios_ids)
                for p in profesores_ids for d in dias_ids)

# %% [markdown]
# ### (3.3) Restricciones externas

# %% [markdown]
# #### (3.3.1) cantidad de salones
#
# $$ \sum_{m} {u_{mb}} \leq K $$
#
#     para todo b

# %%
K = 13      # 13 salones en este caso

def constr_cantidad_salones(model, u_dict):
    model.addConstrs(gp.quicksum(u_dict[m, b].variable for m in materias_ids) <= K for b in bloques_horario_ids)

# %% [markdown]
# #### (3.3.2) restricciones ad hoc

# %% [markdown]
# #### (3.3.3) practico despues del teorico
#
# $$ \max_b\{(-b)*u_{mb}\} > \max_b\{(-b)*u_{m'b}\} $$
#
#     para todo par (teorico, practico) =  (m, m')

# %%
def constr_teo_prac(model, u_dict):

    """
    Variables:
        teo (list): Array containing IDs of theoretical subjects.
        prac (list): Array containing IDs of practical subjects.
        vars1erHora (dict): Dictionary mapping subject IDs to Gurobi integer variables representing the first hour.
        scaled_u_dict (dict): Dictionary mapping tuples of subject IDs and block IDs to scaled Gurobi integer variables.

    Functions:
        search_materias_by_nombre(materias, nombre): Searches for subjects by name in the given list of subjects.

    Workflow:
    1. Populate `teo` and `vars1erHora` with IDs and variables for theoretical subjects.
    2. Populate `prac` and `vars1erHora` with IDs and variables for practical subjects.
    3. Create scaled variables `scaled_u_dict` for each subject and block combination.
    4. Add constraints to the model to ensure that `vars1erHora` variables are the maximum of the scaled variables.
    5. Add constraints to ensure that the first hour of theoretical subjects is greater than or equal to the first hour of practical subjects if the lengths of `teo` and `prac` are equal.


    """
    teo = []    # array con IDS de materias de teorico
    prac = []    # array con IDS de materias de practico
    vars1erHora = {}
    scaled_u_dict = {}

    for t in [m for m in materias if m.teo_prac == "teo"]:
        teo.append(t.id)
        vars1erHora[t.id] = model.addVar(vtype=GRB.INTEGER, name=str(t)+"_1er_hora")

    for p in [m for m in materias if m.teo_prac == "prac"]:
        prac.append(p.id)
        vars1erHora[p.id] = model.addVar(vtype=GRB.INTEGER, name=str(p)+"_1er_hora")

    L = len(bloques_horario_ids)

    for m in teo + prac:
        for b in range(0, L):
            scaled_u_dict[m, bloques_horario_ids[b]] = model.addVar(vtype=GRB.INTEGER, name=str(m)+"scaled_u")
            model.addConstr(scaled_u_dict[m, bloques_horario_ids[b]] == (L - b) * u_dict[m, bloques_horario_ids[b]].variable)

    for m_id in vars1erHora:
        print(m_id, vars1erHora[m_id])
        model.addConstr(vars1erHora[m_id] ==
                        # gp.max_( (L - b) * u_dict[m_id, bloques_horario_ids[b]].variable
                        gp.max_( scaled_u_dict[m_id, bloques_horario_ids[b]]
                                for b in range(0, L)) )


    if len(teo) == len(prac):
        model.addConstrs(vars1erHora[teo[m]] >= vars1erHora[prac[m]] for m in range(0, len(teo)))
    else:
        print("Error: no coinciden cantidad de teoricos con practicos")

# %% [markdown]
# #### (3.3.4) Limitar horas excepcionales
#
# $$ \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} \leq E$$

# %%
def constr_horarios_excepcionales(model, u_dict, E_teo, E_prac):

    suma_horas_prac = gp.LinExpr()
    suma_horas_teo = gp.LinExpr()
    
    for m in materias:
        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos())) > 0:
                if m.teo_prac == "prac":
                    suma_horas_prac += u_dict[m.id, b.id].variable
                else:
                    suma_horas_teo += u_dict[m.id, b.id].variable
    
    model.addConstr(suma_horas_prac <= E_prac, "horas_excepcionales_prac")
    model.addConstr(suma_horas_teo <= E_teo, "horas_excepcionales_teo")

# %% [markdown]
# ### (3.4) Grupos

# %% [markdown]
# #### (3.4.1) definicion de variable "x"
#
# $$ x_{gb} = \sum_{m \in M_g} {u_{mb}} $$
#
# $$ x_{gb} = OR_{m \in M_g} {u_{mb}} $$

# %%
def constr_definir_x(model, x_dict, u_dict):

    # SUMA
    # for g in grupos:
    #     gr_mats_ids = [m.id for m in materias_grupo(g, materias)]
    #     model.addConstrs(x_dict[g.id, b].variable == gp.quicksum(u_dict[m, b].variable for m in gr_mats_ids) for b in bloques_horario_ids)

    # OR
    for g in grupos:
        # gr_mats_ids = [m.id for m in materias_grupo(g, materias)]
        gr_mats_ids = [m.id for m in materias_grupo(g, [m for m in materias if not m.electiva])] # filtrar materias electivas
        model.addConstrs(x_dict[g.id, b].variable == gp.or_(u_dict[m, b].variable for m in gr_mats_ids) for b in bloques_horario_ids)

# %% [markdown]
# #### (3.4.2) evitar horas puente por grupo
#
# $$ \sum_h {x_{gdh}} - \sum_h {x_{gd(h)} · x_{gd(h+1)}} \leq 1 $$
#     para todo g, d

# %%
def constr_horas_puente_grupos(model, x_dict):

    for g in grupos:
        model.addConstrs(gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
                    - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
                    <= 1 for d in dias_ids)

# %% [markdown]
# ## (4) Funcion Objetivo

# %% [markdown]
# ### (4.1) Prioridad horaria de los docentes
#
# $$ \min: \sum_{m,b,p} {A_{pb}·w_{mp}·u_{mb}} $$

# %%
def obj_prioridades(u_dict, w_dict):

    OBJ1 = gp.QuadExpr()
    """
    This script constructs a quadratic expression for an optimization problem using Gurobi's QuadExpr.
    Variables:
        OBJ1 (gp.QuadExpr): A quadratic expression object to accumulate the terms.
        count (int): A counter to keep track of the number of terms added to the quadratic expression.
    Loops:
        The script iterates over all combinations of 'materias' and 'profesores'. For each professor, it further iterates over their 'prioridades'.
    Inner Loop:
        For each priority 'pr' of a professor:
            - 'b' is assigned the 'bloque_horario' of the priority.
            - 'A' is assigned the 'value' of the priority.
            - The quadratic expression 'OBJ1' is updated by adding the product of 'A', the variable corresponding to the combination of 'materia' and 'profesor' from 'w_dict', and the variable corresponding to the combination of 'materia' and 'bloque_horario' from 'u_dict'.
            - The counter 'count' is incremented.
    Final Step:
        The constructed quadratic expression 'OBJ1' is added to the main objective 'OBJ'.
    Output:
        The total count of terms added to the quadratic expression is printed.
    """

    count = 0
    for m in materias:
        for p in profesores:
            for pr in p.prioridades:
                b = pr.bloque_horario
                A = pr.value
                OBJ1 += A * w_dict[m.id, p.id].variable * u_dict[m.id, b.id].variable
                count += 1


    print("obj_prioridades terms:", count)

    return OBJ1

# %% [markdown]
# ### (4.2) Minimizar/Maximizar dias con clase por profesor
# $$ \min: \sum_{p,d} {\alpha_p} {z_{pd}}$$
# donde $\alpha_p = 1$ si se minimiza, $\alpha_p = -1$ si se maximiza y $\alpha_p = 0$ si es irrelevante

# %%
def obj_min_max_dias(z_dict):

    OBJ2 = gp.LinExpr()
    DP = {}

    count = 0
    for p in profesores:
        
        D_p = gp.quicksum(z_dict[p.id,d].variable for d in dias_ids)
        DP[p.id] = D_p

        # filtrar si el profesor prefiere minimizar o maximizar o ninguno
        match p.min_max_dias:
            case "min":
                OBJ2 += D_p
                count += len(dias_ids)
            case "max":
                OBJ2 -= D_p
                count += len(dias_ids)
            case None:
                pass

    print("obj_min_max_dias terms:", count)

    return OBJ2, DP

# %% [markdown]
# ### (4.3) Minimizar horas puente por grupo (se incluye directamente como restriccion)
#
# $$ \min: -\sum_{g,d,h} {x_{gd(h)}·x_{gd(h+1)}} $$

# %%
def obj_horas_puente_grupos(x_dict):
    OBJ3 = gp.QuadExpr()

    count = 0
    for g in grupos:
        for d in dias_ids:
            OBJ3 += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
            count += 1

    print("obj_horas_puente_grupos terms:", count)

    return OBJ3

# %% [markdown]
# ### (4.4) Minimizar superposicion de electivas
#
# $$ \min:  \sum_{b} \sum_{m, m'}{u_{mb} \times SE_{m,m'} \times u_{m'b}} = 0 $$
#
# para todo par (m, m') de electivas

# %%
def obj_superposicion_electivas(u_dict):
    OBJ4 = gp.QuadExpr()

    count = 0
    for m1 in electivas(materias):
        for m2 in electivas(materias):
            for b in bloques_horario_ids:
                OBJ4 += u_dict[m1.id, b].variable * superposicion_electivas[m1.id, m2.id].value * u_dict[m2.id, b].variable
                count += 1

    print("obj_superposicion_electivas terms:", count)

    return OBJ4

# %% [markdown]
# ### (4.5) Evitar horas excepcionales
#
# $$ \min: \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} $$

# %%
def obj_horarios_excepcionales(u_dict, prac=False):

    objetivo = gp.QuadExpr()

    count = 0
    for m in materias:

        if (not prac and m.teo_prac == "prac") or (prac and m.teo_prac != "prac"):
            continue

        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos()))>0:
                objetivo += u_dict[m.id, b.id].variable
                count += 1
        
    print("obj_horarios_excepcionales terms:", count)

    return objetivo

# %% [markdown]
# # Resolver     ...para ejecutar ->

# %% [markdown]
# ### Filtrar

# %%
# recargar input original

import copy

anios = copy.deepcopy(ANIOS)
dias = copy.deepcopy(DIAS)
horarios = copy.deepcopy(HORARIOS)
bloques_horario = copy.deepcopy(BLOQUES_HORARIO)
profesores = copy.deepcopy(PROFESORES)
grupos = copy.deepcopy(GRUPOS)
materias = copy.deepcopy(MATERIAS)
superposicion = copy.deepcopy(SUPERPOSICION)
superposicion_electivas = copy.deepcopy(SUPERPOSICION_ELECTIVAS)

# %%
# actualizar id arrays

dias_ids = [d.id for d in dias]

horarios_ids = [h.id for h in horarios]

bloques_horario_ids = [b for b in bloques_horario]

profesores_ids = [p.id for p in profesores]

grupos_ids = [g.id for g in grupos]

materias_ids = [m.id for m in materias]

# %% [markdown]
# ## Compilar modelo

# %%
# Create a new model
model: gp.Model = gp.Model("timetable")

# %%
# variables
u_dict, v_dict, w_dict, x_dict, y_dict, z_dict = initialize_variables(materias, bloques_horario, dias, profesores, grupos)
create_variables(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)
# Out:
# u:  13200
# v:  825
# w:  19305
# x:  2320
# y:  9360
# z:  585

# %%
# generate_instance_json("../instances/instance_2026sem1.json", materias, grupos, profesores, dias, horarios, turnos, superposicion, superposicion_electivas, mats_dias_consecutivos, p_grupos_simultaneos)

# %% [markdown]
# ### Seleccionar restricciones

# %%
constr_superposicion(model, u_dict)
constr_carga_horaria(model, u_dict)
constr_dias_materia(model, v_dict)
constr_max_min_horas(model, u_dict, v_dict)

# %%
constr_turnos_materia(model, u_dict)
constr_horas_consecutivas(model, u_dict, v_dict)
constr_dias_consecutivos(model, v_dict)
# constr_horarios_excepcionales(model, u_dict, 7, 1)   # (opcional) limitar cantidad de horas excepcionales

# %%
constr_no_disponible_profesor(model, u_dict, w_dict)
constr_unica_materia_profesor(model, u_dict, w_dict)
constr_limitar_profesores_materia(model, w_dict)
constr_cantidad_profesores(model, w_dict)
constr_grupos_max_profesor(model, w_dict)
# constr_ad_hoc_profesores(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)

# %%
constr_definir_y(model, y_dict, u_dict, w_dict)
constr_definir_z(model, z_dict, y_dict)

# %%
# %%capture
constr_cantidad_salones(model, u_dict)
# constr_ad_hoc_materias(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)
constr_teo_prac(model, u_dict)

# %%
constr_definir_x(model, x_dict, u_dict)
constr_horas_puente_grupos(model, x_dict)

# %% [markdown]
# ### Funcion objetivo

# %%
# funcion objetivo

objectives = { # name : (expr, weight)
    
    "prioridades" : (obj_prioridades(u_dict, w_dict), 1), # weight = 1
    "min_max_dias" : (obj_min_max_dias(z_dict)[0], 0), # weight = 5
    "superposicion_electivas" : (obj_superposicion_electivas(u_dict), 0), # weight = 10
    "horarios_excepcionales (practico)" : (obj_horarios_excepcionales(u_dict, prac=True), 0), # weight = 50
    "horarios_excepcionales" : (obj_horarios_excepcionales(u_dict, prac=False), 0), # weight = 100

}

OBJ = gp.QuadExpr()
for name in objectives:
    expr, weight = objectives[name]
    OBJ += weight * expr

model.setObjective(OBJ, GRB.MINIMIZE)
# Out:
# obj_prioridades terms: 667425
# obj_min_max_dias terms: 175
# obj_superposicion_electivas terms: 8000
# obj_horarios_excepcionales terms: 110
# obj_horarios_excepcionales terms: 865

# %% [markdown]
# ## Optimizar

# %%
model.setParam("TimeLimit", 40*60)
# model.setParam('OutputFlag', 1)
model.Params.MIPGap = 0.01/100
# model.Params.PoolSolutions = 10 # Number of solutions to find
# model.Params.PoolSearchMode = 0 # 0, 1, 2

model.optimize()

# nSolutions = model.SolCount
# print(f"Number of solutions found: {nSolutions}")
# Out:
# Set parameter TimeLimit to value 2400
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 32462 rows, 68919 columns and 108511 nonzeros
# Model fingerprint: 0x11d1ed77
# Model has 667425 quadratic objective terms
# Model has 41256 quadratic constraints
# Model has 12309 general constraints
# Variable types: 0 continuous, 68919 integer (45595 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 2e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+00, 6e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
#   QRHS range       [1e+00, 2e+00]
# Presolve added 571 rows and 0 columns
# Presolve removed 0 rows and 51716 columns
# Presolve time: 0.56s
# Presolved: 60024 rows, 24604 columns, 156977 nonzeros
# Presolved model has 29 SOS constraint(s)
# Variable types: 0 continuous, 24604 integer (22802 binary)
#
# Root relaxation: objective 6.364257e+02, 12270 iterations, 1.26 seconds (0.68 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  636.42574    0 2029          -  636.42574      -     -    5s
#      0     0  636.89375    0 1908          -  636.89375      -     -    5s
#      0     0  774.70103    0 2624          -  774.70103      -     -    9s
#      0     0  774.70103    0 2628          -  774.70103      -     -    9s
#      0     0  774.92181    0 2723          -  774.92181      -     -   10s
#      0     0  785.43956    0 2507          -  785.43956      -     -   16s
#      0     0  785.43956    0 2404          -  785.43956      -     -   18s
#      0     0  786.85826    0 2638          -  786.85826      -     -   21s
#      0     0  786.85826    0 2040          -  786.85826      -     -   27s
#      0     2  786.86063    0 1937          -  786.86063      -     -   32s
#     13    20  787.98569    4 1658          -  787.55680      -  1851   36s
#     97    93  790.11236    9 1263          -  787.77902      -   647   40s
#    216   172  805.50000   19  992          -  787.77902      -   449   45s
#    298   253  808.50000   30  856          -  787.77902      -   612   50s
#    403   346  814.50000   49  729          -  787.77902      -   684   55s
#    677   599  815.06667   68  622          -  787.77902      -   596   61s
#    893   729  792.94569   10 1321          -  787.98378      -   540   66s
#    940   742  795.20063   10 1601          -  787.98378      -   563   70s
#    990   793  794.21139    5 1817          -  787.98569      -   598   76s
#   1067   853  801.48168    9 1482          -  787.98569      -   618   80s
#   1155   956  806.62718   16 1087          -  787.98569      -   641   85s
#   1298  1065  810.50000   30  695          -  787.98569      -   636   90s
#   1387  1118  810.50000   35  889          -  787.98569      -   649   95s
#   1448  1152  805.00000   61 1518          -  787.98569      -   671  102s
#   1450  1154  796.50000   20 1991          -  787.98569      -   670  108s
#   1451  1154  805.00000   63 2074          -  789.94902      -   669  111s
#   1452  1155  801.25000   22 1913          -  790.77004      -   669  115s
#   1459  1160  813.50000   47 1700          -  791.28924      -   666  120s
#   1466  1164  801.95556   19 1726          -  791.51724      -   662  126s
#   1471  1168  799.74471   57 1664          -  791.66698      -   660  130s
#   1479  1173  793.05556   18 1536          -  791.87481      -   657  135s
#   1489  1180  800.50000   36 1605          -  791.94886      -   652  141s
#   1495  1184  800.51010   23 1587          -  792.07136      -   650  145s
#   1503  1189  810.50000   45 1475          -  792.13317      -   646  150s
#   1510  1194  807.86236   11 1477          -  792.19500      -   643  157s
#   1516  1198  806.50000   37 1535          -  792.27526      -   641  161s
#   1521  1201  802.43156   17 1601          -  792.36740      -   638  165s
#   1528  1206  810.50000   24 1529          -  792.48689      -   636  170s
#   1534  1210  821.00000  113 1427          -  792.56888      -   633  175s
#   1542  1215  793.50000   19 1355          -  792.65995      -   630  180s
#   1548  1219  805.00000   61 1378          -  792.67121      -   627  185s
#   1552  1222  801.25000   22 1371          -  792.75222      -   626  190s
#   1559  1226  813.50000   47 1643          -  792.79050      -   623  195s
#   1564  1230  797.70000   30 1581          -  792.83354      -   621  200s

# %% [markdown]
# ### Analizar no-factibilidad

# %%
# if model.Status == GRB.INFEASIBLE:
#     model.computeIIS()
#     model.write('iismodel.ilp')

#     # Print out the IIS constraints and variables
#     print('\nThe following constraints and variables are in the IIS:')
#     for c in model.getConstrs():
#         if c.IISConstr: print(f'\t{c.constrname}: {model.getRow(c)} {c.Sense} {c.RHS}')

#     for v in model.getVars():
#         if v.IISLB: print(f'\t{v.varname} ≥ {v.LB}')
#         if v.IISUB: print(f'\t{v.varname} ≤ {v.UB}')

# %% [markdown]
# ## Imprimir horarios

# %%
model.setParam("SolutionNumber", 0)
model.update()


if not model.Status == GRB.INFEASIBLE:
    print('Obj: %g' % model.ObjVal)
    for name in objectives:
        expr, weight = objectives[name]
        print(f"\t{name}: \t{" "*(35-len(name))}{round(expr.getValue())} \t(peso={weight})")
    print('=============================================================')
    
    print_timetable(dias, horarios, u_dict, w_dict, grupos, anios)

    save_solution_json(u_dict, v_dict, w_dict, "../results/solution.json")
# Out:
# Obj: 71
# 	prioridades: 	                        951 	(peso=0)
# 	min_max_dias: 	                       78 	(peso=0)
# 	superposicion_electivas: 	            50 	(peso=0)
# 	horarios_excepcionales (practico): 	  1 	(peso=1)
# 	horarios_excepcionales: 	             7 	(peso=10)
# =============================================================
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  1
#
#  Grupo:  10
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		---		---		49		96
# 1_start-1_end		70		66		---		49		96
# 2_start-2_end		70		66		6		49		73
# 3_start-3_end		---		66		6		23		73
# 4_start-4_end		---		23		64		23		66
# 5_start-5_end		---		23		64		23		66
# 6_start-6_end *		---		---		64		---		---
#
#  Grupo:  11
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		---		---		---		---
# 1_start-1_end		66		23		49		23		66
# 2_start-2_end		66		23		49		23		66
# 3_start-3_end		70		64		49		23		66
# 4_start-4_end		70		64		6		73		96
# 5_start-5_end		---		64		6		73		96
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  12
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		64		---		73		---
# 1_start-1_end		---		64		---		73		70
# 2_start-2_end		---		64		66		23		70
# 3_start-3_end		49		23		66		23		66
# 4_start-4_end		49		23		6		96		66
# 5_start-5_end		49		23		6		96		66
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  13
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		64		70		23		96		23
# 8_start-8_end		64		70		23		96		23
# 9_start-9_end		64		49		23		73		6
# 10_start-10_end		66		49		66		73		6
# 11_start-11_end		66		49		66		---		---
# 12_start-12_end *		---		---		66		---		---
#
#  Grupo:  14
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		---		69		10		69		10
# 8_start-8_end		86		69		10		69		10
# 9_start-9_end		86		83		87		69		10
# 10_start-10_end		86		83		87		---		86
# 11_start-11_end		---		---		---		---		86
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  15
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		---		69		10		69		10
# 8_start-8_end		86		69		10		69		10
# 9_start-9_end		86		83		87		69		10
# 10_start-10_end		86		83		87		---		86
# 11_start-11_end		---		---		---		---		86
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  16
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		89		---		89		---		59
# 12_start-12_end		89		95		89		41		59
# 13_start-13_end		41		95		59		41		59
# 14_start-14_end		41		34		59		34		59
# 15_start-15_end		41		34		---		34		---
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  2
#
#  Grupo:  27
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		35		74		42		0		5
# 1_start-1_end		35		74		42		0		5
# 2_start-2_end		35		5		35		0		5
# 3_start-3_end		92		5		35		93		74
# 4_start-4_end		92		93		92		93		74
# 5_start-5_end		92		93		92		---		74
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  28
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		35		74		42		82		5
# 1_start-1_end		35		74		42		82		5
# 2_start-2_end		35		5		35		82		5
# 3_start-3_end		92		5		35		93		74
# 4_start-4_end		92		93		92		93		74
# 5_start-5_end		92		93		92		---		74
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  29
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		29		44/44		42		44/44		30
# 1_start-1_end		29		44/44		42		44/44		30
# 2_start-2_end		29		93		93		44/44		30
# 3_start-3_end		92		93		93		29		88/88
# 4_start-4_end		92		88/88		92		29		88/88
# 5_start-5_end		92		88/88		92		29		88/88
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  210
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		29		44/44		67		44/44		29
# 1_start-1_end		29		44/44		67		44/44		29
# 2_start-2_end		29		8		55		44/44		29
# 3_start-3_end		67		8		55		8		88/88
# 4_start-4_end		67		88/88		93		8		88/88
# 5_start-5_end		67		88/88		93		93		88/88
# 6_start-6_end *		---		---		---		93		---
#
#  Grupo:  211
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		29		88		44		88		44
# 1_start-1_end		29		88		44		88		44
# 2_start-2_end		29		93		93		88		44
# 3_start-3_end		67		93		93		29		8
# 4_start-4_end		67		8		67		29		8
# 5_start-5_end		67		8		67		29		55
# 6_start-6_end *		---		---		---		---		55
#
#  Grupo:  212
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		---		92		---		92		---
# 8_start-8_end		---		92		---		92		---
# 9_start-9_end		---		---		---		92		---
# 10_start-10_end		---		---		42		---		---
# 11_start-11_end		---		---		42		---		---
# 12_start-12_end *		---		---		---		---		---
#
#  Grupo:  213
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		---		26		11		37		11
# 12_start-12_end		44		26		11		37		11
# 13_start-13_end		44		26		11		37		44
# 14_start-14_end		44		37		38		26		44
# 15_start-15_end		38		37		38		26		---
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  3
#
#  Grupo:  314
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		54		61		90		61		85
# 1_start-1_end		54		61		90		61		85
# 2_start-2_end		54		91		90		91		50
# 3_start-3_end		54		91		50		39		50
# 4_start-4_end		54		39		50		39		---
# 5_start-5_end		54		39		---		39		---
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  315
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		97		61		97		61		51
# 1_start-1_end		97		61		97		61		51
# 2_start-2_end		97		91		97		91		50
# 3_start-3_end		16		91		50		16		50
# 4_start-4_end		16		51		50		16		---
# 5_start-5_end		16		51		---		16		---
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  316
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		19		76		19		---		76
# 1_start-1_end		19		76		19		25		76
# 2_start-2_end		91		25		19		25		50
# 3_start-3_end		16		25		50		16		50
# 4_start-4_end		16		25		50		16		91
# 5_start-5_end		16		---		---		16		91
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  317
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		46		13		62		---		13
# 1_start-1_end		46		13		62		---		13
# 2_start-2_end		91		13		56		46		62
# 3_start-3_end		56		65		56		46		62
# 4_start-4_end		56		65		---		65		91
# 5_start-5_end		56		65		---		65		91
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  318
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		46		91		---		46		---
# 1_start-1_end		46		91		76		46		76
# 2_start-2_end		25		50		76		50		76
# 3_start-3_end		25		50		25		50		13
# 4_start-4_end		25		13		25		91		13
# 5_start-5_end		---		13		---		---		13
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  319
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		4		---		---		79		---
# 12_start-12_end		94		47		4		79		94
# 13_start-13_end		94		47		4		72		94
# 14_start-14_end		72		47		15		72		15
# 15_start-15_end		72		47		15		---		15
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  4
#
#  Grupo:  420
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		4		80/27/84		4		---		77/3
# 10_start-10_end		4		80/27/84		77/3		45		77/3
# 11_start-11_end		80/27/84		20		77/3		45		81
# 12_start-12_end		80/27/84		20		20		20		81
# 13_start-13_end		---		81		20		20		12
# 14_start-14_end		---		81		12		20		12
# 15_start-15_end *		---		---		12		---		---
#
#  Grupo:  421
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		---		2		77/3		2		77/3
# 10_start-10_end		17		2		77/3		2		77/3
# 11_start-11_end		17		7		40		2		4
# 12_start-12_end		17		7		40		7		4
# 13_start-13_end		4		7		40		7		17
# 14_start-14_end		---		---		40		---		17
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  422
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		4		---		4		---		77/3
# 10_start-10_end		4		48		77/3		48		77/3
# 11_start-11_end		52		48		77/3		48		9
# 12_start-12_end		52		---		53		52		9
# 13_start-13_end		53		---		53		52		9
# 14_start-14_end		53		---		53		52		9
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  423
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		79		77/3		4		---		---
# 10_start-10_end		79		77/3		4		---		4
# 11_start-11_end		98		48		98		---		9
# 12_start-12_end		98		48		98		48		9
# 13_start-13_end		---		22		77/3		48		9
# 14_start-14_end		---		22		77/3		---		9
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  424
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		31		---		---		46		---
# 12_start-12_end		31		46		---		46		31
# 13_start-13_end		---		46		13		63		31
# 14_start-14_end		13		91		13		63		91
# 15_start-15_end		13		91		13		63		---
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  5
#
#  Grupo:  525
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		57
# 9_start-9_end		---		80/27/84		---		---		57
# 10_start-10_end		---		80/27/84		---		43		21
# 11_start-11_end		80/27/84		---		57		43		21
# 12_start-12_end		80/27/84		43		57/57		21		---
# 13_start-13_end		57		43		57		21		12
# 14_start-14_end		57		68		12		68		12
# 15_start-15_end *		---		68		12		68		---
#
#  Grupo:  526
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		57
# 9_start-9_end		60		---		60		33		57
# 10_start-10_end		60		33		60		33		18
# 11_start-11_end		28		33		57		14		18
# 12_start-12_end		28		18		57/57		14		28
# 13_start-13_end		57		18		57		14		28
# 14_start-14_end		57		68		---		68		---
# 15_start-15_end *		---		68		---		68		---
#
#  Grupo:  527
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		57
# 9_start-9_end		32/78/75		---		58		78		57
# 10_start-10_end		32/78/75		---		58		78		58
# 11_start-11_end		32/31/75		---		57		---		58
# 12_start-12_end		31/75		24		57/57		24		1/36/31
# 13_start-13_end		57		24		57		24		1/36/31
# 14_start-14_end		57		68		---		68		1/36
# 15_start-15_end *		---		68		---		68		---
#
#  Grupo:  528
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		32/78/75		68		---		78		57
# 10_start-10_end		32/78/75		68		---		78		57
# 11_start-11_end		32/31/75		57		---		68		---
# 12_start-12_end		31/75		57		57		68		1/36/31
# 13_start-13_end		57		71		57		71		1/36/31
# 14_start-14_end		57		71		---		71		1/36
# 15_start-15_end *		---		---		---		---		---

# %%
if not model.Status == GRB.INFEASIBLE:
    print_prof_timetable_excel(dias, horarios, u_dict, w_dict, profesores, materias)
# Out:
#  Profesor:  3 3
# 	1	2	3	4	5
# 0_start-0_end	---	---	90	---	---
# 1_start-1_end	---	---	90	---	---
# 2_start-2_end	---	---	90	---	---
# 9_start-9_end	---	84	---	---	---
# 10_start-10_end	---	84	---	---	---
# 11_start-11_end	84	---	---	---	---
# 12_start-12_end	84	---	---	---	---
#
#  Profesor:  4 4
# 	1	2	3	4	5
# 1_start-1_end	70	---	---	---	70
# 2_start-2_end	70	---	---	---	70
# 3_start-3_end	70	---	---	---	---
# 4_start-4_end	70	---	---	---	---
# 7_start-7_end	---	70	---	---	---
# 8_start-8_end	---	70	---	---	---
#
#  Profesor:  5 5
# 	1	2	3	4	5
# 11_start-11_end	4	---	---	---	4
# 12_start-12_end	---	---	4	---	4
# 13_start-13_end	4	---	4	---	---
#
#  Profesor:  6 6
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	20	---
# 13_start-13_end	---	---	---	20	---
# 14_start-14_end	---	---	---	20	---
#
#  Profesor:  7 7
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	---	21
# 11_start-11_end	---	---	---	---	21
# 12_start-12_end	---	---	---	21	---
# 13_start-13_end	---	---	---	21	---
#
#  Profesor:  9 9
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	46	---
# 12_start-12_end	---	46	---	46	---
# 13_start-13_end	---	46	---	---	---
#
#  Profesor:  11 11
# 	1	2	3	4	5
# 10_start-10_end	66	---	66	---	---
# 11_start-11_end	66	---	66	---	---
# 12_start-12_end	---	---	66	---	---
#
#  Profesor:  12 12
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	73
# 3_start-3_end	49	---	---	---	73
# 4_start-4_end	49	---	---	---	---
# 5_start-5_end	49	---	---	---	---
#
#  Profesor:  13 13
# 	1	2	3	4	5
# 9_start-9_end	---	68	---	---	---
# 10_start-10_end	---	68	---	---	---
# 11_start-11_end	---	---	---	68	---
# 12_start-12_end	---	---	---	68	---
# 14_start-14_end	---	68	---	68	---
# 15_start-15_end	---	68	---	68	---
#
#  Profesor:  14 14
# 	1	2	3	4	5
# 0_start-0_end	---	64	---	---	---
# 1_start-1_end	---	64	---	---	---
# 2_start-2_end	---	64	---	---	---
# 3_start-3_end	---	64	---	---	---
# 4_start-4_end	---	64	64	---	---
# 5_start-5_end	---	64	64	---	---
# 6_start-6_end	---	---	64	---	---
# 7_start-7_end	64	---	---	---	---
# 8_start-8_end	64	---	---	---	---
# 9_start-9_end	64	---	---	---	---
#
#  Profesor:  15 15
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	23	---
# 4_start-4_end	---	23	---	23	---
# 5_start-5_end	---	23	---	23	---
# 7_start-7_end	---	69	---	69	---
# 8_start-8_end	---	69	---	69	---
# 9_start-9_end	---	83	---	69	---
# 10_start-10_end	---	83	---	---	---
#
#  Profesor:  16 16
# 	1	2	3	4	5
# 9_start-9_end	32	---	---	---	---
# 10_start-10_end	32	---	---	---	---
# 11_start-11_end	32	---	---	---	---
#
#  Profesor:  17 17
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	30
# 1_start-1_end	---	---	---	---	30
# 2_start-2_end	---	---	---	---	30
#
#  Profesor:  18 18
# 	1	2	3	4	5
# 0_start-0_end	29	---	---	---	29
# 1_start-1_end	29	---	---	---	29
# 2_start-2_end	29	---	---	---	29
#
#  Profesor:  21 21
# 	1	2	3	4	5
# 14_start-14_end	---	---	15	---	15
# 15_start-15_end	---	---	15	---	15
#
#  Profesor:  26 26
# 	1	2	3	4	5
# 11_start-11_end	---	26	---	---	---
# 12_start-12_end	---	26	---	41	---
# 13_start-13_end	41	26	---	41	---
# 14_start-14_end	41	---	---	26	---
# 15_start-15_end	41	---	---	26	---
#
#  Profesor:  28 28
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	50
# 3_start-3_end	---	---	50	---	50
# 4_start-4_end	---	---	50	---	---
#
#  Profesor:  29 29
# 	1	2	3	4	5
# 9_start-9_end	75	---	---	---	---
# 10_start-10_end	75	---	---	---	---
# 11_start-11_end	75	---	---	---	---
# 12_start-12_end	75	---	---	---	---
#
#  Profesor:  30 30
# 	1	2	3	4	5
# 10_start-10_end	---	48	---	48	---
# 11_start-11_end	---	48	---	48	---
# 13_start-13_end	---	71	---	71	---
# 14_start-14_end	---	71	---	71	---
#
#  Profesor:  31 31
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	5
# 1_start-1_end	---	---	---	---	5
# 2_start-2_end	---	5	---	---	5
# 3_start-3_end	---	5	---	---	---
#
#  Profesor:  32 32
# 	1	2	3	4	5
# 11_start-11_end	98	---	98	---	---
# 12_start-12_end	98	47	98	---	---
# 13_start-13_end	---	47	---	---	---
#
#  Profesor:  33 33
# 	1	2	3	4	5
# 2_start-2_end	---	50	---	50	---
# 3_start-3_end	---	50	---	50	---
#
#  Profesor:  34 34
# 	1	2	3	4	5
# 12_start-12_end	---	---	57	---	---
# 13_start-13_end	57	---	57	---	---
# 14_start-14_end	57	---	---	---	---
#
#  Profesor:  36 36
# 	1	2	3	4	5
# 2_start-2_end	---	---	66	---	---
# 3_start-3_end	---	---	66	---	66
# 4_start-4_end	---	---	6	---	66
# 5_start-5_end	---	---	6	---	66
# 9_start-9_end	---	---	---	---	6
# 10_start-10_end	---	---	---	---	6
# 11_start-11_end	---	---	---	---	59
# 12_start-12_end	---	---	---	---	59
# 13_start-13_end	---	---	59	---	59
# 14_start-14_end	---	---	59	---	59
#
#  Profesor:  37 37
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	---	9
# 12_start-12_end	---	---	---	---	9
# 13_start-13_end	---	---	---	---	9
# 14_start-14_end	---	---	---	---	9
#
#  Profesor:  38 38
# 	1	2	3	4	5
# 2_start-2_end	---	---	56	---	---
# 3_start-3_end	56	---	56	---	---
# 4_start-4_end	56	---	---	---	---
# 5_start-5_end	56	---	---	---	---
#
#  Profesor:  39 39
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	---	18
# 11_start-11_end	---	---	40	---	18
# 12_start-12_end	---	18	40	---	---
# 13_start-13_end	---	18	40	---	---
# 14_start-14_end	---	---	40	---	---
#
#  Profesor:  42 42
# 	1	2	3	4	5
# 9_start-9_end	---	27	---	---	---
# 10_start-10_end	---	27	---	---	---
# 11_start-11_end	27	---	---	---	---
# 12_start-12_end	27	---	---	---	---
#
#  Profesor:  43 43
# 	1	2	3	4	5
# 0_start-0_end	54	---	---	---	---
# 1_start-1_end	54	---	---	---	---
# 2_start-2_end	54	---	---	---	---
# 3_start-3_end	54	---	---	---	---
# 4_start-4_end	54	---	---	---	---
# 5_start-5_end	54	---	---	---	---
#
#  Profesor:  44 44
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	0	---
# 1_start-1_end	---	---	---	0	---
# 2_start-2_end	---	---	---	0	---
#
#  Profesor:  47 47
# 	1	2	3	4	5
# 9_start-9_end	---	---	3	---	3
# 10_start-10_end	---	---	3	---	3
# 11_start-11_end	---	---	3	---	---
#
#  Profesor:  48 48
# 	1	2	3	4	5
# 10_start-10_end	17	---	---	---	---
# 11_start-11_end	17	---	---	---	---
# 12_start-12_end	17	---	---	---	---
# 13_start-13_end	---	---	---	---	17
# 14_start-14_end	---	---	---	---	17
#
#  Profesor:  49 49
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	43	---
# 11_start-11_end	---	---	---	43	---
# 12_start-12_end	---	43	---	---	---
# 13_start-13_end	---	43	---	---	---
#
#  Profesor:  50 50
# 	1	2	3	4	5
# 0_start-0_end	---	44	---	44	---
# 1_start-1_end	---	44	---	44	---
# 2_start-2_end	---	---	---	44	---
# 9_start-9_end	---	---	87	---	---
# 10_start-10_end	---	---	87	---	---
#
#  Profesor:  53 53
# 	1	2	3	4	5
# 9_start-9_end	---	2	---	2	---
# 10_start-10_end	---	2	---	2	---
# 11_start-11_end	---	---	---	2	---
#
#  Profesor:  54 54
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	50
# 3_start-3_end	---	---	50	---	50
# 4_start-4_end	---	---	50	---	---
#
#  Profesor:  55 55
# 	1	2	3	4	5
# 8_start-8_end	---	---	---	---	57
# 9_start-9_end	---	---	---	---	57
# 10_start-10_end	---	---	---	---	57
# 11_start-11_end	---	57	57	---	---
# 12_start-12_end	---	57	57	---	---
#
#  Profesor:  57 57
# 	1	2	3	4	5
# 9_start-9_end	75	---	---	---	---
# 10_start-10_end	75	---	---	---	---
# 11_start-11_end	75	---	---	---	---
# 12_start-12_end	75	---	---	---	---
#
#  Profesor:  58 58
# 	1	2	3	4	5
# 9_start-9_end	---	80	---	---	---
# 10_start-10_end	---	80	---	---	---
# 11_start-11_end	80	---	---	---	---
# 12_start-12_end	80	---	---	---	---
#
#  Profesor:  59 59
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	23	---
# 3_start-3_end	---	23	---	23	---
# 4_start-4_end	---	23	---	---	---
# 5_start-5_end	---	23	---	---	---
# 7_start-7_end	---	69	---	69	---
# 8_start-8_end	---	69	---	69	---
# 9_start-9_end	---	83	---	69	---
# 10_start-10_end	---	83	---	---	---
#
#  Profesor:  60 60
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	---	12
# 14_start-14_end	---	---	12	---	12
# 15_start-15_end	---	---	12	---	---
#
#  Profesor:  61 61
# 	1	2	3	4	5
# 0_start-0_end	35	---	---	---	---
# 1_start-1_end	35	---	---	---	---
# 2_start-2_end	35	---	35	---	---
# 3_start-3_end	16	---	35	16	---
# 4_start-4_end	16	---	---	16	---
# 5_start-5_end	16	---	---	16	---
#
#  Profesor:  62 62
# 	1	2	3	4	5
# 2_start-2_end	25	---	---	---	---
# 3_start-3_end	25	---	25	---	---
# 4_start-4_end	25	---	25	---	---
#
#  Profesor:  64 64
# 	1	2	3	4	5
# 0_start-0_end	---	---	44	---	44
# 1_start-1_end	---	---	44	---	44
# 2_start-2_end	---	---	---	---	44
#
#  Profesor:  66 66
# 	1	2	3	4	5
# 1_start-1_end	---	---	76	---	76
# 2_start-2_end	---	---	76	---	76
# 13_start-13_end	---	22	---	---	---
# 14_start-14_end	---	22	---	---	---
#
#  Profesor:  68 68
# 	1	2	3	4	5
# 11_start-11_end	---	48	---	---	---
# 12_start-12_end	---	48	---	48	---
# 13_start-13_end	---	---	---	48	---
#
#  Profesor:  71 71
# 	1	2	3	4	5
# 0_start-0_end	19	---	19	---	---
# 1_start-1_end	19	---	19	---	---
# 2_start-2_end	---	---	19	---	---
# 11_start-11_end	---	---	11	---	11
# 12_start-12_end	---	---	11	---	11
# 13_start-13_end	---	---	11	---	---
#
#  Profesor:  72 72
# 	1	2	3	4	5
# 0_start-0_end	---	61	---	61	---
# 1_start-1_end	---	61	---	61	---
#
#  Profesor:  74 74
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	---	88
# 4_start-4_end	---	88	---	---	88
# 5_start-5_end	---	88	---	---	88
# 11_start-11_end	---	---	---	37	---
# 12_start-12_end	---	---	---	37	---
# 13_start-13_end	---	---	---	37	---
# 14_start-14_end	---	37	---	---	---
# 15_start-15_end	---	37	---	---	---
#
#  Profesor:  75 75
# 	1	2	3	4	5
# 2_start-2_end	---	93	93	---	---
# 3_start-3_end	---	93	93	93	---
# 4_start-4_end	---	93	93	93	---
# 5_start-5_end	---	93	93	93	---
# 6_start-6_end	---	---	---	93	---
#
#  Profesor:  76 76
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	33	---
# 10_start-10_end	---	33	---	33	18
# 11_start-11_end	---	33	---	---	18
# 12_start-12_end	---	18	---	---	---
# 13_start-13_end	---	18	---	---	---
#
#  Profesor:  77 77
# 	1	2	3	4	5
# 1_start-1_end	---	---	---	25	---
# 2_start-2_end	---	25	---	25	---
# 3_start-3_end	---	25	---	---	---
# 4_start-4_end	---	25	---	---	---
#
#  Profesor:  80 80
# 	1	2	3	4	5
# 9_start-9_end	79	---	---	---	---
# 10_start-10_end	79	---	---	---	---
# 11_start-11_end	---	---	---	79	---
# 12_start-12_end	---	---	---	79	---
#
#  Profesor:  82 82
# 	1	2	3	4	5
# 0_start-0_end	---	76	---	---	76
# 1_start-1_end	---	76	---	---	76
# 12_start-12_end	---	---	---	---	1
# 13_start-13_end	---	---	---	---	1
# 14_start-14_end	---	---	---	---	1
#
#  Profesor:  84 84
# 	1	2	3	4	5
# 4_start-4_end	---	---	---	73	---
# 5_start-5_end	---	---	---	73	---
# 9_start-9_end	---	---	---	73	---
# 10_start-10_end	---	---	---	73	---
#
#  Profesor:  85 85
# 	1	2	3	4	5
# 1_start-1_end	---	23	---	23	---
# 2_start-2_end	---	23	---	23	---
# 3_start-3_end	92	---	---	23	---
# 4_start-4_end	92	---	92	---	---
# 5_start-5_end	92	---	92	---	---
#
#  Profesor:  86 86
# 	1	2	3	4	5
# 0_start-0_end	46	---	---	46	---
# 1_start-1_end	46	---	---	46	---
#
#  Profesor:  87 87
# 	1	2	3	4	5
# 14_start-14_end	---	47	---	---	---
# 15_start-15_end	---	47	---	---	---
#
#  Profesor:  88 88
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	63	---
# 14_start-14_end	---	---	---	63	---
# 15_start-15_end	---	---	---	63	---
#
#  Profesor:  91 91
# 	1	2	3	4	5
# 2_start-2_end	---	---	55	---	---
# 3_start-3_end	67	---	55	---	---
# 4_start-4_end	67	---	67	---	---
# 5_start-5_end	67	---	67	---	55
# 6_start-6_end	---	---	---	---	55
# 7_start-7_end	---	---	10	---	10
# 8_start-8_end	---	---	10	---	10
# 9_start-9_end	---	---	---	---	10
#
#  Profesor:  92 92
# 	1	2	3	4	5
# 9_start-9_end	---	2	---	2	---
# 10_start-10_end	---	2	---	2	---
# 11_start-11_end	---	---	---	2	---
#
#  Profesor:  94 94
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	14	---
# 12_start-12_end	---	---	---	14	---
# 13_start-13_end	---	---	---	14	---
#
#  Profesor:  95 95
# 	1	2	3	4	5
# 8_start-8_end	86	---	---	---	---
# 9_start-9_end	86	---	---	---	---
# 10_start-10_end	86	---	---	---	86
# 11_start-11_end	---	---	---	---	86
#
#  Profesor:  97 97
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	72	---
# 14_start-14_end	72	---	---	72	---
# 15_start-15_end	72	---	---	---	---
#
#  Profesor:  99 99
# 	1	2	3	4	5
# 11_start-11_end	---	20	---	---	---
# 12_start-12_end	---	20	---	---	---
#
#  Profesor:  100 100
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	45	---
# 11_start-11_end	---	---	---	45	81
# 12_start-12_end	---	---	---	---	81
# 13_start-13_end	---	81	---	---	---
# 14_start-14_end	---	81	---	---	---
#
#  Profesor:  101 101
# 	1	2	3	4	5
# 12_start-12_end	---	95	---	---	---
# 13_start-13_end	---	95	---	---	---
#
#  Profesor:  102 102
# 	1	2	3	4	5
# 7_start-7_end	---	---	23	---	23
# 8_start-8_end	---	---	23	---	23
# 9_start-9_end	78	---	23	78	---
# 10_start-10_end	78	---	---	78	---
#
#  Profesor:  103 103
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	85
# 1_start-1_end	---	---	---	---	85
#
#  Profesor:  104 104
# 	1	2	3	4	5
# 0_start-0_end	---	91	---	---	---
# 1_start-1_end	---	91	---	---	---
# 2_start-2_end	---	91	---	91	---
# 3_start-3_end	---	91	---	---	---
# 4_start-4_end	---	---	---	91	---
#
#  Profesor:  106 106
# 	1	2	3	4	5
# 11_start-11_end	---	7	---	---	---
# 12_start-12_end	---	7	---	7	---
# 13_start-13_end	---	7	---	7	---
#
#  Profesor:  107 107
# 	1	2	3	4	5
# 0_start-0_end	---	13	---	---	13
# 1_start-1_end	---	13	---	---	13
# 2_start-2_end	---	13	---	---	---
#
#  Profesor:  108 108
# 	1	2	3	4	5
# 0_start-0_end	---	---	62	---	---
# 1_start-1_end	---	---	62	---	---
# 2_start-2_end	---	---	---	---	62
# 3_start-3_end	---	---	---	---	62
#
#  Profesor:  109 109
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	39	---
# 4_start-4_end	---	39	---	39	---
# 5_start-5_end	---	39	---	39	---
#
#  Profesor:  111 111
# 	1	2	3	4	5
# 3_start-3_end	---	65	---	---	---
# 4_start-4_end	---	65	---	65	---
# 5_start-5_end	---	65	---	65	---
#
#  Profesor:  112 112
# 	1	2	3	4	5
# 0_start-0_end	---	---	42	73	---
# 1_start-1_end	---	---	42	73	---
# 9_start-9_end	---	49	---	---	---
# 10_start-10_end	---	49	42	---	---
# 11_start-11_end	---	49	42	---	---
#
#  Profesor:  115 115
# 	1	2	3	4	5
# 0_start-0_end	19	---	19	---	---
# 1_start-1_end	19	---	19	---	---
# 2_start-2_end	---	---	19	---	---
# 11_start-11_end	---	---	11	---	11
# 12_start-12_end	---	---	11	---	11
# 13_start-13_end	---	---	11	---	---
#
#  Profesor:  116 116
# 	1	2	3	4	5
# 0_start-0_end	---	---	67	---	---
# 1_start-1_end	66	---	67	---	66
# 2_start-2_end	66	---	6	---	66
# 3_start-3_end	67	---	6	---	66
# 4_start-4_end	67	---	6	---	---
# 5_start-5_end	67	---	6	---	---
#
#  Profesor:  119 119
# 	1	2	3	4	5
# 12_start-12_end	---	---	20	---	---
# 13_start-13_end	---	---	20	---	---
#
#  Profesor:  120 120
# 	1	2	3	4	5
# 14_start-14_end	---	---	38	---	---
# 15_start-15_end	38	---	38	---	---
#
#  Profesor:  121 121
# 	1	2	3	4	5
# 12_start-12_end	94	---	---	---	94
# 13_start-13_end	94	---	---	---	94
#
#  Profesor:  122 122
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	45	---
# 11_start-11_end	---	---	---	45	---
#
#  Profesor:  123 123
# 	1	2	3	4	5
# 14_start-14_end	---	91	---	---	91
# 15_start-15_end	---	91	---	---	---
#
#  Profesor:  124 124
# 	1	2	3	4	5
# 0_start-0_end	97	---	97	---	---
# 1_start-1_end	97	---	97	---	---
# 2_start-2_end	97	---	97	---	---
#
#  Profesor:  126 126
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	33	---
# 10_start-10_end	---	33	---	33	---
# 11_start-11_end	---	33	---	---	---
#
#  Profesor:  128 128
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	51
# 1_start-1_end	---	---	---	---	51
# 4_start-4_end	---	51	---	---	---
# 5_start-5_end	---	51	---	---	---
#
#  Profesor:  129 129
# 	1	2	3	4	5
# 9_start-9_end	---	3	3	---	3
# 10_start-10_end	---	3	3	---	3
# 11_start-11_end	---	---	3	---	---
# 13_start-13_end	---	---	3	---	---
# 14_start-14_end	---	---	3	---	---
#
#  Profesor:  131 131
# 	1	2	3	4	5
# 0_start-0_end	54	---	---	---	---
# 1_start-1_end	54	---	---	---	---
# 2_start-2_end	54	---	---	---	---
# 3_start-3_end	54	---	---	---	---
# 4_start-4_end	54	---	---	---	---
# 5_start-5_end	54	---	---	---	---
#
#  Profesor:  132 132
# 	1	2	3	4	5
# 12_start-12_end	44	---	---	---	---
# 13_start-13_end	44	---	---	---	44
# 14_start-14_end	44	---	---	---	44
#
#  Profesor:  134 134
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	---	9
# 12_start-12_end	---	---	---	---	9
# 13_start-13_end	---	---	---	---	9
# 14_start-14_end	---	---	---	---	9
#
#  Profesor:  135 135
# 	1	2	3	4	5
# 9_start-9_end	60	---	60	---	---
# 10_start-10_end	60	---	60	---	---
#
#  Profesor:  136 136
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	36
# 13_start-13_end	---	---	---	---	36
# 14_start-14_end	---	---	---	---	36
#
#  Profesor:  137 137
# 	1	2	3	4	5
# 13_start-13_end	---	---	13	---	---
# 14_start-14_end	13	34	13	34	---
# 15_start-15_end	13	34	13	34	---
#
#  Profesor:  138 138
# 	1	2	3	4	5
# 2_start-2_end	---	8	---	---	---
# 3_start-3_end	---	8	---	8	8
# 4_start-4_end	---	8	---	8	8
# 5_start-5_end	---	8	---	---	---
# 11_start-11_end	31	---	---	---	---
# 12_start-12_end	31	---	---	---	31
# 13_start-13_end	---	---	---	---	31
#
#  Profesor:  140 140
# 	1	2	3	4	5
# 12_start-12_end	---	---	53	---	---
# 13_start-13_end	53	---	53	---	---
# 14_start-14_end	53	---	53	---	---
#
#  Profesor:  141 141
# 	1	2	3	4	5
# 11_start-11_end	89	---	89	---	---
# 12_start-12_end	89	---	89	---	---
#
#  Profesor:  142 142
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	96
# 1_start-1_end	---	---	---	---	96
# 4_start-4_end	---	---	---	96	96
# 5_start-5_end	---	---	---	96	96
# 7_start-7_end	---	---	---	96	---
# 8_start-8_end	---	---	---	96	---
#
#  Profesor:  145 145
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	82	---
# 1_start-1_end	---	---	---	82	---
# 2_start-2_end	---	---	---	82	---
#
#  Profesor:  146 146
# 	1	2	3	4	5
# 9_start-9_end	75	---	---	---	---
# 10_start-10_end	75	---	---	---	---
# 11_start-11_end	75	---	---	---	---
# 12_start-12_end	75	---	---	---	---
#
#  Profesor:  147 147
# 	1	2	3	4	5
# 9_start-9_end	---	2	---	2	---
# 10_start-10_end	---	2	---	2	---
# 11_start-11_end	---	---	---	2	---
#
#  Profesor:  148 148
# 	1	2	3	4	5
# 0_start-0_end	19	---	19	---	---
# 1_start-1_end	19	---	19	---	---
# 2_start-2_end	---	---	19	---	---
# 11_start-11_end	---	---	11	---	11
# 12_start-12_end	---	---	11	---	11
# 13_start-13_end	---	---	11	---	---
#
#  Profesor:  149 149
# 	1	2	3	4	5
# 2_start-2_end	91	---	---	---	---
# 4_start-4_end	---	---	---	---	91
# 5_start-5_end	---	---	---	---	91
# 9_start-9_end	4	---	4	---	---
# 10_start-10_end	4	---	---	---	---
#
#  Profesor:  150 150
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	39	---
# 4_start-4_end	---	39	---	39	---
# 5_start-5_end	---	39	---	39	---
#
#  Profesor:  151 151
# 	1	2	3	4	5
# 1_start-1_end	---	66	---	---	---
# 2_start-2_end	---	66	---	---	---
# 3_start-3_end	---	66	---	---	---
# 4_start-4_end	---	---	---	---	66
# 5_start-5_end	---	---	---	---	66
# 7_start-7_end	---	92	---	92	---
# 8_start-8_end	---	92	---	92	---
# 9_start-9_end	---	---	---	92	---
#
#  Profesor:  152 152
# 	1	2	3	4	5
# 0_start-0_end	---	88	---	88	---
# 1_start-1_end	---	88	---	88	---
# 2_start-2_end	---	---	---	88	---
# 11_start-11_end	52	---	---	---	---
# 12_start-12_end	52	---	---	52	---
# 13_start-13_end	---	---	---	52	---
# 14_start-14_end	---	---	---	52	---
#
#  Profesor:  156 156
# 	1	2	3	4	5
# 12_start-12_end	---	24	---	24	---
# 13_start-13_end	---	24	---	24	---
#
#  Profesor:  157 157
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	---	13
# 4_start-4_end	---	13	---	---	13
# 5_start-5_end	---	13	---	---	13
#
#  Profesor:  158 158
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	---	88
# 4_start-4_end	---	88	---	---	88
# 5_start-5_end	---	88	---	---	88
#
#  Profesor:  159 159
# 	1	2	3	4	5
# 0_start-0_end	46	---	---	---	---
# 1_start-1_end	46	---	---	---	---
# 2_start-2_end	---	---	---	46	---
# 3_start-3_end	---	---	---	46	---
#
#  Profesor:  160 160
# 	1	2	3	4	5
# 9_start-9_end	---	---	58	---	---
# 10_start-10_end	---	---	58	---	58
# 11_start-11_end	---	---	---	---	58
#
#  Profesor:  161 161
# 	1	2	3	4	5
# 0_start-0_end	---	74	---	---	---
# 1_start-1_end	---	74	---	---	---
# 3_start-3_end	---	---	---	---	74
# 4_start-4_end	---	---	---	---	74
# 5_start-5_end	---	---	---	---	74
#
#  Profesor:  162 162
# 	1	2	3	4	5
# 9_start-9_end	---	77	77	---	77
# 10_start-10_end	---	77	77	---	77
# 11_start-11_end	---	---	77	---	---
# 13_start-13_end	---	---	77	---	---
# 14_start-14_end	---	---	77	---	---
#
#  Profesor:  163 163
# 	1	2	3	4	5
# 0_start-0_end	---	44	---	44	---
# 1_start-1_end	---	44	---	44	---
# 2_start-2_end	---	---	---	44	---
#
#  Profesor:  164 164
# 	1	2	3	4	5
# 9_start-9_end	---	68	---	---	---
# 10_start-10_end	---	68	---	---	---
# 11_start-11_end	---	---	---	68	---
# 12_start-12_end	---	---	---	68	---
# 14_start-14_end	---	68	---	68	---
# 15_start-15_end	---	68	---	68	---
#
#  Profesor:  165 165
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	49	---
# 1_start-1_end	---	---	49	49	---
# 2_start-2_end	---	---	49	49	---
# 3_start-3_end	---	---	49	---	---
#
#  Profesor:  167 167
# 	1	2	3	4	5
# 9_start-9_end	---	---	4	---	---
# 10_start-10_end	---	---	4	---	4
#
#  Profesor:  168 168
# 	1	2	3	4	5
# 11_start-11_end	28	---	---	---	---
# 12_start-12_end	28	---	---	---	28
# 13_start-13_end	---	---	---	---	28

# %% [markdown]
# ## Estadísticas de resultados

# %% [markdown]
# ### Promedios de prioridad

# %%
if not model.Status == GRB.INFEASIBLE and "prioridades" in objectives:
    
    CARGA_HORARIA_TOTAL = np.sum([round(y_dict[p, b].variable.X)
                              for p in profesores_ids
                              for b in bloques_horario_ids
                              ])

    obj = objectives["prioridades"][0].getValue()
    print(obj)
    print("Promedio general de prioridad horaria: ", obj/CARGA_HORARIA_TOTAL)
          

# print("Casos de materias con dias consecutivos: ", int(OBJ2.getValue()/10))
# Out:
# 951.0
# Promedio general de prioridad horaria:  1.3944281524926687

# %%
# promedio por profesor:
"""
This script calculates and prints the average workload per professor based on their assigned priorities and time blocks.
Variables:
    profesores (list): List of professor objects, each containing their priorities.
    y_dict (dict): Dictionary mapping professor IDs and time block IDs to Gurobi variables.
    bloques_horario_ids (list): List of time block IDs.
For each professor in the list `profesores`, the script performs the following steps:
1. Initializes a quadratic expression `OBJ_p` to accumulate the weighted priorities.
2. Iterates over the professor's priorities to update `OBJ_p` based on the priority value and corresponding Gurobi variable.
3. Calculates the total workload `CARGA_HORARIA_p` for the professor by summing the relevant Gurobi variables.
4. If the total workload is non-zero, it prints the professor's name, total workload, and the rounded average priority value per workload unit.
5. If the total workload is zero, it prints the professor's name and indicates that they have no workload.

"""
if not model.Status == GRB.INFEASIBLE:
    for p in profesores:

        OBJ_p = gp.QuadExpr()
        # for m in materias:
        #     for pr in p.prioridades:
        #             b = pr.bloque_horario
        #             A = pr.value
        #             OBJ_p += A * w_dict[m.id, p.id].variable * u_dict[m.id, b.id].variable

        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            OBJ_p += A * y_dict[p.id, b.id].variable
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()
        CARGA_HORARIA_p = round(gp.quicksum(y_dict[p.id, b].variable for b in bloques_horario_ids).getValue())

        if CARGA_HORARIA_p != 0:
            print(str(p), "\t", CARGA_HORARIA_p, "\t", round(round(OBJ_p.getValue())/CARGA_HORARIA_p,3))
        else:
            print(str(p), "sin carga horaria")
# Out:
# 3 	 7 	 1.714
# 4 	 8 	 1.0
# 5 	 6 	 1.0
# 6 	 3 	 1.0
# 7 	 4 	 2.0
# 9 	 4 	 1.25
# 11 	 5 	 1.8
# 12 	 5 	 1.4
# 13 	 8 	 1.75
# 14 	 12 	 1.0
# 15 	 12 	 1.0
# 16 	 3 	 1.0
# 17 	 3 	 1.0
# 18 	 6 	 1.333
# 21 	 4 	 3.0
# 26 	 10 	 1.0
# 28 	 4 	 1.0
# 29 	 4 	 1.5
# 30 	 8 	 1.25
# 31 	 5 	 1.2
# 32 	 6 	 1.0
# 33 	 4 	 2.0
# 34 	 4 	 1.25
# 36 	 15 	 1.733
# 37 	 4 	 3.0
# 38 	 5 	 2.6
# 39 	 8 	 1.0
# 42 	 4 	 1.75
# 43 	 6 	 1.833
# 44 	 3 	 1.0
# 47 	 5 	 1.8
# 48 	 5 	 1.6
# 49 	 4 	 1.25
# 50 	 7 	 1.571
# 53 	 5 	 1.0
# 54 	 4 	 2.5
# 55 	 7 	 1.0
# 57 	 4 	 1.0
# 58 	 4 	 2.0
# 59 	 12 	 1.667
# 60 	 4 	 1.0
# 61 	 11 	 1.545
# 62 	 5 	 2.2
# 64 	 5 	 1.2
# 66 	 6 	 1.167
# 68 	 4 	 1.0
# 71 	 10 	 2.0
# 72 	 4 	 1.5
# 74 	 10 	 1.0
# 75 	 12 	 1.0
# 76 	 8 	 1.0
# 77 	 5 	 1.2
# 80 	 4 	 1.5
# 82 	 7 	 1.286
# 84 	 4 	 1.25
# 85 	 10 	 1.0
# 86 	 4 	 1.5
# 87 	 2 	 1.0
# 88 	 3 	 1.0
# 91 	 14 	 1.643
# 92 	 5 	 1.0
# 94 	 3 	 2.0
# 95 	 5 	 1.8
# 97 	 4 	 1.75
# 99 	 2 	 1.5
# 100 	 6 	 1.5
# 101 	 2 	 3.0
# 102 	 9 	 1.0
# 103 	 2 	 2.0
# 104 	 6 	 1.0
# 106 	 5 	 2.8
# 107 	 5 	 1.2
# 108 	 4 	 1.0
# 109 	 5 	 2.0
# 111 	 5 	 1.0
# 112 	 9 	 1.667
# 115 	 10 	 1.0
# 116 	 14 	 1.0
# 119 	 2 	 1.5
# 120 	 3 	 2.0
# 121 	 4 	 2.0
# 122 	 2 	 1.0
# 123 	 3 	 1.0
# 124 	 6 	 1.0
# 126 	 4 	 1.0
# 128 	 4 	 1.0
# 129 	 9 	 2.111
# 131 	 6 	 1.0
# 132 	 5 	 1.0
# 134 	 4 	 1.0
# 135 	 4 	 1.0
# 136 	 3 	 2.0
# 137 	 9 	 1.444
# 138 	 12 	 1.083
# 140 	 5 	 1.4
# 141 	 4 	 1.0
# 142 	 8 	 1.5
# 145 	 3 	 1.0
# 146 	 4 	 1.0
# 147 	 5 	 1.0
# 148 	 10 	 1.0
# 149 	 6 	 1.0
# 150 	 5 	 1.4
# 151 	 10 	 1.0
# 152 	 10 	 2.2
# 156 	 4 	 1.0
# 157 	 5 	 1.0
# 158 	 5 	 1.0
# 159 	 4 	 1.0
# 160 	 4 	 1.0
# 161 	 5 	 1.0
# 162 	 9 	 1.0
# 163 	 5 	 1.0
# 164 	 8 	 1.5
# 165 	 6 	 1.0
# 167 	 3 	 1.333
# 168 	 4 	 3.0

# %%
# # DIAS CLASE POR PROFESOR

# print("DIAS CON CLASE")
# for p in profesores:
#     if p.min_max_dias is not None:
#         print(str(p), ": ", round(DP[p.id].getValue()), p.min_max_dias)

# %%
# HORAS PUENTE

# HP = gp.QuadExpr()
# for g in grupos_reales:
#     HPg = gp.QuadExpr()
#     for d in dias_ids:
#         HPg += gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
#         HPg += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
#         HPg += - 1
#     # print("horas puente grupo", str(g), ": ", HPg.getValue())
#     HP += HPg

# print("Total de horas puente: ", HP.getValue())

# %% [markdown]
# #### Distribucion de prioridades

# %%
# distribucion de prioridades
"""
This script calculates and prints the distribution of priorities and their averages for a given set of professors and their time block priorities.
Variables:
    promedios_prioridad (dict): A dictionary to store the average priority values for each priority level.
    valores_prioridad (dict): A dictionary to store the count of each priority level.
    profesores (list): A list of professor objects, each containing their priority information.
    y_dict (dict): A dictionary containing the decision variables for the optimization model.
Process:
1. Initialize dictionaries to store priority averages and counts.
2. Iterate over each professor and their priorities:
    - Skip if the priority value is 0.
    - Increment the count for the given priority value.
    - Update the average priority value based on the decision variable.
3. Print the count and percentage distribution of each priority level.
4. Print the average priority values and their percentage distribution.

"""

if not model.Status == GRB.INFEASIBLE:
    promedios_prioridad = {}
    valores_prioridad = {}
    for i in range(1,4):
        promedios_prioridad[i] = 0
        valores_prioridad[i] = 0

    for p in profesores:
        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            if A == 0:
                continue
            valores_prioridad[A] += 1
            # for m in materias:
            #     promedios_prioridad[A] += round(w_dict[m.id, p.id].variable.X * u_dict[m.id, b.id].variable.X)
            promedios_prioridad[A] += round(y_dict[p.id, b.id].variable.X)

    print(valores_prioridad)
    total = np.sum([valores_prioridad[i] for i in valores_prioridad])
    print(*[str(i) + ": " + str(round(valores_prioridad[i]/total*100))+"%" for i in valores_prioridad], sep=", ")

    print(promedios_prioridad)
    total = np.sum([promedios_prioridad[i] for i in promedios_prioridad])
    if total != 0:
        print(*[str(i) + ": " + str(round(promedios_prioridad[i]/total*100))+"%" for i in promedios_prioridad], sep=", ")
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()

        # if CARGA_HORARIA_p != 0:
        #     print(str(p), ": ", OBJ_p.getValue()/CARGA_HORARIA_p)
        # else:
        #     print(str(p), "sin carga horaria")
# Out:
# {1: 3179, 2: 442, 3: 424}
# 1: 79%, 2: 11%, 3: 10%
# {1: 510, 2: 94, 3: 78}
# 1: 75%, 2: 14%, 3: 11%

# %% [markdown]
# ### Ocupacion de salones

# %%
# nivel de ocupacion
if not model.Status == GRB.INFEASIBLE:
    niveles = {}

    for b_id in bloques_horario:
        salones_ocupados = int(gp.quicksum(u_dict[m, b_id].variable for m in materias_ids).getValue())
        nivel = int(salones_ocupados/K*100)
        # print(str(bloques_horario[b_id]), ": ", salones_ocupados,",", str(nivel) + "%")
        niveles[b_id] = nivel

    print_timetable_salones(dias, horarios, niveles)
# Out:
# 		1	2	3	4	5
# ··········································································································
# 0_start-0_end	61%	69%	53%	69%	69%
# 1_start-1_end	76%	84%	69%	84%	92%
# 2_start-2_end	69%	76%	84%	92%	76%
# 3_start-3_end	69%	76%	69%	76%	76%
# 4_start-4_end	69%	92%	61%	76%	69%
# 5_start-5_end	53%	84%	46%	61%	69%
# 6_start-6_end	0%	0%	7%	7%	7%
# 7_start-7_end	7%	30%	15%	30%	15%
# 8_start-8_end	15%	30%	15%	30%	23%
# 9_start-9_end	61%	76%	61%	53%	61%
# 10_start-10_end	69%	92%	76%	53%	84%
# 11_start-11_end	100%	61%	69%	69%	69%
# 12_start-12_end	92%	84%	84%	92%	76%
# 13_start-13_end	53%	84%	84%	92%	76%
# 14_start-14_end	53%	61%	69%	61%	69%
# 15_start-15_end	30%	38%	30%	30%	7%

# %%
# model.write('timetable_opt.lp')
# model.write('timetable_opt.mps')
