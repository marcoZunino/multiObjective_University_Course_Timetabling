# %% [markdown]
# Imports

# %%
from gurobipy import *
import numpy as np

from db_manager import *
from load_data import *
from printing import *

# %%
# clases
from entities import *
from variables import *

# %% [markdown]
# # Cargar datos

# %% [markdown]
# ## (1) Instancia

# %%
instance = "../instances/instance_2026sem1.json"
dias, turnos, horarios, bloques_horario, grupos, materias, profesores, superposicion, superposicion_electivas = read_json_instance(instance)

# %%
dias_ids = [d.id for d in dias]
DIAS = dias

horarios_ids = [h.id for h in horarios]
HORARIOS = horarios

bloques_horario_ids = [b for b in bloques_horario]
BLOQUES_HORARIO = bloques_horario

profesores_ids = [p.id for p in profesores]
PROFESORES = profesores

grupos_ids = [g.id for g in grupos]
GRUPOS = grupos

anios = list(set([g.anio for g in grupos if g.anio != None]))  # anios
ANIOS = anios

materias_ids = [m.id for m in materias]
MATERIAS = materias

SUPERPOSICION = superposicion
SUPERPOSICION_ELECTIVAS = superposicion_electivas

# %%
# # print(*[str(g) for g in grupos], sep="\n")
# print(*[m.profesores for m in materias], sep="\n")

# %%
print_prioridades(dias, horarios, profesores)
# Out:
#  Profesor: 3 3  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	3	3	-
# 1_start-1_end	-	-	1	1	-
# 2_start-2_end	-	-	1	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	2	2	-	-	2
# 10_start-10_end	1	1	-	-	1
# 11_start-11_end	1	1	-	-	1
# 12_start-12_end	3	3	-	-	3
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 4 4  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	1	1	-	-	1
# 2_start-2_end	1	1	-	-	1
# 3_start-3_end	1	1	-	-	1
# 4_start-4_end	1	1	-	-	1
# 5_start-5_end	1	1	-	-	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	1	-	-	1
# 8_start-8_end	-	1	-	-	1
# 9_start-9_end	-	1	-	-	1
# 10_start-10_end	-	1	-	-	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 5 5  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 6 6  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	3	-	3	-
# 12_start-12_end	1	1	-	1	-
# 13_start-13_end	1	1	-	1	-
# 14_start-14_end	1	1	-	1	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 7 7  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	3
# 11_start-11_end	-	1	-	1	3
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	2	-	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 9 9  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	2	-	2	-
# 14_start-14_end	-	3	-	3	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 11 11  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	3	3	3	3	3
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	2	2	2	2	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 12 12  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	2	2	2	-	3
# 3_start-3_end	1	1	1	-	1
# 4_start-4_end	1	1	1	-	1
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 13 13  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	3	-	3	-
#
#  Profesor: 14 14  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	-	-
# 1_start-1_end	-	1	-	-	-
# 2_start-2_end	-	1	-	-	-
# 3_start-3_end	-	1	-	-	-
# 4_start-4_end	1	1	1	-	-
# 5_start-5_end	1	1	1	-	-
# 6_start-6_end	1	1	1	-	-
# 7_start-7_end	1	1	1	-	-
# 8_start-8_end	1	1	1	-	-
# 9_start-9_end	1	1	1	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 15 15  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	1	-	1	-
# 7_start-7_end	-	1	-	1	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	1	-	2	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 16 16  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 17 17  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	1	-	1
# 1_start-1_end	-	-	1	-	1
# 2_start-2_end	-	-	1	-	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 18 18  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 21 21  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 26 26  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	-	1	-
# 12_start-12_end	1	1	-	1	-
# 13_start-13_end	1	1	-	1	-
# 14_start-14_end	1	1	-	1	-
# 15_start-15_end	1	1	-	1	-
#
#  Profesor: 28 28  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 29 29  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	1	-	1	-	-
# 11_start-11_end	1	-	1	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 30 30  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	2	-	2	2
# 11_start-11_end	-	1	-	1	1
# 12_start-12_end	-	1	-	1	1
# 13_start-13_end	-	1	-	1	1
# 14_start-14_end	-	1	-	1	1
# 15_start-15_end	-	3	-	3	3
#
#  Profesor: 31 31  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	2	2	2	2	2
# 4_start-4_end	2	2	2	2	2
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 32 32  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	2	2	2	-
# 3_start-3_end	-	2	2	2	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	1	1	-	-
# 12_start-12_end	1	1	1	-	-
# 13_start-13_end	1	1	1	-	-
# 14_start-14_end	1	1	1	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 33 33  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	3	-	3	-
# 3_start-3_end	-	1	-	1	1
# 4_start-4_end	-	1	-	1	1
# 5_start-5_end	-	2	-	2	2
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 34 34  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 36 36  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	1	-	1
# 3_start-3_end	-	-	1	-	1
# 4_start-4_end	-	-	1	-	1
# 5_start-5_end	-	-	3	-	2
# 6_start-6_end	-	-	3	-	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	2	-	3
# 10_start-10_end	-	-	2	-	3
# 11_start-11_end	-	-	1	-	1
# 12_start-12_end	-	-	1	-	1
# 13_start-13_end	-	-	1	-	1
# 14_start-14_end	-	-	3	-	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 37 37  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	3	1	3	1	3
# 9_start-9_end	3	1	2	1	3
# 10_start-10_end	3	1	2	1	3
# 11_start-11_end	3	1	2	1	3
# 12_start-12_end	3	2	2	2	3
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 38 38  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	3	2	3	2	3
# 3_start-3_end	3	2	3	2	3
# 4_start-4_end	3	2	3	2	3
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	3
# 8_start-8_end	1	1	1	1	3
# 9_start-9_end	1	1	1	1	3
# 10_start-10_end	1	1	1	1	3
# 11_start-11_end	2	1	1	1	-
# 12_start-12_end	2	1	1	1	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor:
|> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	-	1	-	1
# 1_start-1_end	1	-	1	-	1
# 2_start-2_end	1	-	1	-	1
# 3_start-3_end	1	-	1	-	1
# 4_start-4_end	1	-	1	-	1
# 5_start-5_end	1	-	1	-	1
# 6_start-6_end	2	-	2	-	2
# 7_start-7_end	2	-	2	-	2
# 8_start-8_end	3	-	3	-	3
# 9_start-9_end	3	-	3	-	3
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 92 92  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 94 94  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	3	3	3	3	2
# 10_start-10_end	1	2	1	2	2
# 11_start-11_end	1	2	1	2	2
# 12_start-12_end	1	2	1	2	2
# 13_start-13_end	1	2	1	2	3
# 14_start-14_end	2	2	2	2	3
# 15_start-15_end	2	2	2	2	3
#
#  Profesor: 95 95  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	3	2	2	2	1
# 10_start-10_end	3	3	3	3	1
# 11_start-11_end	-	-	-	-	1
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 97 97  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	3	3	3	3
# 12_start-12_end	2	1	2	2	3
# 13_start-13_end	2	1	1	1	3
# 14_start-14_end	2	1	1	1	3
# 15_start-15_end	3	2	2	2	-
#
#  Profesor: 99 99  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	1	1	1	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	2	2	2	2	-
# 13_start-13_end	-	3	3	3	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 100 100  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 101 101  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	1	-	-	-
# 11_start-11_end	-	1	-	-	-
# 12_start-12_end	-	3	-	-	-
# 13_start-13_end	-	3	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 102 102  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	3	3	-	-
# 1_start-1_end	-	3	-	3	3
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	3	3	3	3	3
# 5_start-5_end	3	3	3	3	3
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 103 103  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	2
# 1_start-1_end	1	1	1	1	2
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 104 104  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	1	-
# 1_start-1_end	-	1	-	1	-
# 2_start-2_end	-	1	-	1	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 106 106  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	1	-	1	-
# 9_start-9_end	-	1	-	1	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	2	-	2	-
# 12_start-12_end	-	3	-	3	-
# 13_start-13_end	-	3	-	3	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 107 107  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	2	2	2	2	2
# 3_start-3_end	3	3	3	3	3
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	2	2	2	2	2
# 15_start-15_end	2	2	2	2	2
#
#  Profesor: 108 108  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 109 109  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	1	2	1
# 3_start-3_end	1	-	1	2	1
# 4_start-4_end	2	2	2	2	3
# 5_start-5_end	2	2	2	2	3
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 111 111  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	1	-	1	-
# 4_start-4_end	-	1	-	1	-
# 5_start-5_end	-	1	-	1	-
# 6_start-6_end	-	1	-	1	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 112 112  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	2	2	2	2
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	2	1	1	1	2
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	2	2	2	1
# 11_start-11_end	2	2	2	2	2
# 12_start-12_end	2	2	2	2	2
# 13_start-13_end	2	3	3	3	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 115 115  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 116 116  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	-	1	-	1
# 1_start-1_end	1	-	1	-	1
# 2_start-2_end	1	-	1	-	1
# 3_start-3_end	1	-	1	-	1
# 4_start-4_end	1	-	1	-	1
# 5_start-5_end	1	-	1	-	2
# 6_start-6_end	1	-	1	-	2
# 7_start-7_end	2	-	2	-	-
# 8_start-8_end	2	-	2	-	-
# 9_start-9_end	3	-	3	-	-
# 10_start-10_end	3	-	3	-	-
# 11_start-11_end	3	-	3	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 119 119  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	2	2	2	2	-
# 11_start-11_end	1	1	1	1	-
# 12_start-12_end	1	1	1	1	-
# 13_start-13_end	2	2	2	2	-
# 14_start-14_end	3	3	3	3	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 120 120  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	-	-	-
# 12_start-12_end	1	-	1	-	-
# 13_start-13_end	1	-	1	-	-
# 14_start-14_end	2	-	2	-	-
# 15_start-15_end	2	-	2	-	-
#
#  Profesor: 121 121  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	1	1	2
# 12_start-12_end	2	1	1	1	2
# 13_start-13_end	2	1	1	1	2
# 14_start-14_end	2	1	1	1	2
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 122 122  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	3	3	3	3	3
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	2	2	2	2	2
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 123 123  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 124 124  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	-	-
# 1_start-1_end	1	1	1	-	-
# 2_start-2_end	1	1	1	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 126 126  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	2	1	2	1	-
# 10_start-10_end	2	1	2	1	-
# 11_start-11_end	2	1	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 128 128  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 129 129  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	3	3	3	3
# 9_start-9_end	-	3	3	3	3
# 10_start-10_end	-	1	1	1	1
# 11_start-11_end	-	1	1	1	1
# 12_start-12_end	-	3	3	3	3
# 13_start-13_end	-	3	3	3	3
# 14_start-14_end	-	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 131 131  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	-
# 5_start-5_end	1	1	1	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 132 132  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	-	-	1
# 12_start-12_end	1	-	-	-	1
# 13_start-13_end	1	-	-	-	1
# 14_start-14_end	1	-	-	-	1
# 15_start-15_end	1	-	-	-	1
#
#  Profesor: 134 134  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 135 135  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	2
# 7_start-7_end	1	-	1	-	2
# 8_start-8_end	1	-	1	-	2
# 9_start-9_end	1	-	1	-	-
# 10_start-10_end	1	-	1	-	-
# 11_start-11_end	1	-	1	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 136 136  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	-	-	-	2
# 13_start-13_end	1	-	-	-	2
# 14_start-14_end	1	-	-	-	2
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 137 137  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	1	1	1	3	1
# 14_start-14_end	1	1	1	3	1
# 15_start-15_end	1	1	1	3	1
#
#  Profesor: 138 138  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 140 140  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	2	2	1	2	1
# 13_start-13_end	2	2	1	2	1
# 14_start-14_end	2	2	1	2	1
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 141 141  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	1	-	1
# 1_start-1_end	-	-	1	-	1
# 2_start-2_end	3	3	2	2	-
# 3_start-3_end	3	3	2	2	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	1	-	1	-	2
# 12_start-12_end	1	-	1	-	2
# 13_start-13_end	-	-	3	-	-
# 14_start-14_end	-	-	3	-	-
# 15_start-15_end	-	-	3	-	-
#
#  Profesor: 142 142  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	2
# 1_start-1_end	-	-	-	-	2
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	1	1
# 5_start-5_end	-	-	-	1	1
# 6_start-6_end	-	-	-	1	1
# 7_start-7_end	-	1	-	2	1
# 8_start-8_end	-	1	-	2	1
# 9_start-9_end	-	-	-	3	1
# 10_start-10_end	-	-	-	3	1
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 145 145  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	2	1	1	1	1
# 1_start-1_end	2	1	1	1	1
# 2_start-2_end	2	1	1	1	1
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 146 146  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 147 147  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 148 148  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 149 149  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	-
# 3_start-3_end	1	1	1	1	-
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	3	3	3	3	3
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	-
# 10_start-10_end	1	1	1	1	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 150 150  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	3	3	-	3	3
# 2_start-2_end	2	2	-	2	2
# 3_start-3_end	1	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	2	2	2	2	2
# 6_start-6_end	2	2	2	2	2
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	2	2	2	2	2
# 14_start-14_end	3	3	3	3	3
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 151 151  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	-	-	-
# 1_start-1_end	-	1	-	-	-
# 2_start-2_end	-	1	-	1	1
# 3_start-3_end	-	1	-	1	1
# 4_start-4_end	1	1	-	1	1
# 5_start-5_end	1	1	-	1	1
# 6_start-6_end	1	1	-	1	1
# 7_start-7_end	1	1	-	1	1
# 8_start-8_end	1	1	-	1	1
# 9_start-9_end	1	-	-	1	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 152 152  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	3	3	1	2
# 1_start-1_end	1	3	3	1	2
# 2_start-2_end	-	3	3	1	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	2	1	1	3	3
# 12_start-12_end	2	1	1	3	3
# 13_start-13_end	2	1	1	3	3
# 14_start-14_end	2	1	1	3	3
# 15_start-15_end	2	1	1	3	3
#
#  Profesor: 156 156  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	2	2	2	2	2
# 15_start-15_end	3	3	3	3	3
#
#  Profesor: 157 157  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 158 158  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 159 159  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 160 160  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 161 161  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 162 162  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 163 163  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	1	1	1	1	1
# 1_start-1_end	1	1	1	1	1
# 2_start-2_end	1	1	1	1	1
# 3_start-3_end	1	1	1	1	1
# 4_start-4_end	1	1	1	1	1
# 5_start-5_end	1	1	1	1	1
# 6_start-6_end	1	1	1	1	1
# 7_start-7_end	1	1	1	1	1
# 8_start-8_end	1	1	1	1	1
# 9_start-9_end	1	1	1	1	1
# 10_start-10_end	1	1	1	1	1
# 11_start-11_end	1	1	1	1	1
# 12_start-12_end	1	1	1	1	1
# 13_start-13_end	1	1	1	1	1
# 14_start-14_end	1	1	1	1	1
# 15_start-15_end	1	1	1	1	1
#
#  Profesor: 164 164  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	2	-	2	-
# 9_start-9_end	-	2	-	2	-
# 10_start-10_end	-	2	-	2	-
# 11_start-11_end	-	1	-	1	-
# 12_start-12_end	-	1	-	1	-
# 13_start-13_end	-	1	-	1	-
# 14_start-14_end	-	1	-	1	-
# 15_start-15_end	-	2	-	2	-
#
#  Profesor: 165 165  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	1	1	1	-
# 1_start-1_end	-	1	1	1	-
# 2_start-2_end	-	1	1	1	-
# 3_start-3_end	-	1	1	1	-
# 4_start-4_end	-	1	1	1	-
# 5_start-5_end	-	1	1	1	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	-	-	-	-	-
# 12_start-12_end	-	-	-	-	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 167 167  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	1	-	3	3	2
# 3_start-3_end	1	-	1	1	1
# 4_start-4_end	1	-	1	1	1
# 5_start-5_end	1	-	1	1	1
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	1	-	1	1	1
# 8_start-8_end	-	-	1	1	1
# 9_start-9_end	-	-	1	1	2
# 10_start-10_end	-	-	1	1	2
# 11_start-11_end	-	-	1	1	-
# 12_start-12_end	-	-	2	2	-
# 13_start-13_end	-	-	-	-	-
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-
#
#  Profesor: 168 168  |> last update: None
# 	1	2	3	4	5
# ·····················································
# 0_start-0_end	-	-	-	-	-
# 1_start-1_end	-	-	-	-	-
# 2_start-2_end	-	-	-	-	-
# 3_start-3_end	-	-	-	-	-
# 4_start-4_end	-	-	-	-	-
# 5_start-5_end	-	-	-	-	-
# 6_start-6_end	-	-	-	-	-
# 7_start-7_end	-	-	-	-	-
# 8_start-8_end	-	-	-	-	-
# 9_start-9_end	-	-	-	-	-
# 10_start-10_end	-	-	-	-	-
# 11_start-11_end	3	1	3	1	3
# 12_start-12_end	3	1	3	1	3
# 13_start-13_end	3	3	3	3	3
# 14_start-14_end	-	-	-	-	-
# 15_start-15_end	-	-	-	-	-

# %%
print("Grupos:", len(grupos))
# print([str(i) for i in grupos])
print("Materias:", len(materias))
# print([str(i) for i in materias])
print("Profesores:", len(profesores))
# print([str(i) for i in profesores])
# Out:
# Grupos: 29
# Materias: 165
# Profesores: 117

# %% [markdown]
# # Formulacion

# %% [markdown]
# ## (2) Variables
#
#
# $$ u_{mb} \in \{0,1\} $$
#
#     m: materia
#     b: bloque horario = [dh]: dia y hora
#
# $$ v_{md} \in \{0,1\} $$
#
#     m: materia
#     d: dia
#
# $$ w_{mp} \in \{0,1\} $$
#
#     m: materia
#     p: profesor
#
#
# $$ x_{gb} \in \{0,1\} $$
#
#     g: grupo
#     b: bloque horario = [dh]: dia y hora
#
# $$ y_{pb} \in \{0,1\} $$
#
#     p: profesor
#     b: bloque horario = [dh]: dia y hora
#
# $$ z_{pd} \in \{0,1\} $$
#
#     p: profesor
#     d: dia

# %%
print(len(materias))
print(len(bloques_horario))
# Out:
# 165
# 80

# %% [markdown]
# ## (3) Restricciones

# %% [markdown]
# ### (3.1) Materias

# %% [markdown]
# #### (3.1.1) superposicion (redundante con la definicion de la variable x)
# $$ \sum_{b} \sum_{m, m'}{u_{mb} \times S_{m,m'} \times u_{m'b}} = 0 $$

# %%
"""
    This code defines constraints to ensure that no two subjects (materias) overlap
    in the same time block (bloque horario).
    Constraints:
        1. For each time block (b) in bloques_horario_ids, the sum of the product of the decision variables 
        (u_dict[m1, b].variable and u_dict[m2, b].variable) and the overlap value (superposicion[(m1, m2)].value)
        for all pairs of subjects (m1, m2) must be equal to 0.
"""

def constr_superposicion(model, u_dict):

    model.addConstrs(gp.quicksum(u_dict[m1, b].variable * superposicion[(m1, m2)].value * u_dict[m2, b].variable
                            for m1 in materias_ids for m2 in materias_ids)
                == 0 for b in bloques_horario_ids)

# %% [markdown]
# #### (3.1.2) cubrir carga horaria para cada materia
# $$ \sum_b{u_{mb}} = C_m $$
#
#     para todo m (c_m: carga horaria)

# %%
def constr_carga_horaria(model, u_dict):
    for m in materias:
        model.addConstr(gp.quicksum(u_dict[m.id, b].variable for b in bloques_horario_ids) == m.carga_horaria)

# %% [markdown]
# #### (3.1.3) particion de horas por materia

# %% [markdown]
# ##### (3.1.3.1) fijar cantidad de dias por materia
#
# $$ \sum_d {v_{md}} = D_m $$
#
#     para todo m

# %%
def constr_dias_materia(model, v_dict):
    for m in materias:
        model.addConstr(gp.quicksum(v_dict[m.id, d].variable for d in dias_ids) == m.cantidad_dias)

# %% [markdown]
# ##### (3.1.3.2) fijar maximo y minimo de horas por dia
#
# $$ v_{md} \times {H_{MIN}}_m \leq \sum_h {u_{mdh}} \leq v_{md} \times {H_{MAX}}_m $$
#
#     para todo m, d

# %%
def constr_max_min_horas(model, u_dict, v_dict):

    for m in materias:

        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        <= m.horas_max() * v_dict[m.id,d].variable for d in dias_ids)
        
        model.addConstrs(gp.quicksum(u_dict[(m.id,(d,h))].variable for h in horarios_ids)
                        >= m.horas_min() * v_dict[m.id,d].variable for d in dias_ids)

# %% [markdown]
# ##### (3.1.3.3) fijar materia a turno de horarios
#
# $$ u_{mb} = 0 $$
#
#     para todo b fuera de m.turnos
#     para todo m

# %%
def constr_turnos_materia(model, u_dict):

    for m in materias:
        no_bloques_materia_ids = [b for b in bloques_horario if b not in bloques_horario_materia(m, bloques_horario)]
        model.addConstrs(u_dict[m.id, b].variable == 0 for b in no_bloques_materia_ids)

# %% [markdown]
# #### (3.1.4) horas consecutivas dentro de un dia
#
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} = v_{md} $$
#     para todo m, d

# %%
def constr_horas_consecutivas(model, u_dict, v_dict):

    model.addConstrs(gp.quicksum(u_dict[(m,(d,h))].variable for h in horarios_ids)
                 - gp.quicksum(u_dict[(m,(d,h))].variable * u_dict[(m,(d,h+1))].variable for h in horarios_ids[0:-1])
                 == v_dict[m, d].variable for m in materias_ids for d in dias_ids)

# %% [markdown]
# Alternativa:
# $$ \sum_h {u_{mdh}} - \sum_h {u_{md(h)} · u_{md(h+1)}} \leq 1 $$
#     para todo m, d

# %% [markdown]
# #### (3.1.5) evitar dias consecutivos para una misma materia
#
# $$ \sum_m \sum_d {v_{m(d)} · v_{m(d+1)}} = 0 $$

# %%
mats_dias_consecutivos = [mat for mat in materias if mat.dias_consecutivos]

def constr_dias_consecutivos(model, v_dict):

    model.addConstrs(gp.quicksum(v_dict[m,d].variable * v_dict[m,d+1].variable for d in dias_ids[0:-1]) == 0
                 for m in [mat.id for mat in materias if not mat in mats_dias_consecutivos])

# %% [markdown]
# ### (3.2) Profesores

# %% [markdown]
# #### (3.2.1) indisponibilidad
#
# $$ \sum_m w_{mp} \times u_{mb} = 0 $$
#
#     para todo p sin disponibilidad en b

# %%
def constr_no_disponible_profesor(model, u_dict, w_dict):
    for m in materias:
        for p in m.profesores:
            for b in p.no_disponible:
                model.addConstr(u_dict[m.id, b.id].variable * w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# #### (3.2.2) unica materia por profesor para un mismo bloque horario
#
# $$ \sum_{m} {w_{mp} \times u_{mb}} \leq 1 $$
#
#     para todo b, p

# %% [markdown]
# REDUNDANTE CON DEFINICION DE y_pb

# %%
p_grupos_simultaneos = [p.nombre for p in profesores if p.cursos_simultaneos]

def constr_unica_materia_profesor(model, u_dict, w_dict):

    for p in [p for p in profesores if p.nombre not in p_grupos_simultaneos]:
        model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids)
                     <= 1 for b in bloques_horario_ids)
        
    # caso particular
    for p in [p for p in profesores if p.nombre in p_grupos_simultaneos]:
        model.addConstrs(gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids)
                     <= 2 for b in bloques_horario_ids)

# %% [markdown]
# #### (3.2.3) profesores por materia

# %% [markdown]
# ##### (3.2.3.1) limitar profesores a lista
#
# $$ w_{mp} = 0 $$
#
#     para todo p not in m.lista_profesores
#     para todo m

# %%
def constr_limitar_profesores_materia(model, w_dict):
    
    for m in materias:
        for p in profesores:
            if p not in m.profesores:
                model.addConstr(w_dict[m.id, p.id].variable == 0)

# %% [markdown]
# ##### (3.2.3.2) cantidad de profesores para una misma materia
#
# $$ \sum_p {w_{mp}} = P_m $$
#
#     para todo m

# %%
def constr_cantidad_profesores(model, w_dict):
    for m in materias:
        model.addConstr(gp.quicksum(w_dict[m.id, p].variable for p in profesores_ids) == m.cantidad_profesores)

# %% [markdown]
# #### (3.2.4) carga horaria por docente: limitar la cantidad de materias por profesor
#
#
# $$ \sum_m {w_{mp}} \leq K_p $$
#
#     para todo p

# %%
# separar por nombre de materia
def constr_grupos_max_profesor(model, w_dict):
    for p in profesores:
        for l in p.lista_materias:
            mats = search_materias_by_nombre(materias, l["nombre_materia"]) # subject_id
            if len(mats) > 0:
                model.addConstr(gp.quicksum(w_dict[m.id, p.id].variable for m in mats) <= l["grupos_max"])

# %% [markdown]
# #### (3.2.5) definicion de variable "y" (asignacion horario-profesor)
#
# $$ y_{pb} = \sum_m{u_{mb}·w_{mp}} $$
#
# $$ y_{pb} = \text{OR}_m \{u_{mb}·w_{mp}\} $$
#
#     para todo p, b

# %%
def constr_definir_y(model, y_dict, u_dict, w_dict):

    for p in profesores:
        uw_vars = {} # variable auxiliar = u_mb·w_mp
        mats_p = materias_profesor(p, materias)
        for m in mats_p:
            # for b_id in bloques_horario_materia(m, bloques_horario):
            for b_id in bloques_horario_ids:
                uw_vars[m.id,b_id] = model.addVar(vtype=GRB.INTEGER, name=str(m)+str(b_id)+str(p)+"_uw")
                model.addConstr(uw_vars[m.id,b_id] == u_dict[m.id,b_id].variable * w_dict[m.id,p.id].variable)
        
        mats_p_ids = [m.id for m in mats_p]
        model.addConstrs(y_dict[p.id,b_id].variable ==
                     gp.or_(uw_vars[m_id,b_id] for m_id in mats_p_ids)
                     for b_id in bloques_horario_ids)
    
    # model.addConstrs(y_dict[p, b].variable ==
    #              gp.quicksum(u_dict[m,b].variable * w_dict[m,p].variable for m in materias_ids)
    #              for b in bloques_horario_ids for p in profesores_ids)

# %% [markdown]
# #### (3.2.6) definicion de variable "z" (para dias con clase por profesor)
#
# $$ z_{pd} = OR_h{y_{p(dh)}} $$
#
#     para todo p, d

# %%
def constr_definir_z(model, z_dict, y_dict):
    
    model.addConstrs(z_dict[p,d].variable ==
                gp.or_(y_dict[p,(d,h)].variable for h in horarios_ids)
                for p in profesores_ids for d in dias_ids)

# %% [markdown]
# ### (3.3) Restricciones externas

# %% [markdown]
# #### (3.3.1) cantidad de salones
#
# $$ \sum_{m} {u_{mb}} \leq K $$
#
#     para todo b

# %%
K = 13      # 13 salones en este caso

def constr_cantidad_salones(model, u_dict):
    model.addConstrs(gp.quicksum(u_dict[m, b].variable for m in materias_ids) <= K for b in bloques_horario_ids)

# %% [markdown]
# #### (3.3.2) restricciones ad hoc

# %% [markdown]
# #### (3.3.3) practico despues del teorico
#
# $$ \max_b\{(-b)*u_{mb}\} > \max_b\{(-b)*u_{m'b}\} $$
#
#     para todo par (teorico, practico) =  (m, m')

# %%
def constr_teo_prac(model, u_dict):

    """
    Variables:
        teo (list): Array containing IDs of theoretical subjects.
        prac (list): Array containing IDs of practical subjects.
        vars1erHora (dict): Dictionary mapping subject IDs to Gurobi integer variables representing the first hour.
        scaled_u_dict (dict): Dictionary mapping tuples of subject IDs and block IDs to scaled Gurobi integer variables.

    Functions:
        search_materias_by_nombre(materias, nombre): Searches for subjects by name in the given list of subjects.

    Workflow:
    1. Populate `teo` and `vars1erHora` with IDs and variables for theoretical subjects.
    2. Populate `prac` and `vars1erHora` with IDs and variables for practical subjects.
    3. Create scaled variables `scaled_u_dict` for each subject and block combination.
    4. Add constraints to the model to ensure that `vars1erHora` variables are the maximum of the scaled variables.
    5. Add constraints to ensure that the first hour of theoretical subjects is greater than or equal to the first hour of practical subjects if the lengths of `teo` and `prac` are equal.


    """
    teo = []    # array con IDS de materias de teorico
    prac = []    # array con IDS de materias de practico
    vars1erHora = {}
    scaled_u_dict = {}

    for t in [m for m in materias if m.teo_prac == "teo"]:
        teo.append(t.id)
        vars1erHora[t.id] = model.addVar(vtype=GRB.INTEGER, name=str(t)+"_1er_hora")

    for p in [m for m in materias if m.teo_prac == "prac"]:
        prac.append(p.id)
        vars1erHora[p.id] = model.addVar(vtype=GRB.INTEGER, name=str(p)+"_1er_hora")

    L = len(bloques_horario_ids)

    for m in teo + prac:
        for b in range(0, L):
            scaled_u_dict[m, bloques_horario_ids[b]] = model.addVar(vtype=GRB.INTEGER, name=str(m)+"scaled_u")
            model.addConstr(scaled_u_dict[m, bloques_horario_ids[b]] == (L - b) * u_dict[m, bloques_horario_ids[b]].variable)

    for m_id in vars1erHora:
        print(m_id, vars1erHora[m_id])
        model.addConstr(vars1erHora[m_id] ==
                        # gp.max_( (L - b) * u_dict[m_id, bloques_horario_ids[b]].variable
                        gp.max_( scaled_u_dict[m_id, bloques_horario_ids[b]]
                                for b in range(0, L)) )


    if len(teo) == len(prac):
        model.addConstrs(vars1erHora[teo[m]] >= vars1erHora[prac[m]] for m in range(0, len(teo)))
    else:
        print("Error: no coinciden cantidad de teoricos con practicos")

# %% [markdown]
# #### (3.3.4) Limitar horas excepcionales
#
# $$ \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} \leq E$$

# %%
def constr_horarios_excepcionales(model, u_dict, E_teo, E_prac):

    suma_horas_prac = gp.LinExpr()
    suma_horas_teo = gp.LinExpr()
    
    for m in materias:
        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos())) > 0:
                if m.teo_prac == "prac":
                    suma_horas_prac += u_dict[m.id, b.id].variable
                else:
                    suma_horas_teo += u_dict[m.id, b.id].variable
    
    model.addConstr(suma_horas_prac <= E_prac, "horas_excepcionales_prac")
    model.addConstr(suma_horas_teo <= E_teo, "horas_excepcionales_teo")

# %% [markdown]
# ### (3.4) Grupos

# %% [markdown]
# #### (3.4.1) definicion de variable "x"
#
# $$ x_{gb} = \sum_{m \in M_g} {u_{mb}} $$
#
# $$ x_{gb} = OR_{m \in M_g} {u_{mb}} $$

# %%
def constr_definir_x(model, x_dict, u_dict):

    # SUMA
    # for g in grupos:
    #     gr_mats_ids = [m.id for m in materias_grupo(g, materias)]
    #     model.addConstrs(x_dict[g.id, b].variable == gp.quicksum(u_dict[m, b].variable for m in gr_mats_ids) for b in bloques_horario_ids)

    # OR
    for g in grupos:
        # gr_mats_ids = [m.id for m in materias_grupo(g, materias)]
        gr_mats_ids = [m.id for m in materias_grupo(g, [m for m in materias if not m.electiva])] # filtrar materias electivas
        model.addConstrs(x_dict[g.id, b].variable == gp.or_(u_dict[m, b].variable for m in gr_mats_ids) for b in bloques_horario_ids)

# %% [markdown]
# #### (3.4.2) evitar horas puente por grupo
#
# $$ \sum_h {x_{gdh}} - \sum_h {x_{gd(h)} · x_{gd(h+1)}} \leq 1 $$
#     para todo g, d

# %%
def constr_horas_puente_grupos(model, x_dict):

    for g in grupos:
        model.addConstrs(gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
                    - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
                    <= 1 for d in dias_ids)

# %% [markdown]
# ## (4) Funcion Objetivo

# %% [markdown]
# ### (4.1) Prioridad horaria de los docentes
#
# $$ \min: \sum_{m,b,p} {A_{pb}·w_{mp}·u_{mb}} $$

# %%
def obj_prioridades(u_dict, w_dict):

    OBJ1 = gp.QuadExpr()
    """
    This script constructs a quadratic expression for an optimization problem using Gurobi's QuadExpr.
    Variables:
        OBJ1 (gp.QuadExpr): A quadratic expression object to accumulate the terms.
        count (int): A counter to keep track of the number of terms added to the quadratic expression.
    Loops:
        The script iterates over all combinations of 'materias' and 'profesores'. For each professor, it further iterates over their 'prioridades'.
    Inner Loop:
        For each priority 'pr' of a professor:
            - 'b' is assigned the 'bloque_horario' of the priority.
            - 'A' is assigned the 'value' of the priority.
            - The quadratic expression 'OBJ1' is updated by adding the product of 'A', the variable corresponding to the combination of 'materia' and 'profesor' from 'w_dict', and the variable corresponding to the combination of 'materia' and 'bloque_horario' from 'u_dict'.
            - The counter 'count' is incremented.
    Final Step:
        The constructed quadratic expression 'OBJ1' is added to the main objective 'OBJ'.
    Output:
        The total count of terms added to the quadratic expression is printed.
    """

    count = 0
    for m in materias:
        for p in profesores:
            for pr in p.prioridades:
                b = pr.bloque_horario
                A = pr.value
                OBJ1 += A * w_dict[m.id, p.id].variable * u_dict[m.id, b.id].variable
                count += 1


    print("obj_prioridades terms:", count)

    return OBJ1

# %% [markdown]
# ### (4.2) Minimizar/Maximizar dias con clase por profesor
# $$ \min: \sum_{p,d} {\alpha_p} {z_{pd}}$$
# donde $\alpha_p = 1$ si se minimiza, $\alpha_p = -1$ si se maximiza y $\alpha_p = 0$ si es irrelevante

# %%
def obj_min_max_dias(z_dict):

    OBJ2 = gp.LinExpr()
    DP = {}

    count = 0
    for p in profesores:
        
        D_p = gp.quicksum(z_dict[p.id,d].variable for d in dias_ids)
        DP[p.id] = D_p

        # filtrar si el profesor prefiere minimizar o maximizar o ninguno
        match p.min_max_dias:
            case "min":
                OBJ2 += D_p
                count += len(dias_ids)
            case "max":
                OBJ2 -= D_p
                count += len(dias_ids)
            case None:
                pass

    print("obj_min_max_dias terms:", count)

    return OBJ2, DP

# %% [markdown]
# ### (4.3) Minimizar horas puente por grupo (se incluye directamente como restriccion)
#
# $$ \min: -\sum_{g,d,h} {x_{gd(h)}·x_{gd(h+1)}} $$

# %%
def obj_horas_puente_grupos(x_dict):
    OBJ3 = gp.QuadExpr()

    count = 0
    for g in grupos:
        for d in dias_ids:
            OBJ3 += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
            count += 1

    print("obj_horas_puente_grupos terms:", count)

    return OBJ3

# %% [markdown]
# ### (4.4) Minimizar superposicion de electivas
#
# $$ \min:  \sum_{b} \sum_{m, m'}{u_{mb} \times SE_{m,m'} \times u_{m'b}} = 0 $$
#
# para todo par (m, m') de electivas

# %%
def obj_superposicion_electivas(u_dict):
    OBJ4 = gp.QuadExpr()

    count = 0
    for m1 in electivas(materias):
        for m2 in electivas(materias):
            for b in bloques_horario_ids:
                OBJ4 += u_dict[m1.id, b].variable * superposicion_electivas[m1.id, m2.id].value * u_dict[m2.id, b].variable
                count += 1

    print("obj_superposicion_electivas terms:", count)

    return OBJ4

# %% [markdown]
# ### (4.5) Evitar horas excepcionales
#
# $$ \min: \sum_{m} \sum_{b \in \mathcal{E}_m} {u_{mb}} $$

# %%
def obj_horarios_excepcionales(u_dict, prac=False):

    objetivo = gp.QuadExpr()

    count = 0
    for m in materias:

        if (not prac and m.teo_prac == "prac") or (prac and m.teo_prac != "prac"):
            continue

        for b in bloques_horario.values():
            excep = b.horario.turnos_excepcional
            if len(intersection(excep, m.turnos()))>0:
                objetivo += u_dict[m.id, b.id].variable
                count += 1
        
    print("obj_horarios_excepcionales terms:", count)

    return objetivo

# %% [markdown]
# # Resolver

# %% [markdown]
# ## Compilar modelo

# %%
# Create a new model
model: gp.Model = gp.Model("timetable")

# %%
# variables
u_dict, v_dict, w_dict, x_dict, y_dict, z_dict = initialize_variables(materias, bloques_horario, dias, profesores, grupos)
create_variables(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)
# Out:
# u:  13200
# v:  825
# w:  19305
# x:  2320
# y:  9360
# z:  585

# %%
# generate_instance_json("../instances/instance_2026sem1.json", materias, grupos, profesores, dias, horarios, turnos, superposicion, superposicion_electivas, mats_dias_consecutivos, p_grupos_simultaneos)

# %% [markdown]
# ### Seleccionar restricciones

# %%
constr_superposicion(model, u_dict)
constr_carga_horaria(model, u_dict)
constr_dias_materia(model, v_dict)
constr_max_min_horas(model, u_dict, v_dict)

# %%
constr_turnos_materia(model, u_dict)
constr_horas_consecutivas(model, u_dict, v_dict)
constr_dias_consecutivos(model, v_dict)
constr_horarios_excepcionales(model, u_dict, 7, 1)   # (opcional) limitar cantidad de horas excepcionales

# %%
constr_no_disponible_profesor(model, u_dict, w_dict)
constr_unica_materia_profesor(model, u_dict, w_dict)
constr_limitar_profesores_materia(model, w_dict)
constr_cantidad_profesores(model, w_dict)
constr_grupos_max_profesor(model, w_dict)
# constr_ad_hoc_profesores(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)

# %%
constr_definir_y(model, y_dict, u_dict, w_dict)
constr_definir_z(model, z_dict, y_dict)

# %%
# %%capture
constr_cantidad_salones(model, u_dict)
# constr_ad_hoc_materias(model, u_dict, v_dict, w_dict, x_dict, y_dict, z_dict)
constr_teo_prac(model, u_dict)

# %%
constr_definir_x(model, x_dict, u_dict)
constr_horas_puente_grupos(model, x_dict)

# %% [markdown]
# ### Funcion objetivo

# %%
# funcion objetivo

objectives = { # name : (expr, weight)
    
    "prioridades" : (obj_prioridades(u_dict, w_dict), 1), # weight = 1
    "min_max_dias" : (obj_min_max_dias(z_dict)[0], 0), # weight = 5
    "superposicion_electivas" : (obj_superposicion_electivas(u_dict), 0), # weight = 10
    "horarios_excepcionales (practico)" : (obj_horarios_excepcionales(u_dict, prac=True), 0), # weight = 50
    "horarios_excepcionales" : (obj_horarios_excepcionales(u_dict, prac=False), 0), # weight = 100

}

OBJ = gp.QuadExpr()
for name in objectives:
    expr, weight = objectives[name]
    OBJ += weight * expr

model.setObjective(OBJ, GRB.MINIMIZE)
# Out:
# obj_prioridades terms: 667425
# obj_min_max_dias terms: 175
# obj_superposicion_electivas terms: 8000
# obj_horarios_excepcionales terms: 110
# obj_horarios_excepcionales terms: 865

# %% [markdown]
# ## Optimizar

# %%
model.setParam("TimeLimit", 40*60)
# model.setParam('OutputFlag', 1)
model.Params.MIPGap = 0.01/100
# model.Params.PoolSolutions = 10 # Number of solutions to find
# model.Params.PoolSearchMode = 0 # 0, 1, 2

model.optimize()

# nSolutions = model.SolCount
# print(f"Number of solutions found: {nSolutions}")
# Out:
# Set parameter TimeLimit to value 2400
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 32464 rows, 68919 columns and 109486 nonzeros
# Model fingerprint: 0xf708deb7
# Model has 667425 quadratic objective terms
# Model has 41256 quadratic constraints
# Model has 12309 general constraints
# Variable types: 0 continuous, 68919 integer (45595 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e
work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 840 841 842 ... 848
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400000000000e+02, best bound 8.400000000000e+02, gap 0.0000%

# %% [markdown]
# ### Analizar no-factibilidad

# %%
# if model.Status == GRB.INFEASIBLE:
#     model.computeIIS()
#     model.write('iismodel.ilp')

#     # Print out the IIS constraints and variables
#     print('\nThe following constraints and variables are in the IIS:')
#     for c in model.getConstrs():
#         if c.IISConstr: print(f'\t{c.constrname}: {model.getRow(c)} {c.Sense} {c.RHS}')

#     for v in model.getVars():
#         if v.IISLB: print(f'\t{v.varname} ≥ {v.LB}')
#         if v.IISUB: print(f'\t{v.varname} ≤ {v.UB}')

# %% [markdown]
# ## Imprimir horarios

# %%
model.setParam("SolutionNumber", 0)
model.update()


if not model.Status == GRB.INFEASIBLE:
    print('Obj: %g' % model.ObjVal)
    for name in objectives:
        expr, weight = objectives[name]
        print(f"\t{name}: \t{" "*(35-len(name))}{round(expr.getValue())} \t(peso={weight})")
    print('=============================================================')
    
    print_timetable(dias, horarios, u_dict, w_dict, grupos, anios)

    save_solution_json(u_dict, v_dict, w_dict, "../results/solution.json")
# Out:
# Obj: 840
# 	prioridades: 	                        840 	(peso=1)
# 	min_max_dias: 	                       77 	(peso=0)
# 	superposicion_electivas: 	            42 	(peso=0)
# 	horarios_excepcionales (practico): 	  1 	(peso=0)
# 	horarios_excepcionales: 	             7 	(peso=0)
# =============================================================
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  1
#
#  Grupo:  10
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		49		---		---		6
# 1_start-1_end		23		49		---		23		6
# 2_start-2_end		23		49		66		23		73
# 3_start-3_end		70		64		66		23		73
# 4_start-4_end		70		64		66		96		66
# 5_start-5_end		---		64		---		96		66
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  11
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		66		49		---		96
# 1_start-1_end		---		66		49		---		96
# 2_start-2_end		---		66		49		66		6
# 3_start-3_end		---		23		73		66		6
# 4_start-4_end		64		23		73		23		70
# 5_start-5_end		64		23		---		23		70
# 6_start-6_end *		64		---		---		---		---
#
#  Grupo:  12
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		66		64		6		---		---
# 1_start-1_end		66		64		6		---		---
# 2_start-2_end		66		64		66		---		70
# 3_start-3_end		49		23		66		23		70
# 4_start-4_end		49		23		73		23		96
# 5_start-5_end		49		23		73		---		96
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  13
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		64		70		49		23		---
# 8_start-8_end		64		70		49		23		96
# 9_start-9_end		64		23		49		23		96
# 10_start-10_end		66		23		6		73		66
# 11_start-11_end		66		---		6		73		66
# 12_start-12_end *		66		---		---		---		---
#
#  Grupo:  14
# 			1		2		3		4		5
# ··········································································································
# 7_start-7_end		10		69		86		69		10
# 8_start-8_end		10		69		86		69		10
# 9_start-9_end		10		83		87		69		86
# 10_start-10_end		---		83		87		---		86
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  3
#
#  Grupo:  314
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		54		61		90		61		85
# 1_start-1_end		54		61		90		61		85
# 2_start-2_end		54		91		90		91		50
# 3_start-3_end		54		91		50		39		50
# 4_start-4_end		54		39		50		39		---
# 5_start-5_end		54		39		---		39		---
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  315
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		97		61		97		61		51
# 1_start-1_end		97		61		97		61		51
# 2_start-2_end		97		91		97		91		50
# 3_start-3_end		16		91		50		16		50
# 4_start-4_end		16		51		50		16		---
# 5_start-5_end		16		51		---		16		---
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  316
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		---		19		91		---		19
# 1_start-1_end		76		19		76		25		19
# 2_start-2_end		76		19		76		25		50
# 3_start-3_end		16		25		50		16		50
# 4_start-4_end		16		25		50		16		91
# 5_start-5_end		16		25		---		16		91
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  317
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		13		---		91		13		---
# 1_start-1_end		13		---		46		13		---
# 2_start-2_end		46		62		46		13		62
# 3_start-3_end		46		62		56		65		62
# 4_start-4_end		56		65		56		65		91
# 5_start-5_end		56		65		56		65		91
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  318
# 			1		2		3		4		5
# ··········································································································
# 0_start-0_end		76		46		---		46		76
# 1_start-1_end		76		46		---		46		76
# 2_start-2_end		13		50		25		13		25
# 3_start-3_end		13		50		25		13		25
# 4_start-4_end		13		91		25		91		50
# 5_start-5_end		---		---		---		91		50
# 6_start-6_end *		---		---		---		---		---
#
#  Grupo:  319
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		79		47		15		4		15
# 12_start-12_end		79		47		15		4		15
# 13_start-13_end		4		72		94		72		94
# 14_start-14_end		47		72		94		72		94
# 15_start-15_end		47		---		---		---		---
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  4
#
#  Grupo:  420
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		27		27		4		45		4
# 10_start-10_end		80/27/84		80/27/84		77/3		45		4
# 11_start-11_end		80/84		80/84		77/3		20		77/3
# 12_start-12_end		20		81		20		20		77/3
# 13_start-13_end		20		81		20		81		12
# 14_start-14_end		20		---		12		81		12
# 15_start-15_end *		---		---		12		---		---
#
#  Grupo:  421
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		4		7		4		7		---
# 10_start-10_end		4		7		77/3		7		77/3
# 11_start-11_end		2		40		77/3		7		77/3
# 12_start-12_end		2		40		---		2		17
# 13_start-13_end		17		40		---		2		17
# 14_start-14_end		17		40		---		2		17
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  422
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		9		---		4		---		4
# 10_start-10_end		9		48		77/3		---		4
# 11_start-11_end		9		48		77/3		48		77/3
# 12_start-12_end		9		52		53		48		77/3
# 13_start-13_end		---		52		53		52		53
# 14_start-14_end		---		52		53		52		53
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  423
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		9		4		79		77		---
# 10_start-10_end		9		3		79		77/3		4
# 11_start-11_end		9		3		22		3		4
# 12_start-12_end		9		48		22		48		77
# 13_start-13_end		98		48		98		48		77
# 14_start-14_end		98		---		98		---		---
# 15_start-15_end *		---		---		---		---		---
#
#  Grupo:  424
# 			1		2		3		4		5
# ··········································································································
# 11_start-11_end		31		46		---		46		31
# 12_start-12_end		31		46		---		46		31
# 13_start-13_end		---		91		13		63		---
# 14_start-14_end		13		91		13		63		---
# 15_start-15_end		13		---		13		63		91
#
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# Año:  5
#
#  Grupo:  525
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		57
# 9_start-9_end		27		27		---		---		57
# 10_start-10_end		80/27/84		80/27/84		---		43		21
# 11_start-11_end		80/84		80/84		57		43		21
# 12_start-12_end		---		43		57/57		21		---
# 13_start-13_end		57		43		57		21		12
# 14_start-14_end		57		68		12		68		12
# 15_start-15_end *		---		68		12		68		---
#
#  Grupo:  526
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		57
# 9_start-9_end		60		---		60		33		57
# 10_start-10_end		60		33		60		18/33		14
# 11_start-11_end		18		33		57		18		14
# 12_start-12_end		18		28		57/57		28		14
# 13_start-13_end		57		28		57		28		---
# 14_start-14_end		57		68		---		68		---
# 15_start-15_end *		---		68		---		68		---
#
#  Grupo:  527
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		57
# 9_start-9_end		32/78/75		---		78		---		57
# 10_start-10_end		32/78/75		58		78		58		---
# 11_start-11_end		32/31/75		58		57		58		31
# 12_start-12_end		31/75		24		57/57		24		1/36/31
# 13_start-13_end		57		24		57		24		1/36
# 14_start-14_end		57		68		---		68		1/36
# 15_start-15_end *		---		68		---		68		---
#
#  Grupo:  528
# 			1		2		3		4		5
# ··········································································································
# 8_start-8_end *		---		---		---		---		---
# 9_start-9_end		32/78/75		---		78		---		57
# 10_start-10_end		32/78/75		---		78		---		57
# 11_start-11_end		32/31/75		68		57		68		31
# 12_start-12_end		31/75		68		57/57		68		1/36/31
# 13_start-13_end		57		71		57		71		1/36
# 14_start-14_end		57		71		---		71		1/36
# 15_start-15_end *		---		---		---		---		---

# %%
if not model.Status == GRB.INFEASIBLE:
    print_prof_timetable_excel(dias, horarios, u_dict, w_dict, profesores, materias)
# Out:
#  Profesor:  3 3
# 	1	2	3	4	5
# 0_start-0_end	---	---	90	---	---
# 1_start-1_end	---	---	90	---	---
# 2_start-2_end	---	---	90	---	---
# 10_start-10_end	84	84	---	---	---
# 11_start-11_end	84	84	---	---	---
#
#  Profesor:  4 4
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	70
# 3_start-3_end	70	---	---	---	70
# 4_start-4_end	70	---	---	---	70
# 5_start-5_end	---	---	---	---	70
# 7_start-7_end	---	70	---	---	---
# 8_start-8_end	---	70	---	---	---
#
#  Profesor:  5 5
# 	1	2	3	4	5
# 9_start-9_end	---	4	---	---	---
# 10_start-10_end	---	---	---	---	4
# 11_start-11_end	---	---	---	4	4
# 12_start-12_end	---	---	---	4	---
# 13_start-13_end	4	---	---	---	---
#
#  Profesor:  6 6
# 	1	2	3	4	5
# 12_start-12_end	20	---	---	---	---
# 13_start-13_end	20	---	---	---	---
# 14_start-14_end	20	---	---	---	---
#
#  Profesor:  7 7
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	---	21
# 11_start-11_end	---	---	---	---	21
# 12_start-12_end	---	---	---	21	---
# 13_start-13_end	---	---	---	21	---
#
#  Profesor:  9 9
# 	1	2	3	4	5
# 11_start-11_end	---	46	---	46	---
# 12_start-12_end	---	46	---	46	---
#
#  Profesor:  11 11
# 	1	2	3	4	5
# 10_start-10_end	66	---	---	---	66
# 11_start-11_end	66	---	---	---	66
# 12_start-12_end	66	---	---	---	---
#
#  Profesor:  12 12
# 	1	2	3	4	5
# 3_start-3_end	49	---	73	---	---
# 4_start-4_end	49	---	73	---	---
# 5_start-5_end	49	---	---	---	---
#
#  Profesor:  13 13
# 	1	2	3	4	5
# 11_start-11_end	---	68	---	68	---
# 12_start-12_end	---	68	---	68	---
# 14_start-14_end	---	68	---	68	---
# 15_start-15_end	---	68	---	68	---
#
#  Profesor:  14 14
# 	1	2	3	4	5
# 0_start-0_end	---	64	---	---	---
# 1_start-1_end	---	64	---	---	---
# 2_start-2_end	---	64	---	---	---
# 3_start-3_end	---	64	---	---	---
# 4_start-4_end	64	64	---	---	---
# 5_start-5_end	64	64	---	---	---
# 6_start-6_end	64	---	---	---	---
# 7_start-7_end	64	---	---	---	---
# 8_start-8_end	64	---	---	---	---
# 9_start-9_end	64	---	---	---	---
#
#  Profesor:  15 15
# 	1	2	3	4	5
# 3_start-3_end	---	23	---	23	---
# 4_start-4_end	---	23	---	23	---
# 5_start-5_end	---	23	---	---	---
# 7_start-7_end	---	69	---	69	---
# 8_start-8_end	---	69	---	69	---
# 9_start-9_end	---	83	---	69	---
# 10_start-10_end	---	83	---	---	---
#
#  Profesor:  16 16
# 	1	2	3	4	5
# 9_start-9_end	32	---	---	---	---
# 10_start-10_end	32	---	---	---	---
# 11_start-11_end	32	---	---	---	---
#
#  Profesor:  17 17
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	30
# 1_start-1_end	---	---	---	---	30
# 2_start-2_end	---	---	---	---	30
#
#  Profesor:  18 18
# 	1	2	3	4	5
# 0_start-0_end	29	---	---	---	29
# 1_start-1_end	29	---	---	---	29
# 2_start-2_end	29	---	---	---	29
#
#  Profesor:  21 21
# 	1	2	3	4	5
# 11_start-11_end	---	---	15	---	15
# 12_start-12_end	---	---	15	---	15
#
#  Profesor:  26 26
# 	1	2	3	4	5
# 11_start-11_end	---	26	---	41	---
# 12_start-12_end	---	26	---	41	---
# 13_start-13_end	41	---	---	26	---
# 14_start-14_end	41	---	---	26	---
# 15_start-15_end	41	---	---	26	---
#
#  Profesor:  28 28
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	50
# 3_start-3_end	---	---	50	---	50
# 4_start-4_end	---	---	50	---	---
#
#  Profesor:  29 29
# 	1	2	3	4	5
# 9_start-9_end	75	---	---	---	---
# 10_start-10_end	75	---	---	---	---
# 11_start-11_end	75	---	---	---	---
# 12_start-12_end	75	---	---	---	---
#
#  Profesor:  30 30
# 	1	2	3	4	5
# 10_start-10_end	---	48	---	---	---
# 11_start-11_end	---	48	---	48	---
# 12_start-12_end	---	---	---	48	---
# 13_start-13_end	---	71	---	71	---
# 14_start-14_end	---	71	---	71	---
#
#  Profesor:  31 31
# 	1	2	3	4	5
# 0_start-0_end	---	5	---	---	5
# 1_start-1_end	---	5	---	---	5
# 2_start-2_end	---	---	---	---	5
#
#  Profesor:  32 32
# 	1	2	3	4	5
# 11_start-11_end	---	47	---	---	---
# 12_start-12_end	---	47	---	---	---
# 13_start-13_end	98	---	98	---	---
# 14_start-14_end	98	---	98	---	---
#
#  Profesor:  33 33
# 	1	2	3	4	5
# 2_start-2_end	---	50	---	---	---
# 3_start-3_end	---	50	---	---	---
# 4_start-4_end	---	---	---	---	50
# 5_start-5_end	---	---	---	---	50
#
#  Profesor:  34 34
# 	1	2	3	4	5
# 12_start-12_end	---	---	57	---	---
# 13_start-13_end	57	---	57	---	---
# 14_start-14_end	57	---	---	---	---
#
#  Profesor:  36 36
# 	1	2	3	4	5
# 2_start-2_end	---	---	66	---	6
# 3_start-3_end	---	---	66	---	6
# 4_start-4_end	---	---	66	---	66
# 5_start-5_end	---	---	---	---	66
# 10_start-10_end	---	---	6	---	---
# 11_start-11_end	---	---	6	---	59
# 12_start-12_end	---	---	---	---	59
# 13_start-13_end	---	---	59	---	59
# 14_start-14_end	---	---	59	---	59
#
#  Profesor:  37 37
# 	1	2	3	4	5
# 9_start-9_end	9	---	---	---	---
# 10_start-10_end	9	---	---	---	---
# 11_start-11_end	9	---	---	---	---
# 12_start-12_end	9	---	---	---	---
#
#  Profesor:  38 38
# 	1	2	3	4	5
# 3_start-3_end	---	---	56	---	---
# 4_start-4_end	56	---	56	---	---
# 5_start-5_end	56	---	56	---	---
#
#  Profesor:  39 39
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	18	---
# 11_start-11_end	18	40	---	18	---
# 12_start-12_end	18	40	---	---	---
# 13_start-13_end	---	40	---	---	---
# 14_start-14_end	---	40	---	---	---
#
#  Profesor:  42 42
# 	1	2	3	4	5
# 9_start-9_end	27	27	---	---	---
# 10_start-10_end	27	27	---	---	---
#
#  Profesor:  43 43
# 	1	2	3	4	5
# 0_start-0_end	54	---	---	---	---
# 1_start-1_end	54	---	---	---	---
# 2_start-2_end	54	---	---	---	---
# 3_start-3_end	54	---	---	---	---
# 4_start-4_end	54	---	---	---	---
# 5_start-5_end	54	---	---	---	---
#
#  Profesor:  44 44
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	0	---
# 1_start-1_end	---	---	---	0	---
# 2_start-2_end	---	---	---	0	---
#
#  Profesor:  47 47
# 	1	2	3	4	5
# 10_start-10_end	---	---	3	---	3
# 11_start-11_end	---	---	3	---	3
# 12_start-12_end	---	---	---	---	3
#
#  Profesor:  48 48
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	17
# 13_start-13_end	17	---	---	---	17
# 14_start-14_end	17	---	---	---	17
#
#  Profesor:  49 49
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	43	---
# 11_start-11_end	---	---	---	43	---
# 12_start-12_end	---	43	---	---	---
# 13_start-13_end	---	43	---	---	---
#
#  Profesor:  50 50
# 	1	2	3	4	5
# 0_start-0_end	---	44	---	44	---
# 1_start-1_end	---	44	---	44	---
# 2_start-2_end	---	---	---	44	---
# 9_start-9_end	---	---	87	---	---
# 10_start-10_end	---	---	87	---	---
#
#  Profesor:  53 53
# 	1	2	3	4	5
# 11_start-11_end	2	---	---	---	---
# 12_start-12_end	2	---	---	2	---
# 13_start-13_end	---	---	---	2	---
# 14_start-14_end	---	---	---	2	---
#
#  Profesor:  54 54
# 	1	2	3	4	5
# 2_start-2_end	---	---	---	---	50
# 3_start-3_end	---	---	50	---	50
# 4_start-4_end	---	---	50	---	---
#
#  Profesor:  55 55
# 	1	2	3	4	5
# 8_start-8_end	---	---	---	---	57
# 9_start-9_end	---	---	---	---	57
# 10_start-10_end	---	---	---	---	57
# 11_start-11_end	---	---	57	---	---
# 12_start-12_end	---	---	57	---	---
#
#  Profesor:  57 57
# 	1	2	3	4	5
# 9_start-9_end	75	---	---	---	---
# 10_start-10_end	75	---	---	---	---
# 11_start-11_end	75	---	---	---	---
# 12_start-12_end	75	---	---	---	---
#
#  Profesor:  58 58
# 	1	2	3	4	5
# 10_start-10_end	80	80	---	---	---
# 11_start-11_end	80	80	---	---	---
#
#  Profesor:  59 59
# 	1	2	3	4	5
# 3_start-3_end	---	23	---	---	---
# 4_start-4_end	---	23	---	23	---
# 5_start-5_end	---	23	---	23	---
# 7_start-7_end	---	69	---	69	---
# 8_start-8_end	---	69	---	69	---
# 9_start-9_end	---	83	---	69	---
# 10_start-10_end	---	83	---	---	---
#
#  Profesor:  60 60
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	---	12
# 14_start-14_end	---	---	12	---	12
# 15_start-15_end	---	---	12	---	---
#
#  Profesor:  61 61
# 	1	2	3	4	5
# 3_start-3_end	16	---	---	16	35
# 4_start-4_end	16	35	---	16	35
# 5_start-5_end	16	35	---	16	35
#
#  Profesor:  62 62
# 	1	2	3	4	5
# 2_start-2_end	---	---	25	---	25
# 3_start-3_end	---	---	25	---	25
# 4_start-4_end	---	---	25	---	---
#
#  Profesor:  64 64
# 	1	2	3	4	5
# 0_start-0_end	---	44	---	44	---
# 1_start-1_end	---	44	---	44	---
# 2_start-2_end	---	---	---	44	---
#
#  Profesor:  66 66
# 	1	2	3	4	5
# 1_start-1_end	76	---	76	---	---
# 2_start-2_end	76	---	76	---	---
# 11_start-11_end	---	---	22	---	---
# 12_start-12_end	---	---	22	---	---
#
#  Profesor:  68 68
# 	1	2	3	4	5
# 12_start-12_end	---	48	---	48	---
# 13_start-13_end	---	48	---	48	---
#
#  Profesor:  71 71
# 	1	2	3	4	5
# 0_start-0_end	---	19	---	---	19
# 1_start-1_end	---	19	---	---	19
# 2_start-2_end	---	19	---	---	---
# 11_start-11_end	---	---	---	---	11
# 12_start-12_end	---	---	---	---	11
# 13_start-13_end	---	---	11	---	11
# 14_start-14_end	---	---	11	---	---
#
#  Profesor:  72 72
# 	1	2	3	4	5
# 0_start-0_end	---	61	---	61	---
# 1_start-1_end	---	61	---	61	---
#
#  Profesor:  74 74
# 	1	2	3	4	5
# 2_start-2_end	---	88	---	---	---
# 3_start-3_end	---	88	---	---	88
# 4_start-4_end	---	---	---	---	88
# 5_start-5_end	---	---	---	---	88
# 11_start-11_end	---	---	---	37	---
# 12_start-12_end	---	---	---	37	---
# 13_start-13_end	---	37	---	---	---
# 14_start-14_end	---	37	---	---	---
# 15_start-15_end	---	37	---	---	---
#
#  Profesor:  75 75
# 	1	2	3	4	5
# 2_start-2_end	---	93	93	---	---
# 3_start-3_end	---	93	93	93	---
# 4_start-4_end	---	93	93	93	---
# 5_start-5_end	---	93	93	93	---
# 6_start-6_end	---	---	---	93	---
#
#  Profesor:  76 76
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	33	---
# 10_start-10_end	---	33	---	18	---
# 11_start-11_end	18	33	---	18	---
# 12_start-12_end	18	---	---	---	---
#
#  Profesor:  77 77
# 	1	2	3	4	5
# 1_start-1_end	---	---	---	25	---
# 2_start-2_end	---	---	---	25	---
# 3_start-3_end	---	25	---	---	---
# 4_start-4_end	---	25	---	---	---
# 5_start-5_end	---	25	---	---	---
#
#  Profesor:  80 80
# 	1	2	3	4	5
# 9_start-9_end	---	---	79	---	---
# 10_start-10_end	---	---	79	---	---
# 11_start-11_end	79	---	---	---	---
# 12_start-12_end	79	---	---	---	---
#
#  Profesor:  82 82
# 	1	2	3	4	5
# 0_start-0_end	76	---	---	---	76
# 1_start-1_end	76	---	---	---	76
# 12_start-12_end	---	---	---	---	1
# 13_start-13_end	---	---	---	---	1
# 14_start-14_end	---	---	---	---	1
#
#  Profesor:  84 84
# 	1	2	3	4	5
# 4_start-4_end	---	---	73	---	---
# 5_start-5_end	---	---	73	---	---
# 10_start-10_end	---	---	---	73	---
# 11_start-11_end	---	---	---	73	---
#
#  Profesor:  85 85
# 	1	2	3	4	5
# 1_start-1_end	23	---	---	23	---
# 2_start-2_end	23	---	---	23	---
# 3_start-3_end	92	---	---	23	---
# 4_start-4_end	92	---	92	---	---
# 5_start-5_end	92	---	92	---	---
#
#  Profesor:  86 86
# 	1	2	3	4	5
# 0_start-0_end	---	46	---	46	---
# 1_start-1_end	---	46	---	46	---
#
#  Profesor:  87 87
# 	1	2	3	4	5
# 14_start-14_end	47	---	---	---	---
# 15_start-15_end	47	---	---	---	---
#
#  Profesor:  88 88
# 	1	2	3	4	5
# 13_start-13_end	---	---	---	63	---
# 14_start-14_end	---	---	---	63	---
# 15_start-15_end	---	---	---	63	---
#
#  Profesor:  91 91
# 	1	2	3	4	5
# 0_start-0_end	---	---	67	---	---
# 1_start-1_end	---	---	67	---	---
# 2_start-2_end	---	---	55	---	---
# 3_start-3_end	67	---	55	---	---
# 4_start-4_end	67	---	---	---	---
# 5_start-5_end	67	---	---	---	55
# 6_start-6_end	---	---	---	---	55
# 7_start-7_end	10	---	---	---	10
# 8_start-8_end	10	---	---	---	10
# 9_start-9_end	10	---	---	---	---
#
#  Profesor:  92 92
# 	1	2	3	4	5
# 11_start-11_end	2	---	---	---	---
# 12_start-12_end	2	---	---	2	---
# 13_start-13_end	---	---	---	2	---
# 14_start-14_end	---	---	---	2	---
#
#  Profesor:  94 94
# 	1	2	3	4	5
# 10_start-10_end	---	---	---	---	14
# 11_start-11_end	---	---	---	---	14
# 12_start-12_end	---	---	---	---	14
#
#  Profesor:  95 95
# 	1	2	3	4	5
# 7_start-7_end	---	---	86	---	---
# 8_start-8_end	---	---	86	---	---
# 9_start-9_end	---	---	---	---	86
# 10_start-10_end	---	---	---	---	86
# 11_start-11_end	---	---	---	---	86
#
#  Profesor:  97 97
# 	1	2	3	4	5
# 13_start-13_end	---	72	---	72	---
# 14_start-14_end	---	72	---	72	---
#
#  Profesor:  99 99
# 	1	2	3	4	5
# 11_start-11_end	---	---	---	20	---
# 12_start-12_end	---	---	---	20	---
#
#  Profesor:  100 100
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	45	---
# 10_start-10_end	---	---	---	45	---
# 12_start-12_end	---	81	---	---	---
# 13_start-13_end	---	81	---	81	---
# 14_start-14_end	---	---	---	81	---
#
#  Profesor:  101 101
# 	1	2	3	4	5
# 11_start-11_end	---	95	---	---	---
# 12_start-12_end	---	95	---	---	---
#
#  Profesor:  102 102
# 	1	2	3	4	5
# 7_start-7_end	---	---	---	23	---
# 8_start-8_end	---	---	---	23	---
# 9_start-9_end	78	23	78	23	---
# 10_start-10_end	78	23	78	---	---
#
#  Profesor:  103 103
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	85
# 1_start-1_end	---	---	---	---	85
#
#  Profesor:  104 104
# 	1	2	3	4	5
# 2_start-2_end	---	91	---	91	---
# 3_start-3_end	---	91	---	---	---
# 4_start-4_end	---	91	---	91	---
# 5_start-5_end	---	---	---	91	---
#
#  Profesor:  106 106
# 	1	2	3	4	5
# 9_start-9_end	---	7	---	7	---
# 10_start-10_end	---	7	---	7	---
# 11_start-11_end	---	---	---	7	---
#
#  Profesor:  107 107
# 	1	2	3	4	5
# 0_start-0_end	13	---	---	13	---
# 1_start-1_end	13	---	---	13	---
# 2_start-2_end	---	---	---	13	---
#
#  Profesor:  108 108
# 	1	2	3	4	5
# 2_start-2_end	---	62	---	---	62
# 3_start-3_end	---	62	---	---	62
#
#  Profesor:  109 109
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	39	---
# 4_start-4_end	---	39	---	39	---
# 5_start-5_end	---	39	---	39	---
#
#  Profesor:  111 111
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	65	---
# 4_start-4_end	---	65	---	65	---
# 5_start-5_end	---	65	---	65	---
#
#  Profesor:  112 112
# 	1	2	3	4	5
# 0_start-0_end	---	---	42	---	---
# 1_start-1_end	---	---	42	---	---
# 2_start-2_end	---	---	---	---	73
# 3_start-3_end	---	---	---	---	73
# 7_start-7_end	---	---	49	---	---
# 8_start-8_end	---	---	49	---	---
# 9_start-9_end	---	---	49	---	42
# 10_start-10_end	---	---	---	---	42
#
#  Profesor:  115 115
# 	1	2	3	4	5
# 0_start-0_end	---	19	---	---	19
# 1_start-1_end	---	19	---	---	19
# 2_start-2_end	---	19	---	---	---
# 11_start-11_end	---	---	---	---	11
# 12_start-12_end	---	---	---	---	11
# 13_start-13_end	---	---	11	---	11
# 14_start-14_end	---	---	11	---	---
#
#  Profesor:  116 116
# 	1	2	3	4	5
# 0_start-0_end	66	---	6	---	6
# 1_start-1_end	66	---	6	---	6
# 2_start-2_end	66	---	66	---	---
# 3_start-3_end	67	---	66	---	---
# 4_start-4_end	67	---	67	---	---
# 5_start-5_end	67	---	67	---	---
#
#  Profesor:  119 119
# 	1	2	3	4	5
# 12_start-12_end	---	---	20	---	---
# 13_start-13_end	---	---	20	---	---
#
#  Profesor:  120 120
# 	1	2	3	4	5
# 11_start-11_end	38	---	---	---	---
# 12_start-12_end	38	---	38	---	---
#
#  Profesor:  121 121
# 	1	2	3	4	5
# 13_start-13_end	---	---	94	---	94
# 14_start-14_end	---	---	94	---	94
#
#  Profesor:  122 122
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	45	---
# 10_start-10_end	---	---	---	45	---
#
#  Profesor:  123 123
# 	1	2	3	4	5
# 13_start-13_end	---	91	---	---	---
# 14_start-14_end	---	91	---	---	---
# 15_start-15_end	---	---	---	---	91
#
#  Profesor:  124 124
# 	1	2	3	4	5
# 0_start-0_end	97	---	97	---	---
# 1_start-1_end	97	---	97	---	---
# 2_start-2_end	97	---	97	---	---
#
#  Profesor:  126 126
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	33	---
# 10_start-10_end	---	33	---	33	---
# 11_start-11_end	---	33	---	---	---
#
#  Profesor:  128 128
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	51
# 1_start-1_end	---	---	---	---	51
# 4_start-4_end	---	51	---	---	---
# 5_start-5_end	---	51	---	---	---
#
#  Profesor:  129 129
# 	1	2	3	4	5
# 10_start-10_end	---	3	3	3	3
# 11_start-11_end	---	3	3	3	3
# 12_start-12_end	---	---	---	---	3
#
#  Profesor:  131 131
# 	1	2	3	4	5
# 0_start-0_end	54	---	---	---	---
# 1_start-1_end	54	---	---	---	---
# 2_start-2_end	54	---	---	---	---
# 3_start-3_end	54	---	---	---	---
# 4_start-4_end	54	---	---	---	---
# 5_start-5_end	54	---	---	---	---
#
#  Profesor:  132 132
# 	1	2	3	4	5
# 13_start-13_end	44	---	---	---	---
# 14_start-14_end	44	---	---	---	44
# 15_start-15_end	44	---	---	---	44
#
#  Profesor:  134 134
# 	1	2	3	4	5
# 9_start-9_end	9	---	---	---	---
# 10_start-10_end	9	---	---	---	---
# 11_start-11_end	9	---	---	---	---
# 12_start-12_end	9	---	---	---	---
#
#  Profesor:  135 135
# 	1	2	3	4	5
# 9_start-9_end	60	---	60	---	---
# 10_start-10_end	60	---	60	---	---
#
#  Profesor:  136 136
# 	1	2	3	4	5
# 12_start-12_end	---	---	---	---	36
# 13_start-13_end	---	---	---	---	36
# 14_start-14_end	---	---	---	---	36
#
#  Profesor:  137 137
# 	1	2	3	4	5
# 13_start-13_end	---	34	13	34	---
# 14_start-14_end	13	34	13	34	---
# 15_start-15_end	13	---	13	---	---
#
#  Profesor:  138 138
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	8
# 1_start-1_end	---	---	---	---	8
# 2_start-2_end	---	8	---	---	---
# 3_start-3_end	---	8	---	8	---
# 4_start-4_end	---	8	---	8	---
# 5_start-5_end	---	8	---	---	---
# 11_start-11_end	31	---	---	---	31
# 12_start-12_end	31	---	---	---	31
#
#  Profesor:  140 140
# 	1	2	3	4	5
# 12_start-12_end	---	---	53	---	---
# 13_start-13_end	---	---	53	---	53
# 14_start-14_end	---	---	53	---	53
#
#  Profesor:  141 141
# 	1	2	3	4	5
# 11_start-11_end	89	---	89	---	---
# 12_start-12_end	89	---	89	---	---
#
#  Profesor:  142 142
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	---	96
# 1_start-1_end	---	---	---	---	96
# 4_start-4_end	---	---	---	96	96
# 5_start-5_end	---	---	---	96	96
# 8_start-8_end	---	---	---	---	96
# 9_start-9_end	---	---	---	---	96
#
#  Profesor:  145 145
# 	1	2	3	4	5
# 0_start-0_end	---	---	---	82	---
# 1_start-1_end	---	---	---	82	---
# 2_start-2_end	---	---	---	82	---
#
#  Profesor:  146 146
# 	1	2	3	4	5
# 9_start-9_end	75	---	---	---	---
# 10_start-10_end	75	---	---	---	---
# 11_start-11_end	75	---	---	---	---
# 12_start-12_end	75	---	---	---	---
#
#  Profesor:  147 147
# 	1	2	3	4	5
# 11_start-11_end	2	---	---	---	---
# 12_start-12_end	2	---	---	2	---
# 13_start-13_end	---	---	---	2	---
# 14_start-14_end	---	---	---	2	---
#
#  Profesor:  148 148
# 	1	2	3	4	5
# 0_start-0_end	---	19	---	---	19
# 1_start-1_end	---	19	---	---	19
# 2_start-2_end	---	19	---	---	---
# 11_start-11_end	---	---	---	---	11
# 12_start-12_end	---	---	---	---	11
# 13_start-13_end	---	---	11	---	11
# 14_start-14_end	---	---	11	---	---
#
#  Profesor:  149 149
# 	1	2	3	4	5
# 0_start-0_end	---	---	91	---	---
# 4_start-4_end	---	---	---	---	91
# 5_start-5_end	---	---	---	---	91
# 9_start-9_end	4	---	4	---	---
# 10_start-10_end	4	---	---	---	---
#
#  Profesor:  150 150
# 	1	2	3	4	5
# 3_start-3_end	---	---	---	39	---
# 4_start-4_end	---	39	---	39	---
# 5_start-5_end	---	39	---	39	---
#
#  Profesor:  151 151
# 	1	2	3	4	5
# 0_start-0_end	---	66	---	---	---
# 1_start-1_end	---	66	---	---	---
# 2_start-2_end	---	66	---	66	---
# 3_start-3_end	---	---	---	66	---
# 7_start-7_end	---	92	---	92	---
# 8_start-8_end	---	92	---	92	---
# 9_start-9_end	---	---	---	92	---
#
#  Profesor:  152 152
# 	1	2	3	4	5
# 0_start-0_end	---	88	---	88	---
# 1_start-1_end	---	88	---	88	---
# 2_start-2_end	---	---	---	88	---
# 12_start-12_end	---	52	---	---	---
# 13_start-13_end	---	52	---	52	---
# 14_start-14_end	---	52	---	52	---
#
#  Profesor:  156 156
# 	1	2	3	4	5
# 12_start-12_end	---	24	---	24	---
# 13_start-13_end	---	24	---	24	---
#
#  Profesor:  157 157
# 	1	2	3	4	5
# 2_start-2_end	13	---	---	13	---
# 3_start-3_end	13	---	---	13	---
# 4_start-4_end	13	---	---	---	---
#
#  Profesor:  158 158
# 	1	2	3	4	5
# 2_start-2_end	---	88	---	---	---
# 3_start-3_end	---	88	---	---	88
# 4_start-4_end	---	---	---	---	88
# 5_start-5_end	---	---	---	---	88
#
#  Profesor:  159 159
# 	1	2	3	4	5
# 1_start-1_end	---	---	46	---	---
# 2_start-2_end	46	---	46	---	---
# 3_start-3_end	46	---	---	---	---
#
#  Profesor:  160 160
# 	1	2	3	4	5
# 10_start-10_end	---	58	---	58	---
# 11_start-11_end	---	58	---	58	---
#
#  Profesor:  161 161
# 	1	2	3	4	5
# 0_start-0_end	74	---	---	---	---
# 1_start-1_end	74	---	---	---	---
# 2_start-2_end	74	---	74	---	---
# 3_start-3_end	---	---	74	---	---
#
#  Profesor:  162 162
# 	1	2	3	4	5
# 9_start-9_end	---	---	---	77	---
# 10_start-10_end	---	---	77	77	77
# 11_start-11_end	---	---	77	---	77
# 12_start-12_end	---	---	---	---	77
# 13_start-13_end	---	---	---	---	77
#
#  Profesor:  163 163
# 	1	2	3	4	5
# 0_start-0_end	---	---	44	---	---
# 1_start-1_end	---	---	44	---	---
# 2_start-2_end	---	---	---	---	44
# 3_start-3_end	---	---	---	---	44
# 4_start-4_end	---	---	---	---	44
#
#  Profesor:  164 164
# 	1	2	3	4	5
# 11_start-11_end	---	68	---	68	---
# 12_start-12_end	---	68	---	68	---
# 14_start-14_end	---	68	---	68	---
# 15_start-15_end	---	68	---	68	---
#
#  Profesor:  165 165
# 	1	2	3	4	5
# 0_start-0_end	---	49	49	---	---
# 1_start-1_end	---	49	49	---	---
# 2_start-2_end	---	49	49	---	---
#
#  Profesor:  167 167
# 	1	2	3	4	5
# 9_start-9_end	---	---	4	---	4
# 10_start-10_end	---	---	---	---	4
#
#  Profesor:  168 168
# 	1	2	3	4	5
# 12_start-12_end	---	28	---	28	---
# 13_start-13_end	---	28	---	28	---

# %% [markdown]
# ## Estadísticas de resultados

# %% [markdown]
# ### Promedios de prioridad

# %%
if not model.Status == GRB.INFEASIBLE and "prioridades" in objectives:
    
    CARGA_HORARIA_TOTAL = np.sum([round(y_dict[p, b].variable.X)
                              for p in profesores_ids
                              for b in bloques_horario_ids
                              ])

    obj = objectives["prioridades"][0].getValue()
    print(obj)
    print("Promedio general de prioridad horaria: ", obj/CARGA_HORARIA_TOTAL)
          

# print("Casos de materias con dias consecutivos: ", int(OBJ2.getValue()/10))
# Out:
# 840.0
# Promedio general de prioridad horaria:  1.238938053097345

# %%
# promedio por profesor:
"""
This script calculates and prints the average workload per professor based on their assigned priorities and time blocks.
Variables:
    profesores (list): List of professor objects, each containing their priorities.
    y_dict (dict): Dictionary mapping professor IDs and time block IDs to Gurobi variables.
    bloques_horario_ids (list): List of time block IDs.
For each professor in the list `profesores`, the script performs the following steps:
1. Initializes a quadratic expression `OBJ_p` to accumulate the weighted priorities.
2. Iterates over the professor's priorities to update `OBJ_p` based on the priority value and corresponding Gurobi variable.
3. Calculates the total workload `CARGA_HORARIA_p` for the professor by summing the relevant Gurobi variables.
4. If the total workload is non-zero, it prints the professor's name, total workload, and the rounded average priority value per workload unit.
5. If the total workload is zero, it prints the professor's name and indicates that they have no workload.

"""
if not model.Status == GRB.INFEASIBLE:
    for p in profesores:

        OBJ_p = gp.QuadExpr()
        # for m in materias:
        #     for pr in p.prioridades:
        #             b = pr.bloque_horario
        #             A = pr.value
        #             OBJ_p += A * w_dict[m.id, p.id].variable * u_dict[m.id, b.id].variable

        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            OBJ_p += A * y_dict[p.id, b.id].variable
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()
        CARGA_HORARIA_p = round(gp.quicksum(y_dict[p.id, b].variable for b in bloques_horario_ids).getValue())

        if CARGA_HORARIA_p != 0:
            print(str(p), "\t", CARGA_HORARIA_p, "\t", round(round(OBJ_p.getValue())/CARGA_HORARIA_p,3))
        else:
            print(str(p), "sin carga horaria")
# Out:
# 3 	 7 	 1.286
# 4 	 8 	 1.0
# 5 	 6 	 1.0
# 6 	 3 	 1.0
# 7 	 4 	 2.0
# 9 	 4 	 1.0
# 11 	 5 	 1.8
# 12 	 5 	 1.0
# 13 	 8 	 1.5
# 14 	 12 	 1.0
# 15 	 12 	 1.0
# 16 	 3 	 1.0
# 17 	 3 	 1.0
# 18 	 6 	 1.333
# 21 	 4 	 1.0
# 26 	 10 	 1.0
# 28 	 4 	 1.0
# 29 	 4 	 1.5
# 30 	 8 	 1.125
# 31 	 5 	 1.0
# 32 	 6 	 1.0
# 33 	 4 	 1.75
# 34 	 4 	 1.25
# 36 	 15 	 1.4
# 37 	 4 	 3.0
# 38 	 5 	 2.2
# 39 	 8 	 1.0
# 42 	 4 	 1.0
# 43 	 6 	 1.833
# 44 	 3 	 1.0
# 47 	 5 	 1.4
# 48 	 5 	 1.0
# 49 	 4 	 1.25
# 50 	 7 	 1.571
# 53 	 5 	 1.0
# 54 	 4 	 2.5
# 55 	 5 	 1.0
# 57 	 4 	 1.0
# 58 	 4 	 1.5
# 59 	 12 	 1.417
# 60 	 4 	 1.0
# 61 	 11 	 1.0
# 62 	 5 	 1.4
# 64 	 5 	 1.2
# 66 	 6 	 1.0
# 68 	 4 	 1.0
# 71 	 10 	 1.5
# 72 	 4 	 1.5
# 74 	 10 	 1.0
# 75 	 12 	 1.0
# 76 	 7 	 1.0
# 77 	 5 	 1.2
# 80 	 4 	 1.0
# 82 	 7 	 1.0
# 84 	 4 	 1.25
# 85 	 10 	 1.0
# 86 	 4 	 1.0
# 87 	 2 	 1.0
# 88 	 3 	 1.0
# 91 	 14 	 1.643
# 92 	 5 	 1.0
# 94 	 3 	 2.0
# 95 	 5 	 1.0
# 97 	 4 	 1.0
# 99 	 2 	 1.5
# 100 	 6 	 1.667
# 101 	 2 	 2.0
# 102 	 9 	 1.0
# 103 	 2 	 2.0
# 104 	 6 	 1.0
# 106 	 5 	 1.6
# 107 	 5 	 1.2
# 108 	 4 	 1.0
# 109 	 5 	 2.0
# 111 	 5 	 1.0
# 112 	 9 	 1.111
# 115 	 10 	 1.0
# 116 	 14 	 1.0
# 119 	 2 	 1.5
# 120 	 3 	 1.0
# 121 	 4 	 1.5
# 122 	 2 	 1.0
# 123 	 3 	 1.0
# 124 	 6 	 1.0
# 126 	 4 	 1.0
# 128 	 4 	 1.0
# 129 	 9 	 1.222
# 131 	 6 	 1.0
# 132 	 5 	 1.0
# 134 	 4 	 1.0
# 135 	 4 	 1.0
# 136 	 3 	 2.0
# 137 	 9 	 1.444
# 138 	 12 	 1.0
# 140 	 5 	 1.0
# 141 	 4 	 1.0
# 142 	 8 	 1.25
# 145 	 3 	 1.0
# 146 	 4 	 1.0
# 147 	 5 	 1.0
# 148 	 10 	 1.0
# 149 	 6 	 1.0
# 150 	 5 	 1.4
# 151 	 10 	 1.0
# 152 	 10 	 1.8
# 156 	 4 	 1.0
# 157 	 5 	 1.0
# 158 	 5 	 1.0
# 159 	 4 	 1.0
# 160 	 4 	 1.0
# 161 	 5 	 1.0
# 162 	 8 	 1.0
# 163 	 5 	 1.0
# 164 	 8 	 1.25
# 165 	 6 	 1.0
# 167 	 3 	 1.667
# 168 	 4 	 2.0

# %%
# # DIAS CLASE POR PROFESOR

# print("DIAS CON CLASE")
# for p in profesores:
#     if p.min_max_dias is not None:
#         print(str(p), ": ", round(DP[p.id].getValue()), p.min_max_dias)

# %%
# HORAS PUENTE

# HP = gp.QuadExpr()
# for g in grupos_reales:
#     HPg = gp.QuadExpr()
#     for d in dias_ids:
#         HPg += gp.quicksum(x_dict[(g.id,(d,h))].variable for h in horarios_ids)
#         HPg += - gp.quicksum(x_dict[(g.id,(d,h))].variable * x_dict[(g.id,(d,h+1))].variable for h in horarios_ids[0:-1])
#         HPg += - 1
#     # print("horas puente grupo", str(g), ": ", HPg.getValue())
#     HP += HPg

# print("Total de horas puente: ", HP.getValue())

# %% [markdown]
# #### Distribucion de prioridades

# %%
# distribucion de prioridades
"""
This script calculates and prints the distribution of priorities and their averages for a given set of professors and their time block priorities.
Variables:
    promedios_prioridad (dict): A dictionary to store the average priority values for each priority level.
    valores_prioridad (dict): A dictionary to store the count of each priority level.
    profesores (list): A list of professor objects, each containing their priority information.
    y_dict (dict): A dictionary containing the decision variables for the optimization model.
Process:
1. Initialize dictionaries to store priority averages and counts.
2. Iterate over each professor and their priorities:
    - Skip if the priority value is 0.
    - Increment the count for the given priority value.
    - Update the average priority value based on the decision variable.
3. Print the count and percentage distribution of each priority level.
4. Print the average priority values and their percentage distribution.

"""

if not model.Status == GRB.INFEASIBLE:
    promedios_prioridad = {}
    valores_prioridad = {}
    for i in range(1,4):
        promedios_prioridad[i] = 0
        valores_prioridad[i] = 0

    for p in profesores:
        for pr in p.prioridades:
            b = pr.bloque_horario
            A = pr.value
            if A == 0:
                continue
            valores_prioridad[A] += 1
            # for m in materias:
            #     promedios_prioridad[A] += round(w_dict[m.id, p.id].variable.X * u_dict[m.id, b.id].variable.X)
            promedios_prioridad[A] += round(y_dict[p.id, b.id].variable.X)

    print(valores_prioridad)
    total = np.sum([valores_prioridad[i] for i in valores_prioridad])
    print(*[str(i) + ": " + str(round(valores_prioridad[i]/total*100))+"%" for i in valores_prioridad], sep=", ")

    print(promedios_prioridad)
    total = np.sum([promedios_prioridad[i] for i in promedios_prioridad])
    if total != 0:
        print(*[str(i) + ": " + str(round(promedios_prioridad[i]/total*100))+"%" for i in promedios_prioridad], sep=", ")
        
        # CARGA_HORARIA_p = gp.quicksum(u_dict[m, b].variable * w_dict[m, p.id].variable for m in materias_ids for b in bloques_horario_ids).getValue()

        # if CARGA_HORARIA_p != 0:
        #     print(str(p), ": ", OBJ_p.getValue()/CARGA_HORARIA_p)
        # else:
        #     print(str(p), "sin carga horaria")
# Out:
# {1: 3179, 2: 442, 3: 424}
# 1: 79%, 2: 11%, 3: 10%
# {1: 576, 2: 61, 3: 41}
# 1: 85%, 2: 9%, 3: 6%

# %% [markdown]
# ### Ocupacion de salones

# %%
# nivel de ocupacion
if not model.Status == GRB.INFEASIBLE:
    niveles = {}

    for b_id in bloques_horario:
        salones_ocupados = int(gp.quicksum(u_dict[m, b_id].variable for m in materias_ids).getValue())
        nivel = int(salones_ocupados/K*100)
        # print(str(bloques_horario[b_id]), ": ", salones_ocupados,",", str(nivel) + "%")
        niveles[b_id] = nivel

    print_timetable_salones(dias, horarios, niveles)
# Out:
# 		1	2	3	4	5
# ··········································································································
# 0_start-0_end	61%	76%	61%	61%	76%
# 1_start-1_end	76%	76%	69%	76%	76%
# 2_start-2_end	76%	84%	84%	84%	76%
# 3_start-3_end	69%	84%	69%	76%	76%
# 4_start-4_end	76%	84%	69%	76%	69%
# 5_start-5_end	61%	76%	38%	61%	69%
# 6_start-6_end	7%	0%	0%	7%	7%
# 7_start-7_end	15%	30%	15%	30%	7%
# 8_start-8_end	15%	30%	15%	30%	23%
# 9_start-9_end	69%	46%	53%	61%	46%
# 10_start-10_end	76%	84%	69%	69%	76%
# 11_start-11_end	92%	92%	76%	100%	100%
# 12_start-12_end	76%	92%	76%	92%	84%
# 13_start-13_end	61%	92%	69%	92%	69%
# 14_start-14_end	69%	61%	53%	69%	61%
# 15_start-15_end	30%	15%	15%	23%	15%
